# %%
import os
import pandas as pd

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

train_data = pd.read_csv('/kaggle/input/ai-2-dl-for-nlp-2025-homework-3-distil-bert/train_dataset.csv')
test_data = pd.read_csv('/kaggle/input/ai-2-dl-for-nlp-2025-homework-3-distil-bert/test_dataset.csv')
validation_data = pd.read_csv('/kaggle/input/ai-2-dl-for-nlp-2025-homework-3-distil-bert/val_dataset.csv')
# Out:
# /kaggle/input/ai-2-dl-for-nlp-2025-homework-3-distil-bert/sample_submission.csv
# /kaggle/input/ai-2-dl-for-nlp-2025-homework-3-distil-bert/train_dataset.csv
# /kaggle/input/ai-2-dl-for-nlp-2025-homework-3-distil-bert/test_dataset.csv
# /kaggle/input/ai-2-dl-for-nlp-2025-homework-3-distil-bert/val_dataset.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

if 'plots' not in os.listdir():
    os.mkdir('plots')

# %%
import torch
import random
import numpy as np

def set_seed(seed):
    random.seed(seed)                   # Python random module
    np.random.seed(seed)                 # NumPy
    torch.manual_seed(seed)              # PyTorch CPU
    torch.cuda.manual_seed(seed)         # PyTorch GPU
    torch.cuda.manual_seed_all(seed)     # If you use multi-GPU
    torch.backends.cudnn.deterministic = True  # Make CUDA deterministic
    torch.backends.cudnn.benchmark = False     # Disable optimization for speed (forces deterministic)

set_seed(42)

# %%
train_data
# Out:
#             ID                                               Text  Label
# 0       189385      @whoisralphie dude  I'm so bummed ur leaving!      0
# 1        58036  oh my god, a severed foot was foun in a wheely...      0
# 2       190139  I end up &quot;dog dialing&quot; sumtimes. Wha...      1
# 3        99313                         @_rachelx meeeee toooooo!       0
# 4       157825  I was hoping I could stay home and work today,...      0
# ...        ...                                                ...    ...
# 148383   99894  just love the jonas brothers  its tooo bad i w...      0
# 148384   61015  another day gone by....time is moving so fast...       0
# 148385   36598  fuck college, i'm just gonna marry rich. : fuc...      1
# 148386   83799    ZOMGZ NEW SONG FTW.  remember that night. &lt;3      1
# 148387  185558  http://twitpic.com/7mwrd - Arby's took down th...      0
#
# [148388 rows x 3 columns]

# %%
import html
import re

# Function to preprocess text
def preprocess_text(text):
    # Unescape HTML characters
    text = html.unescape(text)
    # Remove URLs
    text = re.sub(r'http\S+|www\S+', '', text)
    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Function to preprocess text
def preprocess_text2(text):
    # Unescape HTML characters
    text = html.unescape(text)
    # Remove URLs
    text = re.sub(r'http\S+|www\S+', '<url>', text)
    # Remove mentions
    text = re.sub(r'@\w+', '<user>', text)
    # Remove hashtags
    text = re.sub(r'#\w+', '<hashtag>', text)
    # Remove special characters and numbers except < and >
    # text = re.sub(r'[^a-zA-Z0-9\s<>]', '', text)
    # text = re.sub(r'[^a-zA-Z0-9\s<>\.\,\!\?\:\;\'\"]', '', text)
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Apply preprocessing to train, test, and validation datasets
train_data['Clean'] = train_data['Text'].apply(preprocess_text)
test_data['Clean'] = test_data['Text'].apply(preprocess_text)
validation_data['Clean'] = validation_data['Text'].apply(preprocess_text)

# Apply preprocessing to train, test, and validation datasets
train_data['Clean2'] = train_data['Text'].apply(preprocess_text2)
test_data['Clean2'] = test_data['Text'].apply(preprocess_text2)
validation_data['Clean2'] = validation_data['Text'].apply(preprocess_text2)

# Display a sample of the cleaned text
train_data[['Text', 'Clean', 'Clean2']]
# Out:
#                                                      Text  \
# 0           @whoisralphie dude  I'm so bummed ur leaving!
# 1       oh my god, a severed foot was foun in a wheely...
# 2       I end up &quot;dog dialing&quot; sumtimes. Wha...
# 3                              @_rachelx meeeee toooooo!
# 4       I was hoping I could stay home and work today,...
# ...                                                   ...
# 148383  just love the jonas brothers  its tooo bad i w...
# 148384  another day gone by....time is moving so fast...
# 148385  fuck college, i'm just gonna marry rich. : fuc...
# 148386    ZOMGZ NEW SONG FTW.  remember that night. &lt;3
# 148387  http://twitpic.com/7mwrd - Arby's took down th...
#
#                                                     Clean  \
# 0               whoisralphie dude im so bummed ur leaving
# 1       oh my god a severed foot was foun in a wheely ...
# 2       i end up dog dialing sumtimes whats dog dialin...
# 3                                  rachelx meeeee toooooo
# 4       i was hoping i could stay home and work today ...
# ...                                                   ...
# 148383  just love the jonas brothers its tooo bad i wi...
# 148384          another day gone bytime is moving so fast
# 148385  fuck college im just gonna marry rich fuck col...
# 148386             zomgz new song ftw remember that night
# 148387  arbys took down their roastburger coupon but i...
#
#                                                    Clean2
# 0                   <user> dude I'm so bummed ur leaving!
# 1       oh my god, a severed foot was foun in a wheely...
# 2       I end up "dog dialing" sumtimes. What's dog di...
# 3                                  <user> meeeee toooooo!
# 4       I was hoping I could stay home and work today,...
# ...                                                   ...
# 148383  just love the jonas brothers its tooo bad i wi...
# 148384   another day gone by....time is moving so fast...
# 148385  fuck college, i'm just gonna marry rich. : fuc...
# 148386        ZOMGZ NEW SONG FTW. remember that night. <3
# 148387  <url> - Arby's took down their Roastburger cou...
#
# [148388 rows x 3 columns]

# %%
from transformers import DistilBertTokenizer
tokenizer1 = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
tokenizer2 = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]

# %%
# prompt: add special tokens to tokenizer2 (<url>, <user>, <hashtag>)

# Define the special tokens to add
special_tokens = ['<url>', '<user>', '<hashtag>']

# Add the special tokens to the tokenizer
num_added_toks = tokenizer2.add_special_tokens({'additional_special_tokens': special_tokens})

# %%
# prompt: tokenize the clean and clean2 columns

# Tokenize the 'Clean' and 'Clean2' columns
train_data['Tokenized_Clean'] = train_data['Clean'].apply(lambda x: tokenizer1.encode(x, add_special_tokens=True))
train_data['Tokenized_Clean2'] = train_data['Clean2'].apply(lambda x: tokenizer2.encode(x, add_special_tokens=True))

test_data['Tokenized_Clean'] = test_data['Clean'].apply(lambda x: tokenizer1.encode(x, add_special_tokens=True))
test_data['Tokenized_Clean2'] = test_data['Clean2'].apply(lambda x: tokenizer2.encode(x, add_special_tokens=True))

validation_data['Tokenized_Clean'] = validation_data['Clean'].apply(lambda x: tokenizer1.tokenize(x))
validation_data['Tokenized_Clean2'] = validation_data['Clean2'].apply(lambda x: tokenizer2.encode(x, add_special_tokens=True))

# Display a sample of the tokenized text
train_data[['Clean', 'Tokenized_Clean', 'Clean2', 'Tokenized_Clean2']]
# Out:
#                                                     Clean  \
# 0               whoisralphie dude im so bummed ur leaving
# 1       oh my god a severed foot was foun in a wheely ...
# 2       i end up dog dialing sumtimes whats dog dialin...
# 3                                  rachelx meeeee toooooo
# 4       i was hoping i could stay home and work today ...
# ...                                                   ...
# 148383  just love the jonas brothers its tooo bad i wi...
# 148384          another day gone bytime is moving so fast
# 148385  fuck college im just gonna marry rich fuck col...
# 148386             zomgz new song ftw remember that night
# 148387  arbys took down their roastburger coupon but i...
#
#                                           Tokenized_Clean  \
# 0       [101, 2040, 2483, 7941, 21850, 2063, 12043, 10...
# 1       [101, 2821, 2026, 2643, 1037, 16574, 3329, 200...
# 2       [101, 1045, 2203, 2039, 3899, 13764, 2075, 768...
# 3       [101, 5586, 2595, 2033, 4402, 4402, 2205, 9541...
# 4       [101, 1045, 2001, 5327, 1045, 2071, 2994, 2188...
# ...                                                   ...
# 148383  [101, 2074, 2293, 1996, 10680, 3428, 2049, 220...
# 148384  [101, 2178, 2154, 2908, 2011, 7292, 2003, 3048...
# 148385  [101, 6616, 2267, 10047, 2074, 6069, 5914, 413...
# 148386  [101, 1062, 5358, 2290, 2480, 2047, 2299, 3027...
# 148387  [101, 12098, 3762, 2015, 2165, 2091, 2037, 250...
#
#                                                    Clean2  \
# 0                   <user> dude I'm so bummed ur leaving!
# 1       oh my god, a severed foot was foun in a wheely...
# 2       I end up "dog dialing" sumtimes. What's dog di...
# 3                                  <user> meeeee toooooo!
# 4       I was hoping I could stay home and work today,...
# ...                                                   ...
# 148383  just love the jonas brothers its tooo bad i wi...
# 148384   another day gone by....time is moving so fast...
# 148385  fuck college, i'm just gonna marry rich. : fuc...
# 148386        ZOMGZ NEW SONG FTW. remember that night. <3
# 148387  <url> - Arby's took down their Roastburger cou...
#
#                                          Tokenized_Clean2
# 0       [101, 30523, 12043, 1045, 1005, 1049, 2061, 26...
# 1       [101, 2821, 2026, 2643, 1010, 1037, 16574, 332...
# 2       [101, 1045, 2203, 2039, 1000, 3899, 13764, 207...
# 3       [101, 30523, 2033, 4402, 4402, 2205, 9541, 954...
# 4       [101, 1045, 2001, 5327, 1045, 2071, 2994, 2188...
# ...                                                   ...
# 148383  [101, 2074, 2293, 1996, 10680, 3428, 2049, 220...
# 148384  [101, 2178, 2154, 2908, 2011, 1012, 1012, 1012...
# 148385  [101, 6616, 2267, 1010, 1045, 1005, 1049, 2074...
# 148386  [101, 1062, 5358, 2290, 2480, 2047, 2299, 3027...
# 148387  [101, 30522, 1011, 12098, 3762, 1005, 1055, 21...
#
# [148388 rows x 4 columns]

# %%
train_data['Tokenized_Clean'].map(len).describe(), train_data['Tokenized_Clean2'].map(len).describe()
# Out:
# (count    148388.000000
#  mean         18.007905
#  std           7.949658
#  min           2.000000
#  25%          12.000000
#  50%          17.000000
#  75%          24.000000
#  max          59.000000
#  Name: Tokenized_Clean, dtype: float64,
#  count    148388.000000
#  mean         20.322951
#  std           9.921036
#  min           3.000000
#  25%          12.000000
#  50%          19.000000
#  75%          27.000000
#  max         256.000000
#  Name: Tokenized_Clean2, dtype: float64)

# %%
# prompt: perform quantile analysis with the token length of Tokenized_Clean2 include plots

# Calculate token lengths for Tokenized_Clean2
train_data['Tokenized_Clean2_Length'] = train_data['Tokenized_Clean2'].map(len)
validation_data['Tokenized_Clean2_Length'] = validation_data['Tokenized_Clean2'].map(len)
test_data['Tokenized_Clean2_Length'] = test_data['Tokenized_Clean2'].map(len)

train_data['Dataset'] = 'Train'
validation_data['Dataset'] = 'Validation'
test_data['Dataset'] = 'Test'
# Concatenate all token lengths for Tokenized_Clean2
all_token_lengths_clean2 = pd.concat([train_data[['Tokenized_Clean2_Length', 'Dataset']],
                                     validation_data[['Tokenized_Clean2_Length', 'Dataset']],
                                     test_data[['Tokenized_Clean2_Length', 'Dataset']]])

# Prepare the combined DataFrame for plotting
all_token_lengths2 = pd.concat([train_data[['Tokenized_Clean2_Length', 'Dataset']],
                                 validation_data[['Tokenized_Clean2_Length', 'Dataset']],
                                 test_data[['Tokenized_Clean2_Length', 'Dataset']]])

# Plotting the distribution of token lengths for all datasets, varying hue by dataset
# plt.figure(figsize=(10, 6))
sns.ecdfplot(data=all_token_lengths2, x='Tokenized_Clean2_Length', hue='Dataset')
plt.title('Distribution of Token Lengths (Tokenized_Clean2) by Dataset')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.savefig('plots/token_length_distribution_clean2_by_dataset.png', dpi=300)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# # prompt: retokenize using tokenizer2 with a max length of 128 (with padding) and replace tokenized_clean2

# # Retokenize using tokenizer2 with max length 128 and padding
# train_data['Tokenized_Clean2'] = train_data['Clean2'].apply(lambda x: tokenizer2(x, padding='max_length', truncation=True, max_length=64))
# test_data['Tokenized_Clean2'] = test_data['Clean2'].apply(lambda x: tokenizer2(x, padding='max_length', truncation=True, max_length=64))
# validation_data['Tokenized_Clean2'] = validation_data['Clean2'].apply(lambda x: tokenizer2(x, padding='max_length', truncation=True, max_length=64))

# # Display a sample of the retokenized text (showing input_ids for simplicity)
# train_data[['Clean2', 'Tokenized_Clean2']]

# %%
# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def tokenize_and_encode(text, tokenizer, max_len):
    encoded = tokenizer.encode_plus(
        text,
        padding='max_length',
        truncation=True,
        max_length=max_len,
        return_attention_mask=True,
        return_tensors='pt'  # Return PyTorch tensors
    )
    return encoded['input_ids'].squeeze(), encoded['attention_mask'].squeeze() # Return as tensors

# %%
max_length = train_data['Tokenized_Clean'].map(len).max()

train_data['Tokenized_Clean'], train_data['Attention_Mask_Clean'] = zip(*train_data['Clean'].apply(lambda x: tokenize_and_encode(x, tokenizer2, max_length)))
test_data['Tokenized_Clean'], test_data['Attention_Mask_Clean'] = zip(*test_data['Clean'].apply(lambda x: tokenize_and_encode(x, tokenizer2, max_length)))
validation_data['Tokenized_Clean'], validation_data['Attention_Mask_Clean'] = zip(*validation_data['Clean'].apply(lambda x: tokenize_and_encode(x, tokenizer2, max_length)))

# Display a sample of the encoded data (showing input_ids and attention_mask)
print("Sample of encoded train data:")
print(train_data[['Clean', 'Tokenized_Clean', 'Attention_Mask_Clean']].head())

print("\nSample of encoded test data:")
print(test_data[['Clean', 'Tokenized_Clean', 'Attention_Mask_Clean']].head())

print("\nSample of encoded validation data:")
print(validation_data[['Clean', 'Tokenized_Clean', 'Attention_Mask_Clean']].head())

print("\nShape of encoded data (first element):")
print(train_data['Tokenized_Clean'].iloc[0].shape)
print(train_data['Attention_Mask_Clean'].iloc[0].shape)
# Out:
# Sample of encoded train data:
#                                                Clean  \
# 0          whoisralphie dude im so bummed ur leaving
# 1  oh my god a severed foot was foun in a wheely ...
# 2  i end up dog dialing sumtimes whats dog dialin...
# 3                             rachelx meeeee toooooo
# 4  i was hoping i could stay home and work today ...
#
#                                      Tokenized_Clean  \
# 0  [tensor(101), tensor(2040), tensor(2483), tens...
# 1  [tensor(101), tensor(2821), tensor(2026), tens...
# 2  [tensor(101), tensor(1045), tensor(2203), tens...
# 3  [tensor(101), tensor(5586), tensor(2595), tens...
# 4  [tensor(101), tensor(1045), tensor(2001), tens...
#
#                                 Attention_Mask_Clean
# 0  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 1  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 2  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 3  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 4  [tensor(1), tensor(1), tensor(1), tensor(1), t...
#
# Sample of encoded test data:
#                                                Clean  \
# 0  the books arrived those who want a copy write ...
# 1  spunkransom alright yea its cute i guess this ...
# 2          on the way to zen buffet no crabs i think
# 3                        good tuesday morning all am
# 4                                         bed timeee
#
#                                      Tokenized_Clean  \
# 0  [tensor(101), tensor(1996), tensor(2808), tens...
# 1  [tensor(101), tensor(7455), tensor(22272), ten...
# 2  [tensor(101), tensor(2006), tensor(1996), tens...
# 3  [tensor(101), tensor(2204), tensor(9857), tens...
# 4  [tensor(101), tensor(2793), tensor(2051), tens...
#
#                                 Attention_Mask_Clean
# 0  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 1  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 2  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 3  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 4  [tensor(1), tensor(1), tensor(1), tensor(1), t...
#
# Sample of encoded validation data:
#                                                Clean  \
# 0  natexthegreat heyheyhey maybe i will get them ...
# 1  molliesmummy work work was crap i missed your ...
# 2  want trip to boston next month need additl mot...
# 3                          first day starts tomorrow
# 4  goodforyoursoul course fish in little saigon a...
#
#                                      Tokenized_Clean  \
# 0  [tensor(101), tensor(8253), tensor(18413), ten...
# 1  [tensor(101), tensor(9587), tensor(23697), ten...
# 2  [tensor(101), tensor(2215), tensor(4440), tens...
# 3  [tensor(101), tensor(2034), tensor(2154), tens...
# 4  [tensor(101), tensor(2204), tensor(29278), ten...
#
#                                 Attention_Mask_Clean
# 0  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 1  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 2  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 3  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 4  [tensor(1), tensor(1), tensor(1), tensor(1), t...
#
# Shape of encoded data (first element):
# torch.Size([59])
# torch.Size([59])

# %%
# prompt: reencode the dataset using special tokens and attentionmasks


max_length = 64

train_data['Tokenized_Clean2'], train_data['Attention_Mask_Clean2'] = zip(*train_data['Clean2'].apply(lambda x: tokenize_and_encode(x, tokenizer2, max_length)))
test_data['Tokenized_Clean2'], test_data['Attention_Mask_Clean2'] = zip(*test_data['Clean2'].apply(lambda x: tokenize_and_encode(x, tokenizer2, max_length)))
validation_data['Tokenized_Clean2'], validation_data['Attention_Mask_Clean2'] = zip(*validation_data['Clean2'].apply(lambda x: tokenize_and_encode(x, tokenizer2, max_length)))

# Display a sample of the encoded data (showing input_ids and attention_mask)
print("Sample of encoded train data:")
print(train_data[['Clean2', 'Tokenized_Clean2', 'Attention_Mask_Clean2']].head())

print("\nSample of encoded test data:")
print(test_data[['Clean2', 'Tokenized_Clean2', 'Attention_Mask_Clean2']].head())

print("\nSample of encoded validation data:")
print(validation_data[['Clean2', 'Tokenized_Clean2', 'Attention_Mask_Clean2']].head())

print("\nShape of encoded data (first element):")
print(train_data['Tokenized_Clean2'].iloc[0].shape)
print(train_data['Attention_Mask_Clean2'].iloc[0].shape)
# Out:
# Sample of encoded train data:
#                                               Clean2  \
# 0              <user> dude I'm so bummed ur leaving!
# 1  oh my god, a severed foot was foun in a wheely...
# 2  I end up "dog dialing" sumtimes. What's dog di...
# 3                             <user> meeeee toooooo!
# 4  I was hoping I could stay home and work today,...
#
#                                     Tokenized_Clean2  \
# 0  [tensor(101), tensor(30523), tensor(12043), te...
# 1  [tensor(101), tensor(2821), tensor(2026), tens...
# 2  [tensor(101), tensor(1045), tensor(2203), tens...
# 3  [tensor(101), tensor(30523), tensor(2033), ten...
# 4  [tensor(101), tensor(1045), tensor(2001), tens...
#
#                                Attention_Mask_Clean2
# 0  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 1  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 2  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 3  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 4  [tensor(1), tensor(1), tensor(1), tensor(1), t...
#
# Sample of encoded test data:
#                                               Clean2  \
# 0  The books ARRIVED!!! Those who want a copy - w...
# 1  <user> alright yea its cute. I guess this prov...
# 2         On the way to zen buffet! no crabs I think
# 3              Good Tuesday Morning All (5:20am)....
# 4                                         Bed timeee
#
#                                     Tokenized_Clean2  \
# 0  [tensor(101), tensor(1996), tensor(2808), tens...
# 1  [tensor(101), tensor(30523), tensor(10303), te...
# 2  [tensor(101), tensor(2006), tensor(1996), tens...
# 3  [tensor(101), tensor(2204), tensor(9857), tens...
# 4  [tensor(101), tensor(2793), tensor(2051), tens...
#
#                                Attention_Mask_Clean2
# 0  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 1  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 2  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 3  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 4  [tensor(1), tensor(1), tensor(1), tensor(1), t...
#
# Sample of encoded validation data:
#                                               Clean2  \
# 0  <user> heyheyhey maybe i will get them IF I CO...
# 1  <user> Work? Work was crap. I missed your cond...
# 2  Want: Trip to Boston next month. Need: Addit'l...
# 3                         first day starts tomorrow!
# 4  <user> 8 course fish in Little Saigon, and a d...
#
#                                     Tokenized_Clean2  \
# 0  [tensor(101), tensor(30523), tensor(4931), ten...
# 1  [tensor(101), tensor(30523), tensor(2147), ten...
# 2  [tensor(101), tensor(2215), tensor(1024), tens...
# 3  [tensor(101), tensor(2034), tensor(2154), tens...
# 4  [tensor(101), tensor(30523), tensor(1022), ten...
#
#                                Attention_Mask_Clean2
# 0  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 1  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 2  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 3  [tensor(1), tensor(1), tensor(1), tensor(1), t...
# 4  [tensor(1), tensor(1), tensor(1), tensor(1), t...
#
# Shape of encoded data (first element):
# torch.Size([64])
# torch.Size([64])

# %%
# prompt: generate train test validation dataloaders from tokenized_clean and tokenized_clean2 with attention masks for distilbert (don't define custom datasets)

from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset

# Convert lists of tensors to single tensors
train_inputs_clean = torch.stack(list(train_data['Tokenized_Clean']))
train_masks_clean = torch.stack(list(train_data['Attention_Mask_Clean']))
train_labels = torch.tensor(train_data['Label'].values)

validation_inputs_clean = torch.stack(list(validation_data['Tokenized_Clean']))
validation_masks_clean = torch.stack(list(validation_data['Attention_Mask_Clean']))
validation_labels = torch.tensor(validation_data['Label'].values)

test_inputs_clean = torch.stack(list(test_data['Tokenized_Clean']))
test_masks_clean = torch.stack(list(test_data['Attention_Mask_Clean']))
test_labels = torch.tensor([0.0] * len(test_data))

train_inputs_clean2 = torch.stack(list(train_data['Tokenized_Clean2']))
train_masks_clean2 = torch.stack(list(train_data['Attention_Mask_Clean2']))

validation_inputs_clean2 = torch.stack(list(validation_data['Tokenized_Clean2']))
validation_masks_clean2 = torch.stack(list(validation_data['Attention_Mask_Clean2']))

test_inputs_clean2 = torch.stack(list(test_data['Tokenized_Clean2']))
test_masks_clean2 = torch.stack(list(test_data['Attention_Mask_Clean2']))

# Create TensorDatasets
train_dataset_clean = TensorDataset(train_inputs_clean, train_masks_clean, train_labels)
validation_dataset_clean = TensorDataset(validation_inputs_clean, validation_masks_clean, validation_labels)
test_dataset_clean = TensorDataset(test_inputs_clean, test_masks_clean, test_labels)

train_dataset_clean2 = TensorDataset(train_inputs_clean2, train_masks_clean2, train_labels)
validation_dataset_clean2 = TensorDataset(validation_inputs_clean2, validation_masks_clean2, validation_labels)
test_dataset_clean2 = TensorDataset(test_inputs_clean2, test_masks_clean2, test_labels)

# Define batch size
batch_size = 32

# Create DataLoaders for Tokenized_Clean
train_dataloader_clean = DataLoader(train_dataset_clean, batch_size=batch_size, shuffle=True)
validation_dataloader_clean = DataLoader(validation_dataset_clean, batch_size=batch_size)
test_dataloader_clean = DataLoader(test_dataset_clean, batch_size=batch_size)

# Create DataLoaders for Tokenized_Clean2
train_dataloader_clean2 = DataLoader(train_dataset_clean2, batch_size=batch_size, shuffle=True)
validation_dataloader_clean2 = DataLoader(validation_dataset_clean2, batch_size=batch_size)
test_dataloader_clean2 = DataLoader(test_dataset_clean2, batch_size=batch_size)

print("\nDataLoaders created:")
print(f"train_dataloader_clean: {len(train_dataloader_clean)} batches")
print(f"validation_dataloader_clean: {len(validation_dataloader_clean)} batches")
print(f"test_dataloader_clean: {len(test_dataloader_clean)} batches")
print(f"train_dataloader_clean2: {len(train_dataloader_clean2)} batches")
print(f"validation_dataloader_clean2: {len(validation_dataloader_clean2)} batches")
print(f"test_dataloader_clean2: {len(test_dataloader_clean2)} batches")
# Out:
# DataLoaders created:
# train_dataloader_clean: 4638 batches
# validation_dataloader_clean: 1325 batches
# test_dataloader_clean: 663 batches
# train_dataloader_clean2: 4638 batches
# validation_dataloader_clean2: 1325 batches
# test_dataloader_clean2: 663 batches

# %%
import datetime

# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))

    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
import time

def train_and_validate(model, train_dataloader, validation_dataloader, optimizer, scheduler, device, epochs=2):
    training_stats = []

    # Measure the total training time for the whole run.
    total_t0 = time.time()

    # For each epoch...
    for epoch_i in range(0, epochs):

        # ========================================
        #               Training
        # ========================================

        # Perform one full pass over the training set.

        print("")
        print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
        print('Training...')

        # Measure how long the training epoch takes.
        t0 = time.time()

        # Reset the total loss for this epoch.
        total_train_loss = 0
        total_train_correct = 0

        # Put the model into training mode. Don't be mislead--the call to
        # `train` just changes the *mode*, it doesn't *perform* the training.
        # `dropout` and `batchnorm` layers behave differently during training
        # vs. test (source: https://stackoverflow.com/questions/51433378/what-does-model-train-do-in-pytorch)
        model.train()

        # For each batch of training data...
        for step, batch in enumerate(train_dataloader):

            # Progress update every 40 batches.
            if step % 40 == 0 and not step == 0:
                # Calculate elapsed time in minutes.
                elapsed = format_time(time.time() - t0)

                # Report progress.
                print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

            # Unpack this training batch from our dataloader.
            #
            # As we unpack the batch, we'll also copy each tensor to the GPU using the
            # `to` method.
            #
            # `batch` contains three pytorch tensors:
            #   [0]: input ids
            #   [1]: attention masks
            #   [2]: labels
            b_input_ids = batch[0].to(device)
            b_input_mask = batch[1].to(device)
            b_labels = batch[2].to(device)

            # Always clear any previously calculated gradients before performing a
            # backward pass. PyTorch doesn't do this automatically because
            # accumulating the gradients is "convenient while training RNNs".
            # (source: https://stackoverflow.com/questions/48001598/why-do-we-need-to-call-zero-grad-in-pytorch)
            model.zero_grad()

            # Perform a forward pass (evaluate the model on this training batch).
            # In PyTorch, calling `model` will in turn call the model's `forward`
            # function and pass down the arguments. The `forward` function is
            # documented here:
            # https://huggingface.co/transformers/model_doc/bert.html#bertforsequenceclassification
            # The results are returned in a results object, documented here:
            # https://huggingface.co/transformers/main_classes/output.html#transformers.modeling_outputs.SequenceClassifierOutput
            # Specifically, we'll get the loss (because we provided labels) and the
            # "logits"--the model outputs prior to activation (the scores).
            result = model(b_input_ids,
                        attention_mask=b_input_mask,
                        labels=b_labels,
                        return_dict=True)

            loss = result.loss
            logits = result.logits

            # Accumulate the training loss over all of the batches so that we can
            # calculate the average loss at the end. `loss` is a Tensor containing a
            # single value; the `.item()` function just returns the Python value
            # from the tensor.
            logits = logits.detach().cpu().numpy()
            label_ids = b_labels.to('cpu').numpy()
            total_train_correct += flat_accuracy(logits, label_ids)
            total_train_loss += loss.item()

            # Perform a backward pass to calculate the gradients.
            loss.backward()

            # Clip the norm of the gradients to 1.0.
            # This is to help prevent the "exploding gradients" problem.
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

            # Update parameters and take a step using the computed gradient.
            # The optimizer dictates the "update rule"--how the parameters are
            # modified based on their gradients, the learning rate, etc.
            optimizer.step()

            # Update the learning rate.
            scheduler.step()

        # Calculate the average loss over all of the batches.
        avg_train_loss = total_train_loss / len(train_dataloader)
        avg_train_acc = total_train_correct / len(train_dataloader)

        # Measure how long this epoch took.
        training_time = format_time(time.time() - t0)

        print("")
        print("  Average training loss: {0:.2f}".format(avg_train_loss))
        print("  Average training accuracy: {0:.2f}".format(avg_train_acc))
        print("  Training epcoh took: {:}".format(training_time))

        # ========================================
        #               Validation
        # ========================================
        # After the completion of each training epoch, measure our performance on
        # our validation set.

        print("")
        print("Running Validation...")

        t0 = time.time()

        # Put the model in evaluation mode--the dropout layers behave differently
        # during evaluation.
        model.eval()

        # Tracking variables
        total_eval_accuracy = 0
        total_eval_loss = 0
        nb_eval_steps = 0

        # Evaluate data for one epoch
        for batch in validation_dataloader:

            # Unpack this training batch from our dataloader.
            #
            # As we unpack the batch, we'll also copy each tensor to the GPU using
            # the `to` method.
            #
            # `batch` contains three pytorch tensors:
            #   [0]: input ids
            #   [1]: attention masks
            #   [2]: labels
            b_input_ids = batch[0].to(device)
            b_input_mask = batch[1].to(device)
            b_labels = batch[2].to(device)

            # Tell pytorch not to bother with constructing the compute graph during
            # the forward pass, since this is only needed for backprop (training).
            with torch.no_grad():

                # Forward pass, calculate logit predictions.
                # token_type_ids is the same as the "segment ids", which
                # differentiates sentence 1 and 2 in 2-sentence tasks.
                result = model(b_input_ids,
                            attention_mask=b_input_mask,
                            labels=b_labels,
                            return_dict=True)

            # Get the loss and "logits" output by the model. The "logits" are the
            # output values prior to applying an activation function like the
            # softmax.
            loss = result.loss
            logits = result.logits

            # Accumulate the validation loss.
            total_eval_loss += loss.item()

            # Move logits and labels to CPU
            logits = logits.detach().cpu().numpy()
            label_ids = b_labels.to('cpu').numpy()

            # Calculate the accuracy for this batch of test sentences, and
            # accumulate it over all batches.
            total_eval_accuracy += flat_accuracy(logits, label_ids)


        # Report the final accuracy for this validation run.
        avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
        print("  Accuracy: {0:.2f}".format(avg_val_accuracy))

        # Calculate the average loss over all of the batches.
        avg_val_loss = total_eval_loss / len(validation_dataloader)

        # Measure how long the validation run took.
        validation_time = format_time(time.time() - t0)

        print("  Validation Loss: {0:.2f}".format(avg_val_loss))
        print("  Validation took: {:}".format(validation_time))

        # Record all statistics from this epoch.
        training_stats.append(
            {
                'epoch': epoch_i + 1,
                'Training Accur.': avg_train_acc,
                'Training Loss': avg_train_loss,
                'Valid. Loss': avg_val_loss,
                'Valid. Accur.': avg_val_accuracy,
                'Training Time': training_time,
                'Validation Time': validation_time
            }
        )

    print("")
    print("Training complete!")

    print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
    return training_stats

# %%
def plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies, name=None):
    epochs = range(1, len(train_losses) + 1)
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_losses, label='Training Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.plot(epochs, train_accuracies, label='Training Accuracy')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Loss/Accuracy')
    plt.title('Training and Validation Metrics')
    plt.legend()
    plt.grid(True)
    if name:
        plt.savefig(name, dpi=300)
    plt.show()

# %%
import torch.nn.functional as F
from sklearn.metrics import classification_report

def extract_metrics(model, validation_loader, device):
  model.eval()  # Set the model to evaluation mode
  y_true = []
  y_pred = []
  y_proba = []

  for batch in validation_loader:
    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_labels = batch[2].to(device)

    with torch.no_grad():
      outputs = model(b_input_ids,
                      attention_mask=b_input_mask)

    logits = outputs.logits
    probabilities = F.softmax(logits, dim=1)

    # Move to CPU and convert to numpy arrays
    logits = logits.detach().cpu().numpy()
    label_ids = b_labels.to('cpu').numpy()
    probabilities = probabilities.detach().cpu().numpy()

    # Store results
    y_true.extend(label_ids)
    y_pred.extend(np.argmax(logits, axis=1).flatten())
    y_proba.extend(probabilities)

  return np.array(y_true), np.array(y_pred), np.array(y_proba)[:, 1]

# %%
from transformers import DistilBertForSequenceClassification
from torch.optim import AdamW
from transformers import get_linear_schedule_with_warmup

def get_model(resize_embeddings=False, device='cuda'):
    model = DistilBertForSequenceClassification.from_pretrained(
        "distilbert-base-uncased",
        num_labels = 2,
        output_attentions = False,
        output_hidden_states = False,
    )
    if resize_embeddings:
        model.distilbert.resize_token_embeddings(len(tokenizer2))
    model.to(device)
    return model
# Out:
# 2025-06-01 17:47:29.997065: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748800050.213773      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748800050.277046      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
model1 = get_model(device=device)
epochs = 2

optimizer = AdamW(model1.parameters(), lr = 1e-5, eps = 1e-8)
total_steps = len(train_dataloader_clean) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps = 0, num_training_steps = total_steps)
results1 = train_and_validate(model1, train_dataloader_clean, validation_dataloader_clean, optimizer, scheduler, device, epochs)
y_true1, y_pred1, y_proba1 = extract_metrics(model1, validation_dataloader_clean, device)
print(classification_report(y_true1, y_pred1))
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ======== Epoch 1 / 2 ========
# Training...
#   Batch    40  of  4,638.    Elapsed: 0:00:04.
#   Batch    80  of  4,638.    Elapsed: 0:00:08.
#   Batch   120  of  4,638.    Elapsed: 0:00:12.
#   Batch   160  of  4,638.    Elapsed: 0:00:16.
#   Batch   200  of  4,638.    Elapsed: 0:00:20.
#   Batch   240  of  4,638.    Elapsed: 0:00:23.
#   Batch   280  of  4,638.    Elapsed: 0:00:27.
#   Batch   320  of  4,638.    Elapsed: 0:00:31.
#   Batch   360  of  4,638.    Elapsed: 0:00:35.
#   Batch   400  of  4,638.    Elapsed: 0:00:39.
#   Batch   440  of  4,638.    Elapsed: 0:00:42.
#   Batch   480  of  4,638.    Elapsed: 0:00:46.
#   Batch   520  of  4,638.    Elapsed: 0:00:50.
#   Batch   560  of  4,638.    Elapsed: 0:00:54.
#   Batch   600  of  4,638.    Elapsed: 0:00:57.
#   Batch   640  of  4,638.    Elapsed: 0:01:01.
#   Batch   680  of  4,638.    Elapsed: 0:01:05.
#   Batch   720  of  4,638.    Elapsed: 0:01:09.
#   Batch   760  of  4,638.    Elapsed: 0:01:13.
#   Batch   800  of  4,638.    Elapsed: 0:01:16.
#   Batch   840  of  4,638.    Elapsed: 0:01:20.
#   Batch   880  of  4,638.    Elapsed: 0:01:24.
#   Batch   920  of  4,638.    Elapsed: 0:01:28.
#   Batch   960  of  4,638.    Elapsed: 0:01:31.
#   Batch 1,000  of  4,638.    Elapsed: 0:01:35.
#   Batch 1,040  of  4,638.    Elapsed: 0:01:39.
#   Batch 1,080  of  4,638.    Elapsed: 0:01:43.
#   Batch 1,120  of  4,638.    Elapsed: 0:01:47.
#   Batch 1,160  of  4,638.    Elapsed: 0:01:50.
#   Batch 1,200  of  4,638.    Elapsed: 0:01:54.
#   Batch 1,240  of  4,638.    Elapsed: 0:01:58.
#   Batch 1,280  of  4,638.    Elapsed: 0:02:02.
#   Batch 1,320  of  4,638.    Elapsed: 0:02:05.
#   Batch 1,360  of  4,638.    Elapsed: 0:02:09.
#   Batch 1,400  of  4,638.    Elapsed: 0:02:13.
#   Batch 1,440  of  4,638.    Elapsed: 0:02:17.
#   Batch 1,480  of  4,638.    Elapsed: 0:02:21.
#   Batch 1,520  of  4,638.    Elapsed: 0:02:24.
#   Batch 1,560  of  4,638.    Elapsed: 0:02:28.
#   Batch 1,600  of  4,638.    Elapsed: 0:02:32.
#   Batch 1,640  of  4,638.    Elapsed: 0:02:36.
#   Batch 1,680  of  4,638.    Elapsed: 0:02:39.
#   Batch 1,720  of  4,638.    Elapsed: 0:02:43.
#   Batch 1,760  of  4,638.    Elapsed: 0:02:47.
#   Batch 1,800  of  4,638.    Elapsed: 0:02:51.
#   Batch 1,840  of  4,638.    Elapsed: 0:02:55.
#   Batch 1,880  of  4,638.    Elapsed: 0:02:58.
#   Batch 1,920  of  4,638.    Elapsed: 0:03:02.
#   Batch 1,960  of  4,638.    Elapsed: 0:03:06.
#   Batch 2,000  of  4,638.    Elapsed: 0:03:10.
#   Batch 2,040  of  4,638.    Elapsed: 0:03:13.
#   Batch 2,080  of  4,638.    Elapsed: 0:03:17.
#   Batch 2,120  of  4,638.    Elapsed: 0:03:21.
#   Batch 2,160  of  4,638.    Elapsed: 0:03:25.
#   Batch 2,200  of  4,638.    Elapsed: 0:03:29.
#   Batch 2,240  of  4,638.    Elapsed: 0:03:32.
#   Batch 2,280  of  4,638.    Elapsed: 0:03:36.
#   Batch 2,320  of  4,638.    Elapsed: 0:03:40.
#   Batch 2,360  of  4,638.    Elapsed: 0:03:44.
#   Batch 2,400  of  4,638.    Elapsed: 0:03:48.
#   Batch 2,440  of  4,638.    Elapsed: 0:03:51.
#   Batch 2,480  of  4,638.    Elapsed: 0:03:55.
#   Batch 2,520  of  4,638.    Elapsed: 0:03:59.
#   Batch 2,560  of  4,638.    Elapsed: 0:04:03.
#   Batch 2,600  of  4,638.    Elapsed: 0:04:06.
#   Batch 2,640  of  4,638.    Elapsed: 0:04:10.
#   Batch 2,680  of  4,638.    Elapsed: 0:04:14.
#   Batch 2,720  of  4,638.    Elapsed: 0:04:18.
#   Batch 2,760  of  4,638.    Elapsed: 0:04:22.
#   Batch 2,800  of  4,638.    Elapsed: 0:04:25.
#   Batch 2,840  of  4,638.    Elapsed: 0:04:29.
#   Batch 2,880  of  4,638.    Elapsed: 0:04:33.
#   Batch 2,920  of  4,638.    Elapsed: 0:04:37.
#   Batch 2,960  of  4,638.    Elapsed: 0:04:40.
#   Batch 3,000  of  4,638.    Elapsed: 0:04:44.
#   Batch 3,040  of  4,638.    Elapsed: 0:04:48.
#   Batch 3,080  of  4,638.    Elapsed: 0:04:52.
#   Batch 3,120  of  4,638.    Elapsed: 0:04:56.
#   Batch 3,160  of  4,638.    Elapsed: 0:04:59.
#   Batch 3,200  of  4,638.    Elapsed: 0:05:03.
#   Batch 3,240  of  4,638.    Elapsed: 0:05:07.
#   Batch 3,280  of  4,638.    Elapsed: 0:05:11.
#   Batch 3,320  of  4,638.    Elapsed: 0:05:14.
#   Batch 3,360  of  4,638.    Elapsed: 0:05:18.
#   Batch 3,400  of  4,638.    Elapsed: 0:05:22.
#   Batch 3,440  of  4,638.    Elapsed: 0:05:26.
#   Batch 3,480  of  4,638.    Elapsed: 0:05:30.
#   Batch 3,520  of  4,638.    Elapsed: 0:05:33.
#   Batch 3,560  of  4,638.    Elapsed: 0:05:37.
#   Batch 3,600  of  4,638.    Elapsed: 0:05:41.
#   Batch 3,640  of  4,638.    Elapsed: 0:05:45.
#   Batch 3,680  of  4,638.    Elapsed: 0:05:48.
#   Batch 3,720  of  4,638.    Elapsed: 0:05:52.
#   Batch 3,760  of  4,638.    Elapsed: 0:05:56.
#   Batch 3,800  of  4,638.    Elapsed: 0:06:00.
#   Batch 3,840  of  4,638.    Elapsed: 0:06:04.
#   Batch 3,880  of  4,638.    Elapsed: 0:06:07.
#   Batch 3,920  of  4,638.    Elapsed: 0:06:11.
#   Batch 3,960  of  4,638.    Elapsed: 0:06:15.
#   Batch 4,000  of  4,638.    Elapsed: 0:06:19.
#   Batch 4,040  of  4,638.    Elapsed: 0:06:22.
#   Batch 4,080  of  4,638.    Elapsed: 0:06:26.
#   Batch 4,120  of  4,638.    Elapsed: 0:06:30.
#   Batch 4,160  of  4,638.    Elapsed: 0:06:34.
#   Batch 4,200  of  4,638.    Elapsed: 0:06:38.
#   Batch 4,240  of  4,638.    Elapsed: 0:06:41.
#   Batch 4,280  of  4,638.    Elapsed: 0:06:45.
#   Batch 4,320  of  4,638.    Elapsed: 0:06:49.
#   Batch 4,360  of  4,638.    Elapsed: 0:06:53.
#   Batch 4,400  of  4,638.    Elapsed: 0:06:56.
#   Batch 4,440  of  4,638.    Elapsed: 0:07:00.
#   Batch 4,480  of  4,638.    Elapsed: 0:07:04.
#   Batch 4,520  of  4,638.    Elapsed: 0:07:08.
#   Batch 4,560  of  4,638.    Elapsed: 0:07:12.
#   Batch 4,600  of  4,638.    Elapsed: 0:07:15.
#
#   Average training loss: 0.42
#   Average training accuracy: 0.81
#   Training epcoh took: 0:07:19
#
# Running Validation...
#   Accuracy: 0.83
#   Validation Loss: 0.39
#   Validation took: 0:00:35
#
# ======== Epoch 2 / 2 ========
# Training...
#   Batch    40  of  4,638.    Elapsed: 0:00:04.
#   Batch    80  of  4,638.    Elapsed: 0:00:08.
#   Batch   120  of  4,638.    Elapsed: 0:00:11.
#   Batch   160  of  4,638.    Elapsed: 0:00:15.
#   Batch   200  of  4,638.    Elapsed: 0:00:19.
#   Batch   240  of  4,638.    Elapsed: 0:00:23.
#   Batch   280  of  4,638.    Elapsed: 0:00:26.
#   Batch   320  of  4,638.    Elapsed: 0:00:30.
#   Batch   360  of  4,638.    Elapsed: 0:00:34.
#   Batch   400  of  4,638.    Elapsed: 0:00:38.
#   Batch   440  of  4,638.    Elapsed: 0:00:42.
#   Batch   480  of  4,638.    Elapsed: 0:00:45.
#   Batch   520  of  4,638.    Elapsed: 0:00:49.
#   Batch   560  of  4,638.    Elapsed: 0:00:53.
#   Batch   600  of  4,638.    Elapsed: 0:00:57.
#   Batch   640  of  4,638.    Elapsed: 0:01:00.
#   Batch   680  of  4,638.    Elapsed: 0:01:04.
#   Batch   720  of  4,638.    Elapsed: 0:01:08.
#   Batch   760  of  4,638.    Elapsed: 0:01:12.
#   Batch   800  of  4,638.    Elapsed: 0:01:16.
#   Batch   840  of  4,638.    Elapsed: 0:01:19.
#   Batch   880  of  4,638.    Elapsed: 0:01:23.
#   Batch   920  of  4,638.    Elapsed: 0:01:27.
#   Batch   960  of  4,638.    Elapsed: 0:01:31.
#   Batch 1,000  of  4,638.    Elapsed: 0:01:34.
#   Batch 1,040  of  4,638.    Elapsed: 0:01:38.
#   Batch 1,080  of  4,638.    Elapsed: 0:01:42.
#   Batch 1,120  of  4,638.    Elapsed: 0:01:46.
#   Batch 1,160  of  4,638.    Elapsed: 0:01:50.
#   Batch 1,200  of  4,638.    Elapsed: 0:01:53.
#   Batch 1,240  of  4,638.    Elapsed: 0:01:57.
#   Batch 1,280  of  4,638.    Elapsed: 0:02:01.
#   Batch 1,320  of  4,638.    Elapsed: 0:02:05.
#   Batch 1,360  of  4,638.    Elapsed: 0:02:08.
#   Batch 1,400  of  4,638.    Elapsed: 0:02:12.
#   Batch 1,440  of  4,638.    Elapsed: 0:02:16.
#   Batch 1,480  of  4,638.    Elapsed: 0:02:20.
#   Batch 1,520  of  4,638.    Elapsed: 0:02:24.
#   Batch 1,560  of  4,638.    Elapsed: 0:02:27.
#   Batch 1,600  of  4,638.    Elapsed: 0:02:31.
#   Batch 1,640  of  4,638.    Elapsed: 0:02:35.
#   Batch 1,680  of  4,638.    Elapsed: 0:02:39.
#   Batch 1,720  of  4,638.    Elapsed: 0:02:42.
#   Batch 1,760  of  4,638.    Elapsed: 0:02:46.
#   Batch 1,800  of  4,638.    Elapsed: 0:02:50.
#   Batch 1,840  of  4,638.    Elapsed: 0:02:54.
#   Batch 1,880  of  4,638.    Elapsed: 0:02:58.
#   Batch 1,920  of  4,638.    Elapsed: 0:03:01.
#   Batch 1,960  of  4,638.    Elapsed: 0:03:05.
#   Batch 2,000  of  4,638.    Elapsed: 0:03:09.
#   Batch 2,040  of  4,638.    Elapsed: 0:03:13.
#   Batch 2,080  of  4,638.    Elapsed: 0:03:16.
#   Batch 2,120  of  4,638.    Elapsed: 0:03:20.
#   Batch 2,160  of  4,638.    Elapsed: 0:03:24.
#   Batch 2,200  of  4,638.    Elapsed: 0:03:28.
#   Batch 2,240  of  4,638.    Elapsed: 0:03:32.
#   Batch 2,280  of  4,638.    Elapsed: 0:03:35.
#   Batch 2,320  of  4,638.    Elapsed: 0:03:39.
#   Batch 2,360  of  4,638.    Elapsed: 0:03:43.
#   Batch 2,400  of  4,638.    Elapsed: 0:03:47.
#   Batch 2,440  of  4,638.    Elapsed: 0:03:50.
#   Batch 2,480  of  4,638.    Elapsed: 0:03:54.
#   Batch 2,520  of  4,638.    Elapsed: 0:03:58.
#   Batch 2,560  of  4,638.    Elapsed: 0:04:02.
#   Batch 2,600  of  4,638.    Elapsed: 0:04:06.
#   Batch 2,640  of  4,638.    Elapsed: 0:04:09.
#   Batch 2,680  of  4,638.    Elapsed: 0:04:13.
#   Batch 2,720  of  4,638.    Elapsed: 0:04:17.
#   Batch 2,760  of  4,638.    Elapsed: 0:04:21.
#   Batch 2,800  of  4,638.    Elapsed: 0:04:24.
#   Batch 2,840  of  4,638.    Elapsed: 0:04:28.
#   Batch 2,880  of  4,638.    Elapsed: 0:04:32.
#   Batch 2,920  of  4,638.    Elapsed: 0:04:36.
#   Batch 2,960  of  4,638.    Elapsed: 0:04:40.
#   Batch 3,000  of  4,638.    Elapsed: 0:04:43.
#   Batch 3,040  of  4,638.    Elapsed: 0:04:47.
#   Batch 3,080  of  4,638.    Elapsed: 0:04:51.
#   Batch 3,120  of  4,638.    Elapsed: 0:04:55.
#   Batch 3,160  of  4,638.    Elapsed: 0:04:58.
#   Batch 3,200  of  4,638.    Elapsed: 0:05:02.
#   Batch 3,240  of  4,638.    Elapsed: 0:05:06.
#   Batch 3,280  of  4,638.    Elapsed: 0:05:10.
#   Batch 3,320  of  4,638.    Elapsed: 0:05:14.
#   Batch 3,360  of  4,638.    Elapsed: 0:05:17.
#   Batch 3,400  of  4,638.    Elapsed: 0:05:21.
#   Batch 3,440  of  4,638.    Elapsed: 0:05:25.
#   Batch 3,480  of  4,638.    Elapsed: 0:05:29.
#   Batch 3,520  of  4,638.    Elapsed: 0:05:32.
#   Batch 3,560  of  4,638.    Elapsed: 0:05:36.
#   Batch 3,600  of  4,638.    Elapsed: 0:05:40.
#   Batch 3,640  of  4,638.    Elapsed: 0:05:44.
#   Batch 3,680  of  4,638.    Elapsed: 0:05:48.
#   Batch 3,720  of  4,638.    Elapsed: 0:05:51.
#   Batch 3,760  of  4,638.    Elapsed: 0:05:55.
#   Batch 3,800  of  4,638.    Elapsed: 0:05:59.
#   Batch 3,840  of  4,638.    Elapsed: 0:06:03.
#   Batch 3,880  of  4,638.    Elapsed: 0:06:06.
#   Batch 3,920  of  4,638.    Elapsed: 0:06:10.
#   Batch 3,960  of  4,638.    Elapsed: 0:06:14.
#   Batch 4,000  of  4,638.    Elapsed: 0:06:18.
#   Batch 4,040  of  4,638.    Elapsed: 0:06:22.
#   Batch 4,080  of  4,638.    Elapsed: 0:06:25.
#   Batch 4,120  of  4,638.    Elapsed: 0:06:29.
#   Batch 4,160  of  4,638.    Elapsed: 0:06:33.
#   Batch 4,200  of  4,638.    Elapsed: 0:06:37.
#   Batch 4,240  of  4,638.    Elapsed: 0:06:41.
#   Batch 4,280  of  4,638.    Elapsed: 0:06:44.
#   Batch 4,320  of  4,638.    Elapsed: 0:06:48.
#   Batch 4,360  of  4,638.    Elapsed: 0:06:52.
#   Batch 4,400  of  4,638.    Elapsed: 0:06:56.
#   Batch 4,440  of  4,638.    Elapsed: 0:06:59.
#   Batch 4,480  of  4,638.    Elapsed: 0:07:03.
#   Batch 4,520  of  4,638.    Elapsed: 0:07:07.
#   Batch 4,560  of  4,638.    Elapsed: 0:07:11.
#   Batch 4,600  of  4,638.    Elapsed: 0:07:14.
#
#   Average training loss: 0.35
#   Average training accuracy: 0.85
#   Training epcoh took: 0:07:18
#
# Running Validation...
#   Accuracy: 0.83
#   Validation Loss: 0.38
#   Validation took: 0:00:35
#
# Training complete!
# Total training took 0:15:47 (h:mm:ss)
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83     21197
#            1       0.83      0.83      0.83     21199
#
#     accuracy                           0.83     42396
#    macro avg       0.83      0.83      0.83     42396
# weighted avg       0.83      0.83      0.83     42396

# %%
model2 = get_model(resize_embeddings=True)
epochs = 2

optimizer = AdamW(model2.parameters(), lr = 1e-5, eps = 1e-8)
total_steps = len(train_dataloader_clean2) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps = 0, num_training_steps = total_steps)
results2 = train_and_validate(model2, train_dataloader_clean2, validation_dataloader_clean2, optimizer, scheduler, device, epochs)
y_true2, y_pred2, y_proba2 = extract_metrics(model2, validation_dataloader_clean2, device)
print(classification_report(y_true2, y_pred2))
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# ======== Epoch 1 / 2 ========
# Training...
#   Batch    40  of  4,638.    Elapsed: 0:00:04.
#   Batch    80  of  4,638.    Elapsed: 0:00:08.
#   Batch   120  of  4,638.    Elapsed: 0:00:12.
#   Batch   160  of  4,638.    Elapsed: 0:00:16.
#   Batch   200  of  4,638.    Elapsed: 0:00:20.
#   Batch   240  of  4,638.    Elapsed: 0:00:24.
#   Batch   280  of  4,638.    Elapsed: 0:00:28.
#   Batch   320  of  4,638.    Elapsed: 0:00:31.
#   Batch   360  of  4,638.    Elapsed: 0:00:35.
#   Batch   400  of  4,638.    Elapsed: 0:00:39.
#   Batch   440  of  4,638.    Elapsed: 0:00:43.
#   Batch   480  of  4,638.    Elapsed: 0:00:47.
#   Batch   520  of  4,638.    Elapsed: 0:00:51.
#   Batch   560  of  4,638.    Elapsed: 0:00:55.
#   Batch   600  of  4,638.    Elapsed: 0:00:59.
#   Batch   640  of  4,638.    Elapsed: 0:01:03.
#   Batch   680  of  4,638.    Elapsed: 0:01:07.
#   Batch   720  of  4,638.    Elapsed: 0:01:11.
#   Batch   760  of  4,638.    Elapsed: 0:01:15.
#   Batch   800  of  4,638.    Elapsed: 0:01:19.
#   Batch   840  of  4,638.    Elapsed: 0:01:23.
#   Batch   880  of  4,638.    Elapsed: 0:01:27.
#   Batch   920  of  4,638.    Elapsed: 0:01:31.
#   Batch   960  of  4,638.    Elapsed: 0:01:34.
#   Batch 1,000  of  4,638.    Elapsed: 0:01:38.
#   Batch 1,040  of  4,638.    Elapsed: 0:01:42.
#   Batch 1,080  of  4,638.    Elapsed: 0:01:46.
#   Batch 1,120  of  4,638.    Elapsed: 0:01:50.
#   Batch 1,160  of  4,638.    Elapsed: 0:01:54.
#   Batch 1,200  of  4,638.    Elapsed: 0:01:58.
#   Batch 1,240  of  4,638.    Elapsed: 0:02:02.
#   Batch 1,280  of  4,638.    Elapsed: 0:02:06.
#   Batch 1,320  of  4,638.    Elapsed: 0:02:10.
#   Batch 1,360  of  4,638.    Elapsed: 0:02:14.
#   Batch 1,400  of  4,638.    Elapsed: 0:02:18.
#   Batch 1,440  of  4,638.    Elapsed: 0:02:22.
#   Batch 1,480  of  4,638.    Elapsed: 0:02:26.
#   Batch 1,520  of  4,638.    Elapsed: 0:02:30.
#   Batch 1,560  of  4,638.    Elapsed: 0:02:34.
#   Batch 1,600  of  4,638.    Elapsed: 0:02:37.
#   Batch 1,640  of  4,638.    Elapsed: 0:02:41.
#   Batch 1,680  of  4,638.    Elapsed: 0:02:45.
#   Batch 1,720  of  4,638.    Elapsed: 0:02:49.
#   Batch 1,760  of  4,638.    Elapsed: 0:02:53.
#   Batch 1,800  of  4,638.    Elapsed: 0:02:57.
#   Batch 1,840  of  4,638.    Elapsed: 0:03:01.
#   Batch 1,880  of  4,638.    Elapsed: 0:03:05.
#   Batch 1,920  of  4,638.    Elapsed: 0:03:09.
#   Batch 1,960  of  4,638.    Elapsed: 0:03:13.
#   Batch 2,000  of  4,638.    Elapsed: 0:03:17.
#   Batch 2,040  of  4,638.    Elapsed: 0:03:21.
#   Batch 2,080  of  4,638.    Elapsed: 0:03:25.
#   Batch 2,120  of  4,638.    Elapsed: 0:03:29.
#   Batch 2,160  of  4,638.    Elapsed: 0:03:33.
#   Batch 2,200  of  4,638.    Elapsed: 0:03:37.
#   Batch 2,240  of  4,638.    Elapsed: 0:03:40.
#   Batch 2,280  of  4,638.    Elapsed: 0:03:44.
#   Batch 2,320  of  4,638.    Elapsed: 0:03:48.
#   Batch 2,360  of  4,638.    Elapsed: 0:03:52.
#   Batch 2,400  of  4,638.    Elapsed: 0:03:56.
#   Batch 2,440  of  4,638.    Elapsed: 0:04:00.
#   Batch 2,480  of  4,638.    Elapsed: 0:04:04.
#   Batch 2,520  of  4,638.    Elapsed: 0:04:08.
#   Batch 2,560  of  4,638.    Elapsed: 0:04:12.
#   Batch 2,600  of  4,638.    Elapsed: 0:04:16.
#   Batch 2,640  of  4,638.    Elapsed: 0:04:20.
#   Batch 2,680  of  4,638.    Elapsed: 0:04:24.
#   Batch 2,720  of  4,638.    Elapsed: 0:04:28.
#   Batch 2,760  of  4,638.    Elapsed: 0:04:32.
#   Batch 2,800  of  4,638.    Elapsed: 0:04:36.
#   Batch 2,840  of  4,638.    Elapsed: 0:04:40.
#   Batch 2,880  of  4,638.    Elapsed: 0:04:44.
#   Batch 2,920  of  4,638.    Elapsed: 0:04:47.
#   Batch 2,960  of  4,638.    Elapsed: 0:04:51.
#   Batch 3,000  of  4,638.    Elapsed: 0:04:55.
#   Batch 3,040  of  4,638.    Elapsed: 0:04:59.
#   Batch 3,080  of  4,638.    Elapsed: 0:05:03.
#   Batch 3,120  of  4,638.    Elapsed: 0:05:07.
#   Batch 3,160  of  4,638.    Elapsed: 0:05:11.
#   Batch 3,200  of  4,638.    Elapsed: 0:05:15.
#   Batch 3,240  of  4,638.    Elapsed: 0:05:19.
#   Batch 3,280  of  4,638.    Elapsed: 0:05:23.
#   Batch 3,320  of  4,638.    Elapsed: 0:05:27.
#   Batch 3,360  of  4,638.    Elapsed: 0:05:31.
#   Batch 3,400  of  4,638.    Elapsed: 0:05:35.
#   Batch 3,440  of  4,638.    Elapsed: 0:05:39.
#   Batch 3,480  of  4,638.    Elapsed: 0:05:43.
#   Batch 3,520  of  4,638.    Elapsed: 0:05:47.
#   Batch 3,560  of  4,638.    Elapsed: 0:05:50.
#   Batch 3,600  of  4,638.    Elapsed: 0:05:54.
#   Batch 3,640  of  4,638.    Elapsed: 0:05:58.
#   Batch 3,680  of  4,638.    Elapsed: 0:06:02.
#   Batch 3,720  of  4,638.    Elapsed: 0:06:06.
#   Batch 3,760  of  4,638.    Elapsed: 0:06:10.
#   Batch 3,800  of  4,638.    Elapsed: 0:06:14.
#   Batch 3,840  of  4,638.    Elapsed: 0:06:18.
#   Batch 3,880  of  4,638.    Elapsed: 0:06:22.
#   Batch 3,920  of  4,638.    Elapsed: 0:06:26.
#   Batch 3,960  of  4,638.    Elapsed: 0:06:30.
#   Batch 4,000  of  4,638.    Elapsed: 0:06:34.
#   Batch 4,040  of  4,638.    Elapsed: 0:06:38.
#   Batch 4,080  of  4,638.    Elapsed: 0:06:42.
#   Batch 4,120  of  4,638.    Elapsed: 0:06:46.
#   Batch 4,160  of  4,638.    Elapsed: 0:06:50.
#   Batch 4,200  of  4,638.    Elapsed: 0:06:53.
#   Batch 4,240  of  4,638.    Elapsed: 0:06:57.
#   Batch 4,280  of  4,638.    Elapsed: 0:07:01.
#   Batch 4,320  of  4,638.    Elapsed: 0:07:05.
#   Batch 4,360  of  4,638.    Elapsed: 0:07:09.
#   Batch 4,400  of  4,638.    Elapsed: 0:07:13.
#   Batch 4,440  of  4,638.    Elapsed: 0:07:17.
#   Batch 4,480  of  4,638.    Elapsed: 0:07:21.
#   Batch 4,520  of  4,638.    Elapsed: 0:07:25.
#   Batch 4,560  of  4,638.    Elapsed: 0:07:29.
#   Batch 4,600  of  4,638.    Elapsed: 0:07:33.
#
#   Average training loss: 0.40
#   Average training accuracy: 0.82
#   Training epcoh took: 0:07:37
#
# Running Validation...
#   Accuracy: 0.84
#   Validation Loss: 0.36
#   Validation took: 0:00:36
#
# ======== Epoch 2 / 2 ========
# Training...
#   Batch    40  of  4,638.    Elapsed: 0:00:04.
#   Batch    80  of  4,638.    Elapsed: 0:00:08.
#   Batch   120  of  4,638.    Elapsed: 0:00:12.
#   Batch   160  of  4,638.    Elapsed: 0:00:16.
#   Batch   200  of  4,638.    Elapsed: 0:00:20.
#   Batch   240  of  4,638.    Elapsed: 0:00:24.
#   Batch   280  of  4,638.    Elapsed: 0:00:28.
#   Batch   320  of  4,638.    Elapsed: 0:00:31.
#   Batch   360  of  4,638.    Elapsed: 0:00:35.
#   Batch   400  of  4,638.    Elapsed: 0:00:39.
#   Batch   440  of  4,638.    Elapsed: 0:00:43.
#   Batch   480  of  4,638.    Elapsed: 0:00:47.
#   Batch   520  of  4,638.    Elapsed: 0:00:51.
#   Batch   560  of  4,638.    Elapsed: 0:00:55.
#   Batch   600  of  4,638.    Elapsed: 0:00:59.
#   Batch   640  of  4,638.    Elapsed: 0:01:03.
#   Batch   680  of  4,638.    Elapsed: 0:01:07.
#   Batch   720  of  4,638.    Elapsed: 0:01:11.
#   Batch   760  of  4,638.    Elapsed: 0:01:15.
#   Batch   800  of  4,638.    Elapsed: 0:01:19.
#   Batch   840  of  4,638.    Elapsed: 0:01:23.
#   Batch   880  of  4,638.    Elapsed: 0:01:27.
#   Batch   920  of  4,638.    Elapsed: 0:01:31.
#   Batch   960  of  4,638.    Elapsed: 0:01:34.
#   Batch 1,000  of  4,638.    Elapsed: 0:01:38.
#   Batch 1,040  of  4,638.    Elapsed: 0:01:42.
#   Batch 1,080  of  4,638.    Elapsed: 0:01:46.
#   Batch 1,120  of  4,638.    Elapsed: 0:01:50.
#   Batch 1,160  of  4,638.    Elapsed: 0:01:54.
#   Batch 1,200  of  4,638.    Elapsed: 0:01:58.
#   Batch 1,240  of  4,638.    Elapsed: 0:02:02.
#   Batch 1,280  of  4,638.    Elapsed: 0:02:06.
#   Batch 1,320  of  4,638.    Elapsed: 0:02:10.
#   Batch 1,360  of  4,638.    Elapsed: 0:02:14.
#   Batch 1,400  of  4,638.    Elapsed: 0:02:18.
#   Batch 1,440  of  4,638.    Elapsed: 0:02:22.
#   Batch 1,480  of  4,638.    Elapsed: 0:02:26.
#   Batch 1,520  of  4,638.    Elapsed: 0:02:30.
#   Batch 1,560  of  4,638.    Elapsed: 0:02:34.
#   Batch 1,600  of  4,638.    Elapsed: 0:02:37.
#   Batch 1,640  of  4,638.    Elapsed: 0:02:41.
#   Batch 1,680  of  4,638.    Elapsed: 0:02:45.
#   Batch 1,720  of  4,638.    Elapsed: 0:02:49.
#   Batch 1,760  of  4,638.    Elapsed: 0:02:53.
#   Batch 1,800  of  4,638.    Elapsed: 0:02:57.
#   Batch 1,840  of  4,638.    Elapsed: 0:03:01.
#   Batch 1,880  of  4,638.    Elapsed: 0:03:05.
#   Batch 1,920  of  4,638.    Elapsed: 0:03:09.
#   Batch 1,960  of  4,638.    Elapsed: 0:03:13.
#   Batch 2,000  of  4,638.    Elapsed: 0:03:17.
#   Batch 2,040  of  4,638.    Elapsed: 0:03:21.
#   Batch 2,080  of  4,638.    Elapsed: 0:03:25.
#   Batch 2,120  of  4,638.    Elapsed: 0:03:29.
#   Batch 2,160  of  4,638.    Elapsed: 0:03:33.
#   Batch 2,200  of  4,638.    Elapsed: 0:03:37.
#   Batch 2,240  of  4,638.    Elapsed: 0:03:40.
#   Batch 2,280  of  4,638.    Elapsed: 0:03:44.
#   Batch 2,320  of  4,638.    Elapsed: 0:03:48.
#   Batch 2,360  of  4,638.    Elapsed: 0:03:52.
#   Batch 2,400  of  4,638.    Elapsed: 0:03:56.
#   Batch 2,440  of  4,638.    Elapsed: 0:04:00.
#   Batch 2,480  of  4,638.    Elapsed: 0:04:04.
#   Batch 2,520  of  4,638.    Elapsed: 0:04:08.
#   Batch 2,560  of  4,638.    Elapsed: 0:04:12.
#   Batch 2,600  of  4,638.    Elapsed: 0:04:16.
#   Batch 2,640  of  4,638.    Elapsed: 0:04:20.
#   Batch 2,680  of  4,638.    Elapsed: 0:04:24.
#   Batch 2,720  of  4,638.    Elapsed: 0:04:28.
#   Batch 2,760  of  4,638.    Elapsed: 0:04:32.
#   Batch 2,800  of  4,638.    Elapsed: 0:04:36.
#   Batch 2,840  of  4,638.    Elapsed: 0:04:40.
#   Batch 2,880  of  4,638.    Elapsed: 0:04:43.
#   Batch 2,920  of  4,638.    Elapsed: 0:04:47.
#   Batch 2,960  of  4,638.    Elapsed: 0:04:51.
#   Batch 3,000  of  4,638.    Elapsed: 0:04:55.
#   Batch 3,040  of  4,638.    Elapsed: 0:04:59.
#   Batch 3,080  of  4,638.    Elapsed: 0:05:03.
#   Batch 3,120  of  4,638.    Elapsed: 0:05:07.
#   Batch 3,160  of  4,638.    Elapsed: 0:05:11.
#   Batch 3,200  of  4,638.    Elapsed: 0:05:15.
#   Batch 3,240  of  4,638.    Elapsed: 0:05:19.
#   Batch 3,280  of  4,638.    Elapsed: 0:05:23.
#   Batch 3,320  of  4,638.    Elapsed: 0:05:27.
#   Batch 3,360  of  4,638.    Elapsed: 0:05:31.
#   Batch 3,400  of  4,638.    Elapsed: 0:05:35.
#   Batch 3,440  of  4,638.    Elapsed: 0:05:39.
#   Batch 3,480  of  4,638.    Elapsed: 0:05:43.
#   Batch 3,520  of  4,638.    Elapsed: 0:05:47.
#   Batch 3,560  of  4,638.    Elapsed: 0:05:50.
#   Batch 3,600  of  4,638.    Elapsed: 0:05:54.
#   Batch 3,640  of  4,638.    Elapsed: 0:05:58.
#   Batch 3,680  of  4,638.    Elapsed: 0:06:02.
#   Batch 3,720  of  4,638.    Elapsed: 0:06:06.
#   Batch 3,760  of  4,638.    Elapsed: 0:06:10.
#   Batch 3,800  of  4,638.    Elapsed: 0:06:14.
#   Batch 3,840  of  4,638.    Elapsed: 0:06:18.
#   Batch 3,880  of  4,638.    Elapsed: 0:06:22.
#   Batch 3,920  of  4,638.    Elapsed: 0:06:26.
#   Batch 3,960  of  4,638.    Elapsed: 0:06:30.
#   Batch 4,000  of  4,638.    Elapsed: 0:06:34.
#   Batch 4,040  of  4,638.    Elapsed: 0:06:38.
#   Batch 4,080  of  4,638.    Elapsed: 0:06:42.
#   Batch 4,120  of  4,638.    Elapsed: 0:06:46.
#   Batch 4,160  of  4,638.    Elapsed: 0:06:50.
#   Batch 4,200  of  4,638.    Elapsed: 0:06:54.
#   Batch 4,240  of  4,638.    Elapsed: 0:06:57.
#   Batch 4,280  of  4,638.    Elapsed: 0:07:01.
#   Batch 4,320  of  4,638.    Elapsed: 0:07:05.
#   Batch 4,360  of  4,638.    Elapsed: 0:07:09.
#   Batch 4,400  of  4,638.    Elapsed: 0:07:13.
#   Batch 4,440  of  4,638.    Elapsed: 0:07:17.
#   Batch 4,480  of  4,638.    Elapsed: 0:07:21.
#   Batch 4,520  of  4,638.    Elapsed: 0:07:25.
#   Batch 4,560  of  4,638.    Elapsed: 0:07:29.
#   Batch 4,600  of  4,638.    Elapsed: 0:07:33.
#
#   Average training loss: 0.33
#   Average training accuracy: 0.86
#   Training epcoh took: 0:07:37
#
# Running Validation...
#   Accuracy: 0.85
#   Validation Loss: 0.36
#   Validation took: 0:00:36
#
# Training complete!
# Total training took 0:16:24 (h:mm:ss)
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85     21197
#            1       0.85      0.84      0.84     21199
#
#     accuracy                           0.85     42396
#    macro avg       0.85      0.85      0.85     42396
# weighted avg       0.85      0.85      0.85     42396

# %%
# Define batch size
batch_size = 16

# Create DataLoaders for Tokenized_Clean2
train_dataloader_clean3 = DataLoader(train_dataset_clean2, batch_size=batch_size, shuffle=True)
validation_dataloader_clean3 = DataLoader(validation_dataset_clean2, batch_size=batch_size)
test_dataloader_clean3 = DataLoader(test_dataset_clean2, batch_size=batch_size)

# %%
model3 = get_model(resize_embeddings=True)
epochs = 2

optimizer = AdamW(model3.parameters(), lr = 1e-5, eps = 1e-8)
total_steps = len(train_dataloader_clean3) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps = 0, num_training_steps = total_steps)
results3 = train_and_validate(model3, train_dataloader_clean3, validation_dataloader_clean3, optimizer, scheduler, device, epochs)
y_true3, y_pred3, y_proba3 = extract_metrics(model3, validation_dataloader_clean3, device)
print(classification_report(y_true3, y_pred3))
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ======== Epoch 1 / 2 ========
# Training...
#   Batch    40  of  9,275.    Elapsed: 0:00:02.
#   Batch    80  of  9,275.    Elapsed: 0:00:05.
#   Batch   120  of  9,275.    Elapsed: 0:00:07.
#   Batch   160  of  9,275.    Elapsed: 0:00:10.
#   Batch   200  of  9,275.    Elapsed: 0:00:12.
#   Batch   240  of  9,275.    Elapsed: 0:00:14.
#   Batch   280  of  9,275.    Elapsed: 0:00:17.
#   Batch   320  of  9,275.    Elapsed: 0:00:19.
#   Batch   360  of  9,275.    Elapsed: 0:00:21.
#   Batch   400  of  9,275.    Elapsed: 0:00:24.
#   Batch   440  of  9,275.    Elapsed: 0:00:26.
#   Batch   480  of  9,275.    Elapsed: 0:00:29.
#   Batch   520  of  9,275.    Elapsed: 0:00:31.
#   Batch   560  of  9,275.    Elapsed: 0:00:33.
#   Batch   600  of  9,275.    Elapsed: 0:00:36.
#   Batch   640  of  9,275.    Elapsed: 0:00:38.
#   Batch   680  of  9,275.    Elapsed: 0:00:41.
#   Batch   720  of  9,275.    Elapsed: 0:00:43.
#   Batch   760  of  9,275.    Elapsed: 0:00:45.
#   Batch   800  of  9,275.    Elapsed: 0:00:48.
#   Batch   840  of  9,275.    Elapsed: 0:00:50.
#   Batch   880  of  9,275.    Elapsed: 0:00:52.
#   Batch   920  of  9,275.    Elapsed: 0:00:55.
#   Batch   960  of  9,275.    Elapsed: 0:00:57.
#   Batch 1,000  of  9,275.    Elapsed: 0:01:00.
#   Batch 1,040  of  9,275.    Elapsed: 0:01:02.
#   Batch 1,080  of  9,275.    Elapsed: 0:01:04.
#   Batch 1,120  of  9,275.    Elapsed: 0:01:07.
#   Batch 1,160  of  9,275.    Elapsed: 0:01:09.
#   Batch 1,200  of  9,275.    Elapsed: 0:01:12.
#   Batch 1,240  of  9,275.    Elapsed: 0:01:14.
#   Batch 1,280  of  9,275.    Elapsed: 0:01:16.
#   Batch 1,320  of  9,275.    Elapsed: 0:01:19.
#   Batch 1,360  of  9,275.    Elapsed: 0:01:21.
#   Batch 1,400  of  9,275.    Elapsed: 0:01:23.
#   Batch 1,440  of  9,275.    Elapsed: 0:01:26.
#   Batch 1,480  of  9,275.    Elapsed: 0:01:28.
#   Batch 1,520  of  9,275.    Elapsed: 0:01:31.
#   Batch 1,560  of  9,275.    Elapsed: 0:01:33.
#   Batch 1,600  of  9,275.    Elapsed: 0:01:35.
#   Batch 1,640  of  9,275.    Elapsed: 0:01:38.
#   Batch 1,680  of  9,275.    Elapsed: 0:01:40.
#   Batch 1,720  of  9,275.    Elapsed: 0:01:43.
#   Batch 1,760  of  9,275.    Elapsed: 0:01:45.
#   Batch 1,800  of  9,275.    Elapsed: 0:01:47.
#   Batch 1,840  of  9,275.    Elapsed: 0:01:50.
#   Batch 1,880  of  9,275.    Elapsed: 0:01:52.
#   Batch 1,920  of  9,275.    Elapsed: 0:01:54.
#   Batch 1,960  of  9,275.    Elapsed: 0:01:57.
#   Batch 2,000  of  9,275.    Elapsed: 0:01:59.
#   Batch 2,040  of  9,275.    Elapsed: 0:02:02.
#   Batch 2,080  of  9,275.    Elapsed: 0:02:04.
#   Batch 2,120  of  9,275.    Elapsed: 0:02:06.
#   Batch 2,160  of  9,275.    Elapsed: 0:02:09.
#   Batch 2,200  of  9,275.    Elapsed: 0:02:11.
#   Batch 2,240  of  9,275.    Elapsed: 0:02:14.
#   Batch 2,280  of  9,275.    Elapsed: 0:02:16.
#   Batch 2,320  of  9,275.    Elapsed: 0:02:18.
#   Batch 2,360  of  9,275.    Elapsed: 0:02:21.
#   Batch 2,400  of  9,275.    Elapsed: 0:02:23.
#   Batch 2,440  of  9,275.    Elapsed: 0:02:25.
#   Batch 2,480  of  9,275.    Elapsed: 0:02:28.
#   Batch 2,520  of  9,275.    Elapsed: 0:02:30.
#   Batch 2,560  of  9,275.    Elapsed: 0:02:33.
#   Batch 2,600  of  9,275.    Elapsed: 0:02:35.
#   Batch 2,640  of  9,275.    Elapsed: 0:02:37.
#   Batch 2,680  of  9,275.    Elapsed: 0:02:40.
#   Batch 2,720  of  9,275.    Elapsed: 0:02:42.
#   Batch 2,760  of  9,275.    Elapsed: 0:02:44.
#   Batch 2,800  of  9,275.    Elapsed: 0:02:47.
#   Batch 2,840  of  9,275.    Elapsed: 0:02:49.
#   Batch 2,880  of  9,275.    Elapsed: 0:02:52.
#   Batch 2,920  of  9,275.    Elapsed: 0:02:54.
#   Batch 2,960  of  9,275.    Elapsed: 0:02:56.
#   Batch 3,000  of  9,275.    Elapsed: 0:02:59.
#   Batch 3,040  of  9,275.    Elapsed: 0:03:01.
#   Batch 3,080  of  9,275.    Elapsed: 0:03:04.
#   Batch 3,120  of  9,275.    Elapsed: 0:03:06.
#   Batch 3,160  of  9,275.    Elapsed: 0:03:08.
#   Batch 3,200  of  9,275.    Elapsed: 0:03:11.
#   Batch 3,240  of  9,275.    Elapsed: 0:03:13.
#   Batch 3,280  of  9,275.    Elapsed: 0:03:15.
#   Batch 3,320  of  9,275.    Elapsed: 0:03:18.
#   Batch 3,360  of  9,275.    Elapsed: 0:03:20.
#   Batch 3,400  of  9,275.    Elapsed: 0:03:23.
#   Batch 3,440  of  9,275.    Elapsed: 0:03:25.
#   Batch 3,480  of  9,275.    Elapsed: 0:03:27.
#   Batch 3,520  of  9,275.    Elapsed: 0:03:30.
#   Batch 3,560  of  9,275.    Elapsed: 0:03:32.
#   Batch 3,600  of  9,275.    Elapsed: 0:03:35.
#   Batch 3,640  of  9,275.    Elapsed: 0:03:37.
#   Batch 3,680  of  9,275.    Elapsed: 0:03:39.
#   Batch 3,720  of  9,275.    Elapsed: 0:03:42.
#   Batch 3,760  of  9,275.    Elapsed: 0:03:44.
#   Batch 3,800  of  9,275.    Elapsed: 0:03:46.
#   Batch 3,840  of  9,275.    Elapsed: 0:03:49.
#   Batch 3,880  of  9,275.    Elapsed: 0:03:51.
#   Batch 3,920  of  9,275.    Elapsed: 0:03:54.
#   Batch 3,960  of  9,275.    Elapsed: 0:03:56.
#   Batch 4,000  of  9,275.    Elapsed: 0:03:58.
#   Batch 4,040  of  9,275.    Elapsed: 0:04:01.
#   Batch 4,080  of  9,275.    Elapsed: 0:04:03.
#   Batch 4,120  of  9,275.    Elapsed: 0:04:06.
#   Batch 4,160  of  9,275.    Elapsed: 0:04:08.
#   Batch 4,200  of  9,275.    Elapsed: 0:04:10.
#   Batch 4,240  of  9,275.    Elapsed: 0:04:13.
#   Batch 4,280  of  9,275.    Elapsed: 0:04:15.
#   Batch 4,320  of  9,275.    Elapsed: 0:04:17.
#   Batch 4,360  of  9,275.    Elapsed: 0:04:20.
#   Batch 4,400  of  9,275.    Elapsed: 0:04:22.
#   Batch 4,440  of  9,275.    Elapsed: 0:04:25.
#   Batch 4,480  of  9,275.    Elapsed: 0:04:27.
#   Batch 4,520  of  9,275.    Elapsed: 0:04:29.
#   Batch 4,560  of  9,275.    Elapsed: 0:04:32.
#   Batch 4,600  of  9,275.    Elapsed: 0:04:34.
#   Batch 4,640  of  9,275.    Elapsed: 0:04:36.
#   Batch 4,680  of  9,275.    Elapsed: 0:04:39.
#   Batch 4,720  of  9,275.    Elapsed: 0:04:41.
#   Batch 4,760  of  9,275.    Elapsed: 0:04:44.
#   Batch 4,800  of  9,275.    Elapsed: 0:04:46.
#   Batch 4,840  of  9,275.    Elapsed: 0:04:48.
#   Batch 4,880  of  9,275.    Elapsed: 0:04:51.
#   Batch 4,920  of  9,275.    Elapsed: 0:04:53.
#   Batch 4,960  of  9,275.    Elapsed: 0:04:56.
#   Batch 5,000  of  9,275.    Elapsed: 0:04:58.
#   Batch 5,040  of  9,275.    Elapsed: 0:05:00.
#   Batch 5,080  of  9,275.    Elapsed: 0:05:03.
#   Batch 5,120  of  9,275.    Elapsed: 0:05:05.
#   Batch 5,160  of  9,275.    Elapsed: 0:05:07.
#   Batch 5,200  of  9,275.    Elapsed: 0:05:10.
#   Batch 5,240  of  9,275.    Elapsed: 0:05:12.
#   Batch 5,280  of  9,275.    Elapsed: 0:05:15.
#   Batch 5,320  of  9,275.    Elapsed: 0:05:17.
#   Batch 5,360  of  9,275.    Elapsed: 0:05:19.
#   Batch 5,400  of  9,275.    Elapsed: 0:05:22.
#   Batch 5,440  of  9,275.    Elapsed: 0:05:24.
#   Batch 5,480  of  9,275.    Elapsed: 0:05:27.
#   Batch 5,520  of  9,275.    Elapsed: 0:05:29.
#   Batch 5,560  of  9,275.    Elapsed: 0:05:31.
#   Batch 5,600  of  9,275.    Elapsed: 0:05:34.
#   Batch 5,640  of  9,275.    Elapsed: 0:05:36.
#   Batch 5,680  of  9,275.    Elapsed: 0:05:38.
#   Batch 5,720  of  9,275.    Elapsed: 0:05:41.
#   Batch 5,760  of  9,275.    Elapsed: 0:05:43.
#   Batch 5,800  of  9,275.    Elapsed: 0:05:46.
#   Batch 5,840  of  9,275.    Elapsed: 0:05:48.
#   Batch 5,880  of  9,275.    Elapsed: 0:05:50.
#   Batch 5,920  of  9,275.    Elapsed: 0:05:53.
#   Batch 5,960  of  9,275.    Elapsed: 0:05:55.
#   Batch 6,000  of  9,275.    Elapsed: 0:05:58.
#   Batch 6,040  of  9,275.    Elapsed: 0:06:00.
#   Batch 6,080  of  9,275.    Elapsed: 0:06:02.
#   Batch 6,120  of  9,275.    Elapsed: 0:06:05.
#   Batch 6,160  of  9,275.    Elapsed: 0:06:07.
#   Batch 6,200  of  9,275.    Elapsed: 0:06:09.
#   Batch 6,240  of  9,275.    Elapsed: 0:06:12.
#   Batch 6,280  of  9,275.    Elapsed: 0:06:14.
#   Batch 6,320  of  9,275.    Elapsed: 0:06:17.
#   Batch 6,360  of  9,275.    Elapsed: 0:06:19.
#   Batch 6,400  of  9,275.    Elapsed: 0:06:21.
#   Batch 6,440  of  9,275.    Elapsed: 0:06:24.
#   Batch 6,480  of  9,275.    Elapsed: 0:06:26.
#   Batch 6,520  of  9,275.    Elapsed: 0:06:29.
#   Batch 6,560  of  9,275.    Elapsed: 0:06:31.
#   Batch 6,600  of  9,275.    Elapsed: 0:06:33.
#   Batch 6,640  of  9,275.    Elapsed: 0:06:36.
#   Batch 6,680  of  9,275.    Elapsed: 0:06:38.
#   Batch 6,720  of  9,275.    Elapsed: 0:06:41.
#   Batch 6,760  of  9,275.    Elapsed: 0:06:43.
#   Batch 6,800  of  9,275.    Elapsed: 0:06:45.
#   Batch 6,840  of  9,275.    Elapsed: 0:06:48.
#   Batch 6,880  of  9,275.    Elapsed: 0:06:50.
#   Batch 6,920  of  9,275.    Elapsed: 0:06:52.
#   Batch 6,960  of  9,275.    Elapsed: 0:06:55.
#   Batch 7,000  of  9,275.    Elapsed: 0:06:57.
#   Batch 7,040  of  9,275.    Elapsed: 0:07:00.
#   Batch 7,080  of  9,275.    Elapsed: 0:07:02.
#   Batch 7,120  of  9,275.    Elapsed: 0:07:04.
#   Batch 7,160  of  9,275.    Elapsed: 0:07:07.
#   Batch 7,200  of  9,275.    Elapsed: 0:07:09.
#   Batch 7,240  of  9,275.    Elapsed: 0:07:12.
#   Batch 7,280  of  9,275.    Elapsed: 0:07:14.
#   Batch 7,320  of  9,275.    Elapsed: 0:07:16.
#   Batch 7,360  of  9,275.    Elapsed: 0:07:19.
#   Batch 7,400  of  9,275.    Elapsed: 0:07:21.
#   Batch 7,440  of  9,275.    Elapsed: 0:07:24.
#   Batch 7,480  of  9,275.    Elapsed: 0:07:26.
#   Batch 7,520  of  9,275.    Elapsed: 0:07:28.
#   Batch 7,560  of  9,275.    Elapsed: 0:07:31.
#   Batch 7,600  of  9,275.    Elapsed: 0:07:33.
#   Batch 7,640  of  9,275.    Elapsed: 0:07:36.
#   Batch 7,680  of  9,275.    Elapsed: 0:07:38.
#   Batch 7,720  of  9,275.    Elapsed: 0:07:40.
#   Batch 7,760  of  9,275.    Elapsed: 0:07:43.
#   Batch 7,800  of  9,275.    Elapsed: 0:07:45.
#   Batch 7,840  of  9,275.    Elapsed: 0:07:48.
#   Batch 7,880  of  9,275.    Elapsed: 0:07:50.
#   Batch 7,920  of  9,275.    Elapsed: 0:07:52.
#   Batch 7,960  of  9,275.    Elapsed: 0:07:55.
#   Batch 8,000  of  9,275.    Elapsed: 0:07:57.
#   Batch 8,040  of  9,275.    Elapsed: 0:08:00.
#   Batch 8,080  of  9,275.    Elapsed: 0:08:02.
#   Batch 8,120  of  9,275.    Elapsed: 0:08:04.
#   Batch 8,160  of  9,275.    Elapsed: 0:08:07.
#   Batch 8,200  of  9,275.    Elapsed: 0:08:09.
#   Batch 8,240  of  9,275.    Elapsed: 0:08:12.
#   Batch 8,280  of  9,275.    Elapsed: 0:08:14.
#   Batch 8,320  of  9,275.    Elapsed: 0:08:16.
#   Batch 8,360  of  9,275.    Elapsed: 0:08:19.
#   Batch 8,400  of  9,275.    Elapsed: 0:08:21.
#   Batch 8,440  of  9,275.    Elapsed: 0:08:23.
#   Batch 8,480  of  9,275.    Elapsed: 0:08:26.
#   Batch 8,520  of  9,275.    Elapsed: 0:08:28.
#   Batch 8,560  of  9,275.    Elapsed: 0:08:31.
#   Batch 8,600  of  9,275.    Elapsed: 0:08:33.
#   Batch 8,640  of  9,275.    Elapsed: 0:08:35.
#   Batch 8,680  of  9,275.    Elapsed: 0:08:38.
#   Batch 8,720  of  9,275.    Elapsed: 0:08:40.
#   Batch 8,760  of  9,275.    Elapsed: 0:08:43.
#   Batch 8,800  of  9,275.    Elapsed: 0:08:45.
#   Batch 8,840  of  9,275.    Elapsed: 0:08:47.
#   Batch 8,880  of  9,275.    Elapsed: 0:08:50.
#   Batch 8,920  of  9,275.    Elapsed: 0:08:52.
#   Batch 8,960  of  9,275.    Elapsed: 0:08:55.
#   Batch 9,000  of  9,275.    Elapsed: 0:08:57.
#   Batch 9,040  of  9,275.    Elapsed: 0:08:59.
#   Batch 9,080  of  9,275.    Elapsed: 0:09:02.
#   Batch 9,120  of  9,275.    Elapsed: 0:09:04.
#   Batch 9,160  of  9,275.    Elapsed: 0:09:07.
#   Batch 9,200  of  9,275.    Elapsed: 0:09:09.
#   Batch 9,240  of  9,275.    Elapsed: 0:09:11.
#
#   Average training loss: 0.40
#   Average training accuracy: 0.82
#   Training epcoh took: 0:09:13
#
# Running Validation...
#   Accuracy: 0.84
#   Validation Loss: 0.36
#   Validation took: 0:00:41
#
# ======== Epoch 2 / 2 ========
# Training...
#   Batch    40  of  9,275.    Elapsed: 0:00:02.
#   Batch    80  of  9,275.    Elapsed: 0:00:05.
#   Batch   120  of  9,275.    Elapsed: 0:00:07.
#   Batch   160  of  9,275.    Elapsed: 0:00:10.
#   Batch   200  of  9,275.    Elapsed: 0:00:12.
#   Batch   240  of  9,275.    Elapsed: 0:00:14.
#   Batch   280  of  9,275.    Elapsed: 0:00:17.
#   Batch   320  of  9,275.    Elapsed: 0:00:19.
#   Batch   360  of  9,275.    Elapsed: 0:00:22.
#   Batch   400  of  9,275.    Elapsed: 0:00:24.
#   Batch   440  of  9,275.    Elapsed: 0:00:26.
#   Batch   480  of  9,275.    Elapsed: 0:00:29.
#   Batch   520  of  9,275.    Elapsed: 0:00:31.
#   Batch   560  of  9,275.    Elapsed: 0:00:33.
#   Batch   600  of  9,275.    Elapsed: 0:00:36.
#   Batch   640  of  9,275.    Elapsed: 0:00:38.
#   Batch   680  of  9,275.    Elapsed: 0:00:41.
#   Batch   720  of  9,275.    Elapsed: 0:00:43.
#   Batch   760  of  9,275.    Elapsed: 0:00:45.
#   Batch   800  of  9,275.    Elapsed: 0:00:48.
#   Batch   840  of  9,275.    Elapsed: 0:00:50.
#   Batch   880  of  9,275.    Elapsed: 0:00:53.
#   Batch   920  of  9,275.    Elapsed: 0:00:55.
#   Batch   960  of  9,275.    Elapsed: 0:00:57.
#   Batch 1,000  of  9,275.    Elapsed: 0:01:00.
#   Batch 1,040  of  9,275.    Elapsed: 0:01:02.
#   Batch 1,080  of  9,275.    Elapsed: 0:01:05.
#   Batch 1,120  of  9,275.    Elapsed: 0:01:07.
#   Batch 1,160  of  9,275.    Elapsed: 0:01:09.
#   Batch 1,200  of  9,275.    Elapsed: 0:01:12.
#   Batch 1,240  of  9,275.    Elapsed: 0:01:14.
#   Batch 1,280  of  9,275.    Elapsed: 0:01:17.
#   Batch 1,320  of  9,275.    Elapsed: 0:01:19.
#   Batch 1,360  of  9,275.    Elapsed: 0:01:21.
#   Batch 1,400  of  9,275.    Elapsed: 0:01:24.
#   Batch 1,440  of  9,275.    Elapsed: 0:01:26.
#   Batch 1,480  of  9,275.    Elapsed: 0:01:28.
#   Batch 1,520  of  9,275.    Elapsed: 0:01:31.
#   Batch 1,560  of  9,275.    Elapsed: 0:01:33.
#   Batch 1,600  of  9,275.    Elapsed: 0:01:36.
#   Batch 1,640  of  9,275.    Elapsed: 0:01:38.
#   Batch 1,680  of  9,275.    Elapsed: 0:01:40.
#   Batch 1,720  of  9,275.    Elapsed: 0:01:43.
#   Batch 1,760  of  9,275.    Elapsed: 0:01:45.
#   Batch 1,800  of  9,275.    Elapsed: 0:01:48.
#   Batch 1,840  of  9,275.    Elapsed: 0:01:50.
#   Batch 1,880  of  9,275.    Elapsed: 0:01:52.
#   Batch 1,920  of  9,275.    Elapsed: 0:01:55.
#   Batch 1,960  of  9,275.    Elapsed: 0:01:57.
#   Batch 2,000  of  9,275.    Elapsed: 0:02:00.
#   Batch 2,040  of  9,275.    Elapsed: 0:02:02.
#   Batch 2,080  of  9,275.    Elapsed: 0:02:04.
#   Batch 2,120  of  9,275.    Elapsed: 0:02:07.
#   Batch 2,160  of  9,275.    Elapsed: 0:02:09.
#   Batch 2,200  of  9,275.    Elapsed: 0:02:12.
#   Batch 2,240  of  9,275.    Elapsed: 0:02:14.
#   Batch 2,280  of  9,275.    Elapsed: 0:02:16.
#   Batch 2,320  of  9,275.    Elapsed: 0:02:19.
#   Batch 2,360  of  9,275.    Elapsed: 0:02:21.
#   Batch 2,400  of  9,275.    Elapsed: 0:02:24.
#   Batch 2,440  of  9,275.    Elapsed: 0:02:26.
#   Batch 2,480  of  9,275.    Elapsed: 0:02:28.
#   Batch 2,520  of  9,275.    Elapsed: 0:02:31.
#   Batch 2,560  of  9,275.    Elapsed: 0:02:33.
#   Batch 2,600  of  9,275.    Elapsed: 0:02:36.
#   Batch 2,640  of  9,275.    Elapsed: 0:02:38.
#   Batch 2,680  of  9,275.    Elapsed: 0:02:40.
#   Batch 2,720  of  9,275.    Elapsed: 0:02:43.
#   Batch 2,760  of  9,275.    Elapsed: 0:02:45.
#   Batch 2,800  of  9,275.    Elapsed: 0:02:47.
#   Batch 2,840  of  9,275.    Elapsed: 0:02:50.
#   Batch 2,880  of  9,275.    Elapsed: 0:02:52.
#   Batch 2,920  of  9,275.    Elapsed: 0:02:55.
#   Batch 2,960  of  9,275.    Elapsed: 0:02:57.
#   Batch 3,000  of  9,275.    Elapsed: 0:02:59.
#   Batch 3,040  of  9,275.    Elapsed: 0:03:02.
#   Batch 3,080  of  9,275.    Elapsed: 0:03:04.
#   Batch 3,120  of  9,275.    Elapsed: 0:03:07.
#   Batch 3,160  of  9,275.    Elapsed: 0:03:09.
#   Batch 3,200  of  9,275.    Elapsed: 0:03:11.
#   Batch 3,240  of  9,275.    Elapsed: 0:03:14.
#   Batch 3,280  of  9,275.    Elapsed: 0:03:16.
#   Batch 3,320  of  9,275.    Elapsed: 0:03:19.
#   Batch 3,360  of  9,275.    Elapsed: 0:03:21.
#   Batch 3,400  of  9,275.    Elapsed: 0:03:23.
#   Batch 3,440  of  9,275.    Elapsed: 0:03:26.
#   Batch 3,480  of  9,275.    Elapsed: 0:03:28.
#   Batch 3,520  of  9,275.    Elapsed: 0:03:31.
#   Batch 3,560  of  9,275.    Elapsed: 0:03:33.
#   Batch 3,600  of  9,275.    Elapsed: 0:03:35.
#   Batch 3,640  of  9,275.    Elapsed: 0:03:38.
#   Batch 3,680  of  9,275.    Elapsed: 0:03:40.
#   Batch 3,720  of  9,275.    Elapsed: 0:03:42.
#   Batch 3,760  of  9,275.    Elapsed: 0:03:45.
#   Batch 3,800  of  9,275.    Elapsed: 0:03:47.
#   Batch 3,840  of  9,275.    Elapsed: 0:03:50.
#   Batch 3,880  of  9,275.    Elapsed: 0:03:52.
#   Batch 3,920  of  9,275.    Elapsed: 0:03:54.
#   Batch 3,960  of  9,275.    Elapsed: 0:03:57.
#   Batch 4,000  of  9,275.    Elapsed: 0:03:59.
#   Batch 4,040  of  9,275.    Elapsed: 0:04:02.
#   Batch 4,080  of  9,275.    Elapsed: 0:04:04.
#   Batch 4,120  of  9,275.    Elapsed: 0:04:06.
#   Batch 4,160  of  9,275.    Elapsed: 0:04:09.
#   Batch 4,200  of  9,275.    Elapsed: 0:04:11.
#   Batch 4,240  of  9,275.    Elapsed: 0:04:14.
#   Batch 4,280  of  9,275.    Elapsed: 0:04:16.
#   Batch 4,320  of  9,275.    Elapsed: 0:04:18.
#   Batch 4,360  of  9,275.    Elapsed: 0:04:21.
#   Batch 4,400  of  9,275.    Elapsed: 0:04:23.
#   Batch 4,440  of  9,275.    Elapsed: 0:04:26.
#   Batch 4,480  of  9,275.    Elapsed: 0:04:28.
#   Batch 4,520  of  9,275.    Elapsed: 0:04:30.
#   Batch 4,560  of  9,275.    Elapsed: 0:04:33.
#   Batch 4,600  of  9,275.    Elapsed: 0:04:35.
#   Batch 4,640  of  9,275.    Elapsed: 0:04:38.
#   Batch 4,680  of  9,275.    Elapsed: 0:04:40.
#   Batch 4,720  of  9,275.    Elapsed: 0:04:42.
#   Batch 4,760  of  9,275.    Elapsed: 0:04:45.
#   Batch 4,800  of  9,275.    Elapsed: 0:04:47.
#   Batch 4,840  of  9,275.    Elapsed: 0:04:49.
#   Batch 4,880  of  9,275.    Elapsed: 0:04:52.
#   Batch 4,920  of  9,275.    Elapsed: 0:04:54.
#   Batch 4,960  of  9,275.    Elapsed: 0:04:57.
#   Batch 5,000  of  9,275.    Elapsed: 0:04:59.
#   Batch 5,040  of  9,275.    Elapsed: 0:05:01.
#   Batch 5,080  of  9,275.    Elapsed: 0:05:04.
#   Batch 5,120  of  9,275.    Elapsed: 0:05:06.
#   Batch 5,160  of  9,275.    Elapsed: 0:05:09.
#   Batch 5,200  of  9,275.    Elapsed: 0:05:11.
#   Batch 5,240  of  9,275.    Elapsed: 0:05:13.
#   Batch 5,280  of  9,275.    Elapsed: 0:05:16.
#   Batch 5,320  of  9,275.    Elapsed: 0:05:18.
#   Batch 5,360  of  9,275.    Elapsed: 0:05:21.
#   Batch 5,400  of  9,275.    Elapsed: 0:05:23.
#   Batch 5,440  of  9,275.    Elapsed: 0:05:25.
#   Batch 5,480  of  9,275.    Elapsed: 0:05:28.
#   Batch 5,520  of  9,275.    Elapsed: 0:05:30.
#   Batch 5,560  of  9,275.    Elapsed: 0:05:33.
#   Batch 5,600  of  9,275.    Elapsed: 0:05:35.
#   Batch 5,640  of  9,275.    Elapsed: 0:05:37.
#   Batch 5,680  of  9,275.    Elapsed: 0:05:40.
#   Batch 5,720  of  9,275.    Elapsed: 0:05:42.
#   Batch 5,760  of  9,275.    Elapsed: 0:05:45.
#   Batch 5,800  of  9,275.    Elapsed: 0:05:47.
#   Batch 5,840  of  9,275.    Elapsed: 0:05:49.
#   Batch 5,880  of  9,275.    Elapsed: 0:05:52.
#   Batch 5,920  of  9,275.    Elapsed: 0:05:54.
#   Batch 5,960  of  9,275.    Elapsed: 0:05:56.
#   Batch 6,000  of  9,275.    Elapsed: 0:05:59.
#   Batch 6,040  of  9,275.    Elapsed: 0:06:01.
#   Batch 6,080  of  9,275.    Elapsed: 0:06:04.
#   Batch 6,120  of  9,275.    Elapsed: 0:06:06.
#   Batch 6,160  of  9,275.    Elapsed: 0:06:08.
#   Batch 6,200  of  9,275.    Elapsed: 0:06:11.
#   Batch 6,240  of  9,275.    Elapsed: 0:06:13.
#   Batch 6,280  of  9,275.    Elapsed: 0:06:16.
#   Batch 6,320  of  9,275.    Elapsed: 0:06:18.
#   Batch 6,360  of  9,275.    Elapsed: 0:06:20.
#   Batch 6,400  of  9,275.    Elapsed: 0:06:23.
#   Batch 6,440  of  9,275.    Elapsed: 0:06:25.
#   Batch 6,480  of  9,275.    Elapsed: 0:06:28.
#   Batch 6,520  of  9,275.    Elapsed: 0:06:30.
#   Batch 6,560  of  9,275.    Elapsed: 0:06:32.
#   Batch 6,600  of  9,275.    Elapsed: 0:06:35.
#   Batch 6,640  of  9,275.    Elapsed: 0:06:37.
#   Batch 6,680  of  9,275.    Elapsed: 0:06:39.
#   Batch 6,720  of  9,275.    Elapsed: 0:06:42.
#   Batch 6,760  of  9,275.    Elapsed: 0:06:44.
#   Batch 6,800  of  9,275.    Elapsed: 0:06:47.
#   Batch 6,840  of  9,275.    Elapsed: 0:06:49.
#   Batch 6,880  of  9,275.    Elapsed: 0:06:51.
#   Batch 6,920  of  9,275.    Elapsed: 0:06:54.
#   Batch 6,960  of  9,275.    Elapsed: 0:06:56.
#   Batch 7,000  of  9,275.    Elapsed: 0:06:59.
#   Batch 7,040  of  9,275.    Elapsed: 0:07:01.
#   Batch 7,080  of  9,275.    Elapsed: 0:07:03.
#   Batch 7,120  of  9,275.    Elapsed: 0:07:06.
#   Batch 7,160  of  9,275.    Elapsed: 0:07:08.
#   Batch 7,200  of  9,275.    Elapsed: 0:07:11.
#   Batch 7,240  of  9,275.    Elapsed: 0:07:13.
#   Batch 7,280  of  9,275.    Elapsed: 0:07:15.
#   Batch 7,320  of  9,275.    Elapsed: 0:07:18.
#   Batch 7,360  of  9,275.    Elapsed: 0:07:20.
#   Batch 7,400  of  9,275.    Elapsed: 0:07:23.
#   Batch 7,440  of  9,275.    Elapsed: 0:07:25.
#   Batch 7,480  of  9,275.    Elapsed: 0:07:27.
#   Batch 7,520  of  9,275.    Elapsed: 0:07:30.
#   Batch 7,560  of  9,275.    Elapsed: 0:07:32.
#   Batch 7,600  of  9,275.    Elapsed: 0:07:35.
#   Batch 7,640  of  9,275.    Elapsed: 0:07:37.
#   Batch 7,680  of  9,275.    Elapsed: 0:07:39.
#   Batch 7,720  of  9,275.    Elapsed: 0:07:42.
#   Batch 7,760  of  9,275.    Elapsed: 0:07:44.
#   Batch 7,800  of  9,275.    Elapsed: 0:07:47.
#   Batch 7,840  of  9,275.    Elapsed: 0:07:49.
#   Batch 7,880  of  9,275.    Elapsed: 0:07:51.
#   Batch 7,920  of  9,275.    Elapsed: 0:07:54.
#   Batch 7,960  of  9,275.    Elapsed: 0:07:56.
#   Batch 8,000  of  9,275.    Elapsed: 0:07:58.
#   Batch 8,040  of  9,275.    Elapsed: 0:08:01.
#   Batch 8,080  of  9,275.    Elapsed: 0:08:03.
#   Batch 8,120  of  9,275.    Elapsed: 0:08:06.
#   Batch 8,160  of  9,275.    Elapsed: 0:08:08.
#   Batch 8,200  of  9,275.    Elapsed: 0:08:10.
#   Batch 8,240  of  9,275.    Elapsed: 0:08:13.
#   Batch 8,280  of  9,275.    Elapsed: 0:08:15.
#   Batch 8,320  of  9,275.    Elapsed: 0:08:18.
#   Batch 8,360  of  9,275.    Elapsed: 0:08:20.
#   Batch 8,400  of  9,275.    Elapsed: 0:08:22.
#   Batch 8,440  of  9,275.    Elapsed: 0:08:25.
#   Batch 8,480  of  9,275.    Elapsed: 0:08:27.
#   Batch 8,520  of  9,275.    Elapsed: 0:08:30.
#   Batch 8,560  of  9,275.    Elapsed: 0:08:32.
#   Batch 8,600  of  9,275.    Elapsed: 0:08:34.
#   Batch 8,640  of  9,275.    Elapsed: 0:08:37.
#   Batch 8,680  of  9,275.    Elapsed: 0:08:39.
#   Batch 8,720  of  9,275.    Elapsed: 0:08:42.
#   Batch 8,760  of  9,275.    Elapsed: 0:08:44.
#   Batch 8,800  of  9,275.    Elapsed: 0:08:46.
#   Batch 8,840  of  9,275.    Elapsed: 0:08:49.
#   Batch 8,880  of  9,275.    Elapsed: 0:08:51.
#   Batch 8,920  of  9,275.    Elapsed: 0:08:54.
#   Batch 8,960  of  9,275.    Elapsed: 0:08:56.
#   Batch 9,000  of  9,275.    Elapsed: 0:08:58.
#   Batch 9,040  of  9,275.    Elapsed: 0:09:01.
#   Batch 9,080  of  9,275.    Elapsed: 0:09:03.
#   Batch 9,120  of  9,275.    Elapsed: 0:09:05.
#   Batch 9,160  of  9,275.    Elapsed: 0:09:08.
#   Batch 9,200  of  9,275.    Elapsed: 0:09:10.
#   Batch 9,240  of  9,275.    Elapsed: 0:09:13.
#
#   Average training loss: 0.32
#   Average training accuracy: 0.86
#   Training epcoh took: 0:09:15
#
# Running Validation...
#   Accuracy: 0.85
#   Validation Loss: 0.36
#   Validation took: 0:00:41
#
# Training complete!
# Total training took 0:19:50 (h:mm:ss)
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85     21197
#            1       0.85      0.85      0.85     21199
#
#     accuracy                           0.85     42396
#    macro avg       0.85      0.85      0.85     42396
# weighted avg       0.85      0.85      0.85     42396

# %%
# prompt: if accuracy of model3 is better than model2, keep either dataset3 or dataset2 for future training

accuracy_model2 = results2[-1]['Valid. Accur.'] # Assuming results2 contains evaluation results for model2
accuracy_model3 = results3[-1]['Valid. Accur.'] # Assuming results2 contains evaluation results for model3

if accuracy_model3 > accuracy_model2:
  print("Model 3 is better than Model 2. Keeping dataset3.")
  best_train_dataloader = train_dataloader_clean3
  best_val_dataloader = validation_dataloader_clean3
  best_test_dataloader = test_dataloader_clean3
else:
  print("Model 2 is better than Model 3. Keeping dataset2.")
  best_train_dataloader = train_dataloader_clean2
  best_val_dataloader = validation_dataloader_clean2
  best_test_dataloader = test_dataloader_clean2
# Out:
# Model 3 is better than Model 2. Keeping dataset3.

# %%
# prompt: use optuna to optimize scheduler and optimizer parameters

# !pip install optuna

import optuna
from sklearn.metrics import accuracy_score

def objective(trial):
    # Define hyperparameters to tune
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 5e-5, log=True)
    eps = trial.suggest_float("eps", 1e-9, 1e-7, log=True)
    warmup_ratio = trial.suggest_float("warmup_ratio", 0.0, 0.1)

    # Get the model
    model = get_model(resize_embeddings=True, device=device)
    model.train()

    # Define optimizer and scheduler
    optimizer = AdamW(model.parameters(), lr=learning_rate, eps=eps)
    total_steps = len(best_train_dataloader) * epochs
    warmup_steps = int(total_steps * warmup_ratio)
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps, num_training_steps=total_steps)

    _results = train_and_validate(model, best_train_dataloader, best_val_dataloader, optimizer, scheduler, device, 2)

    return _results[-1]['Valid. Accur.']

# Create a study and optimize
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=10) # Run 10 trials

# Print the best parameters and their value
print("Best trial:")
print("  Value: {}".format(study.best_trial.value))
print("  Params: ")
for key, value in study.best_trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (2.4.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->optuna) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->optuna) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->optuna) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->optuna) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->optuna) (2024.2.0)
# [I 2025-06-01 18:41:45,811] A new study created in memory with name: no-name-46b3e2c5-34ae-48cc-b241-1f722c1168e3
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ======== Epoch 1 / 2 ========
# Training...
#   Batch    40  of  9,275.    Elapsed: 0:00:02.
#   Batch    80  of  9,275.    Elapsed: 0:00:05.
#   Batch   120  of  9,275.    Elapsed: 0:00:07.
#   Batch   160  of  9,275.    Elapsed: 0:00:10.
#   Batch   200  of  9,275.    Elapsed: 0:00:12.
#   Batch   240  of  9,275.    Elapsed: 0:00:14.
#   Batch   280  of  9,275.    Elapsed: 0:00:17.
#   Batch   320  of  9,275.    Elapsed: 0:00:19.
#   Batch   360  of  9,275.    Elapsed: 0:00:22.
#   Batch   400  of  9,275.    Elapsed: 0:00:24.
#   Batch   440  of  9,275.    Elapsed: 0:00:26.
#   Batch   480  of  9,275.    Elapsed: 0:00:29.
#   Batch   520  of  9,275.    Elapsed: 0:00:31.
#   Batch   560  of  9,275.    Elapsed: 0:00:34.
#   Batch   600  of  9,275.    Elapsed: 0:00:36.
#   Batch   640  of  9,275.    Elapsed: 0:00:38.
#   Batch   680  of  9,275.    Elapsed: 0:00:41.
#   Batch   720  of  9,275.    Elapsed: 0:00:43.
#   Batch   760  of  9,275.    Elapsed: 0:00:45.
#   Batch   800  of  9,275.    Elapsed: 0:00:48.
#   Batch   840  of  9,275.    Elapsed: 0:00:50.
#   Batch   880  of  9,275.    Elapsed: 0:00:53.
#   Batch   920  of  9,275.    Elapsed: 0:00:55.
#   Batch   960  of  9,275.    Elapsed: 0:00:57.
#   Batch 1,000  of  9,275.    Elapsed: 0:01:00.
#   Batch 1,040  of  9,275.    Elapsed: 0:01:02.
#   Batch 1,080  of  9,275.    Elapsed: 0:01:05.
#   Batch 1,120  of  9,275.    Elapsed: 0:01:07.
#   Batch 1,160  of  9,275.    Elapsed: 0:01:09.
#   Batch 1,200  of  9,275.    Elapsed: 0:01:12.
#   Batch 1,240  of  9,275.    Elapsed: 0:01:14.
#   Batch 1,280  of  9,275.    Elapsed: 0:01:17.
#   Batch 1,320  of  9,275.    Elapsed: 0:01:19.
#   Batch 1,360  of  9,275.    Elapsed: 0:01:21.
#   Batch 1,400  of  9,275.    Elapsed: 0:01:24.
#   Batch 1,440  of  9,275.    Elapsed: 0:01:26.
#   Batch 1,480  of  9,275.    Elapsed: 0:01:29.
#   Batch 1,520  of  9,275.    Elapsed: 0:01:31.
#   Batch 1,560  of  9,275.    Elapsed: 0:01:33.
#   Batch 1,600  of  9,275.    Elapsed: 0:01:36.
#   Batch 1,640  of  9,275.    Elapsed: 0:01:38.
#   Batch 1,680  of  9,275.    Elapsed: 0:01:41.
#   Batch 1,720  of  9,275.    Elapsed: 0:01:43.
#   Batch 1,760  of  9,275.    Elapsed: 0:01:45.
#   Batch 1,800  of  9,275.    Elapsed: 0:01:48.
#   Batch 1,840  of  9,275.    Elapsed: 0:01:50.
#   Batch 1,880  of  9,275.    Elapsed: 0:01:53.
#   Batch 1,920  of  9,275.    Elapsed: 0:01:55.
#   Batch 1,960  of  9,275.    Elapsed: 0:01:57.
#   Batch 2,000  of  9,275.    Elapsed: 0:02:00.
#   Batch 2,040  of  9,275.    Elapsed: 0:02:02.
#   Batch 2,080  of  9,275.    Elapsed: 0:02:04.
#   Batch 2,120  of  9,275.    Elapsed: 0:02:07.
#   Batch 2,160  of  9,275.    Elapsed: 0:02:09.
#   Batch 2,200  of  9,275.    Elapsed: 0:02:12.
#   Batch 2,240  of  9,275.    Elapsed: 0:02:14.
#   Batch 2,280  of  9,275.    Elapsed: 0:02:16.
#   Batch 2,320  of  9,275.    Elapsed: 0:02:19.
#   Batch 2,360  of  9,275.    Elapsed: 0:02:21.
#   Batch 2,400  of  9,275.    Elapsed: 0:02:24.
#   Batch 2,440  of  9,275.    Elapsed: 0:02:26.
#   Batch 2,480  of  9,275.    Elapsed: 0:02:28.
#   Batch 2,520  of  9,275.    Elapsed: 0:02:31.
#   Batch 2,560  of  9,275.    Elapsed: 0:02:33.
#   Batch 2,600  of  9,275.    Elapsed: 0:02:36.
#   Batch 2,640  of  9,275.    Elapsed: 0:02:38.
#   Batch 2,680  of  9,275.    Elapsed: 0:02:40.
#   Batch 2,720  of  9,275.    Elapsed: 0:02:43.
#   Batch 2,760  of  9,275.    Elapsed: 0:02:45.
#   Batch 2,800  of  9,275.    Elapsed: 0:02:48.
#   Batch 2,840  of  9,275.    Elapsed: 0:02:50.
#   Batch 2,880  of  9,275.    Elapsed: 0:02:52.
#   Batch 2,920  of  9,275.    Elapsed: 0:02:55.
#   Batch 2,960  of  9,275.    Elapsed: 0:02:57.
#   Batch 3,000  of  9,275.    Elapsed: 0:03:00.
#   Batch 3,040  of  9,275.    Elapsed: 0:03:02.
#   Batch 3,080  of  9,275.    Elapsed: 0:03:04.
#   Batch 3,120  of  9,275.    Elapsed: 0:03:07.
#   Batch 3,160  of  9,275.    Elapsed: 0:03:09.
#   Batch 3,200  of  9,275.    Elapsed: 0:03:12.
#   Batch 3,240  of  9,275.    Elapsed: 0:03:14.
#   Batch 3,280  of  9,275.    Elapsed: 0:03:16.
#   Batch 3,320  of  9,275.    Elapsed: 0:03:19.
#   Batch 3,360  of  9,275.    Elapsed: 0:03:21.
#   Batch 3,400  of  9,275.    Elapsed: 0:03:24.
#   Batch 3,440  of  9,275.    Elapsed: 0:03:26.
#   Batch 3,480  of  9,275.    Elapsed: 0:03:28.
#   Batch 3,520  of  9,275.    Elapsed: 0:03:31.
#   Batch 3,560  of  9,275.    Elapsed: 0:03:33.
#   Batch 3,600  of  9,275.    Elapsed: 0:03:36.
#   Batch 3,640  of  9,275.    Elapsed: 0:03:38.
#   Batch 3,680  of  9,275.    Elapsed: 0:03:40.
#   Batch 3,720  of  9,275.    Elapsed: 0:03:43.
#   Batch 3,760  of  9,275.    Elapsed: 0:03:45.
#   Batch 3,800  of  9,275.    Elapsed: 0:03:47.
#   Batch 3,840  of  9,275.    Elapsed: 0:03:50.
#   Batch 3,880  of  9,275.    Elapsed: 0:03:52.
#   Batch 3,920  of  9,275.    Elapsed: 0:03:55.
#   Batch 3,960  of  9,275.    Elapsed: 0:03:57.
#   Batch 4,000  of  9,275.    Elapsed: 0:03:59.
#   Batch 4,040  of  9,275.    Elapsed: 0:04:02.
#   Batch 4,080  of  9,275.    Elapsed: 0:04:04.
#   Batch 4,120  of  9,275.    Elapsed: 0:04:07.
#   Batch 4,160  of  9,275.    Elapsed: 0:04:09.
#   Batch 4,200  of  9,275.    Elapsed: 0:04:11.
#   Batch 4,240  of  9,275.    Elapsed: 0:04:14.
#   Batch 4,280  of  9,275.    Elapsed: 0:04:16.
#   Batch 4,320  of  9,275.    Elapsed: 0:04:19.
#   Batch 4,360  of  9,275.    Elapsed: 0:04:21.
#   Batch 4,400  of  9,275.    Elapsed: 0:04:23.
#   Batch 4,440  of  9,275.    Elapsed: 0:04:26.
#   Batch 4,480  of  9,275.    Elapsed: 0:04:28.
#   Batch 4,520  of  9,275.    Elapsed: 0:04:31.
#   Batch 4,560  of  9,275.    Elapsed: 0:04:33.
#   Batch 4,600  of  9,275.    Elapsed: 0:04:35.
#   Batch 4,640  of  9,275.    Elapsed: 0:04:38.
#   Batch 4,680  of  9,275.    Elapsed: 0:04:40.
#   Batch 4,720  of  9,275.    Elapsed: 0:04:43.
#   Batch 4,760  of  9,275.    Elapsed: 0:04:45.
#   Batch 4,800  of  9,275.    Elapsed: 0:04:47.
#   Batch 4,840  of  9,275.    Elapsed: 0:04:50.
#   Batch 4,880  of  9,275.    Elapsed: 0:04:52.
#   Batch 4,920  of  9,275.    Elapsed: 0:04:55.
#   Batch 4,960  of  9,275.    Elapsed: 0:04:57.
#   Batch 5,000  of  9,275.    Elapsed: 0:04:59.
#   Batch 5,040  of  9,275.    Elapsed: 0:05:02.
#   Batch 5,080  of  9,275.    Elapsed: 0:05:04.
#   Batch 5,120  of  9,275.    Elapsed: 0:05:07.
#   Batch 5,160  of  9,275.    Elapsed: 0:05:09.
#   Batch 5,200  of  9,275.    Elapsed: 0:05:11.
#   Batch 5,240  of  9,275.    Elapsed: 0:05:14.
#   Batch 5,280  of  9,275.    Elapsed: 0:05:16.
#   Batch 5,320  of  9,275.    Elapsed: 0:05:18.
#   Batch 5,360  of  9,275.    Elapsed: 0:05:21.
#   Batch 5,400  of  9,275.    Elapsed: 0:05:23.
#   Batch 5,440  of  9,275.    Elapsed: 0:05:26.
#   Batch 5,480  of  9,275.    Elapsed: 0:05:28.
#   Batch 5,520  of  9,275.    Elapsed: 0:05:30.
#   Batch 5,560  of  9,275.    Elapsed: 0:05:33.
#   Batch 5,600  of  9,275.    Elapsed: 0:05:35.
#   Batch 5,640  of  9,275.    Elapsed: 0:05:38.
#   Batch 5,680  of  9,275.    Elapsed: 0:05:40.
#   Batch 5,720  of  9,275.    Elapsed: 0:05:42.
#   Batch 5,760  of  9,275.    Elapsed: 0:05:45.
#   Batch 5,800  of  9,275.    Elapsed: 0:05:47.
#   Batch 5,840  of  9,275.    Elapsed: 0:05:50.
#   Batch 5,880  of  9,275.    Elapsed: 0:05:52.
#   Batch 5,920  of  9,275.    Elapsed: 0:05:54.
#   Batch 5,960  of  9,275.    Elapsed: 0:05:57.
#   Batch 6,000  of  9,275.    Elapsed: 0:05:59.
#   Batch 6,040  of  9,275.    Elapsed: 0:06:02.
#   Batch 6,080  of  9,275.    Elapsed: 0:06:04.
#   Batch 6,120  of  9,275.    Elapsed: 0:06:06.
#   Batch 6,160  of  9,275.    Elapsed: 0:06:09.
#   Batch 6,200  of  9,275.    Elapsed: 0:06:11.
#   Batch 6,240  of  9,275.    Elapsed: 0:06:13.
#   Batch 6,280  of  9,275.    Elapsed: 0:06:16.
#   Batch 6,320  of  9,275.    Elapsed: 0:06:18.
#   Batch 6,360  of  9,275.    Elapsed: 0:06:21.
#   Batch 6,400  of  9,275.    Elapsed: 0:06:23.
#   Batch 6,440  of  9,275.    Elapsed: 0:06:25.
#   Batch 6,480  of  9,275.    Elapsed: 0:06:28.
#   Batch 6,520  of  9,275.    Elapsed: 0:06:30.
#   Batch 6,560  of  9,275.    Elapsed: 0:06:33.
#   Batch 6,600  of  9,275.    Elapsed: 0:06:35.
#   Batch 6,640  of  9,275.    Elapsed: 0:06:37.
#   Batch 6,680  of  9,275.    Elapsed: 0:06:40.
#   Batch 6,720  of  9,275.    Elapsed: 0:06:42.
#   Batch 6,760  of  9,275.    Elapsed: 0:06:45.
#   Batch 6,800  of  9,275.    Elapsed: 0:06:47.
#   Batch 6,840  of  9,275.    Elapsed: 0:06:49.
#   Batch 6,880  of  9,275.    Elapsed: 0:06:52.
#   Batch 6,920  of  9,275.    Elapsed: 0:06:54.
#   Batch 6,960  of  9,275.    Elapsed: 0:06:57.
#   Batch 7,000  of  9,275.    Elapsed: 0:06:59.
#   Batch 7,040  of  9,275.    Elapsed: 0:07:01.
#   Batch 7,080  of  9,275.    Elapsed: 0:07:04.
#   Batch 7,120  of  9,275.    Elapsed: 0:07:06.
#   Batch 7,160  of  9,275.    Elapsed: 0:07:09.
#   Batch 7,200  of  9,275.    Elapsed: 0:07:11.
#   Batch 7,240  of  9,275.    Elapsed: 0:07:13.
#   Batch 7,280  of  9,275.    Elapsed: 0:07:16.
#   Batch 7,320  of  9,275.    Elapsed: 0:07:18.
#   Batch 7,360  of  9,275.    Elapsed: 0:07:20.
#   Batch 7,400  of  9,275.    Elapsed: 0:07:23.
#   Batch 7,440  of  9,275.    Elapsed: 0:07:25.
#   Batch 7,480  of  9,275.    Elapsed: 0:07:28.
#   Batch 7,520  of  9,275.    Elapsed: 0:07:30.
#   Batch 7,560  of  9,275.    Elapsed: 0:07:32.
#   Batch 7,600  of  9,275.    Elapsed: 0:07:35.
#   Batch 7,640  of  9,275.    Elapsed: 0:07:37.
#   Batch 7,680  of  9,275.    Elapsed: 0:07:40.
#   Batch 7,720  of  9,275.    Elapsed: 0:07:42.
#   Batch 7,760  of  9,275.    Elapsed: 0:07:44.
#   Batch 7,800  of  9,275.    Elapsed: 0:07:47.
#   Batch 7,840  of  9,275.    Elapsed: 0:07:49.
#   Batch 7,880  of  9,275.    Elapsed: 0:07:52.
#   Batch 7,920  of  9,275.    Elapsed: 0:07:54.
#   Batch 7,960  of  9,275.    Elapsed: 0:07:56.
#   Batch 8,000  of  9,275.    Elapsed: 0:07:59.
#   Batch 8,040  of  9,275.    Elapsed: 0:08:01.
#   Batch 8,080  of  9,275.    Elapsed: 0:08:04.
#   Batch 8,120  of  9,275.    Elapsed: 0:08:06.
#   Batch 8,160  of  9,275.    Elapsed: 0:08:08.
#   Batch 8,200  of  9,275.    Elapsed: 0:08:11.
#   Batch 8,240  of  9,275.    Elapsed: 0:08:13.
#   Batch 8,280  of  9,275.    Elapsed: 0:08:15.
#   Batch 8,320  of  9,275.    Elapsed: 0:08:18.
#   Batch 8,360  of  9,275.    Elapsed: 0:08:20.
#   Batch 8,400  of  9,275.    Elapsed: 0:08:23.
#   Batch 8,440  of  9,275.    Elapsed: 0:08:25.
#   Batch 8,480  of  9,275.    Elapsed: 0:08:27.
#   Batch 8,520  of  9,275.    Elapsed: 0:08:30.
#   Batch 8,560  of  9,275.    Elapsed: 0:08:32.
#   Batch 8,600  of  9,275.    Elapsed: 0:08:35.
#   Batch 8,640  of  9,275.    Elapsed: 0:08:37.
#   Batch 8,680  of  9,275.    Elapsed: 0:08:39.
#   Batch 8,720  of  9,275.    Elapsed: 0:08:42.
#   Batch 8,760  of  9,275.    Elapsed: 0:08:44.
#   Batch 8,800  of  9,275.    Elapsed: 0:08:47.
#   Batch 8,840  of  9,275.    Elapsed: 0:08:49.
#   Batch 8,880  of  9,275.    Elapsed: 0:08:51.
#   Batch 8,920  of  9,275.    Elapsed: 0:08:54.
#   Batch 8,960  of  9,275.    Elapsed: 0:08:56.
#   Batch 9,000  of  9,275.    Elapsed: 0:08:58.
#   Batch 9,040  of  9,275.    Elapsed: 0:09:01.
#   Batch 9,080  of  9,275.    Elapsed: 0:09:03.
#   Batch 9,120  of  9,275.    Elapsed: 0:09:06.
#   Batch 9,160  of  9,275.    Elapsed: 0:09:08.
#   Batch 9,200  of  9,275.    Elapsed: 0:09:10.
#   Batch 9,240  of  9,275.    Elapsed: 0:09:13.
#
#   Average training loss: 0.41
#   Average training accuracy: 0.82
#   Training epcoh took: 0:09:15
#
# Running Validation...
#   Accuracy: 0.84
#   Validation Loss: 0.36
#   Validation took: 0:00:41
#
# ======== Epoch 2 / 2 ========
# Training...
#   Batch    40  of  9,275.    Elapsed: 0:00:02.
#   Batch    80  of  9,275.    Elapsed: 0:00:05.
#   Batch   120  of  9,275.    Elapsed: 0:00:07.
#   Batch   160  of  9,275.    Elapsed: 0:00:10.
#   Batch   200  of  9,275.    Elapsed: 0:00:12.
#   Batch   240  of  9,275.    Elapsed: 0:00:14.
#   Batch   280  of  9,275.    Elapsed: 0:00:17.
#   Batch   320  of  9,275.    Elapsed: 0:00:19.
#   Batch   360  of  9,275.    Elapsed: 0:00:21.
#   Batch   400  of  9,275.    Elapsed: 0:00:24.
#   Batch   440  of  9,275.    Elapsed: 0:00:26.
#   Batch   480  of  9,275.    Elapsed: 0:00:29.
#   Batch   520  of  9,275.    Elapsed: 0:00:31.
#   Batch   560  of  9,275.    Elapsed: 0:00:33.
#   Batch   600  of  9,275.    Elapsed: 0:00:36.
#   Batch   640  of  9,275.    Elapsed: 0:00:38.
#   Batch   680  of  9,275.    Elapsed: 0:00:41.
#   Batch   720  of  9,275.    Elapsed: 0:00:43.
#   Batch   760  of  9,275.    Elapsed: 0:00:45.
#   Batch   800  of  9,275.    Elapsed: 0:00:48.
#   Batch   840  of  9,275.    Elapsed: 0:00:50.
#   Batch   880  of  9,275.    Elapsed: 0:00:52.
#   Batch   920  of  9,275.    Elapsed: 0:00:55.
#   Batch   960  of  9,275.    Elapsed: 0:00:57.
#   Batch 1,000  of  9,275.    Elapsed: 0:01:00.
#   Batch 1,040  of  9,275.    Elapsed: 0:01:02.
#   Batch 1,080  of  9,275.    Elapsed: 0:01:04.
#   Batch 1,120  of  9,275.    Elapsed: 0:01:07.
#   Batch 1,160  of  9,275.    Elapsed: 0:01:09.
#   Batch 1,200  of  9,275.    Elapsed: 0:01:12.
#   Batch 1,240  of  9,275.    Elapsed: 0:01:14.
#   Batch 1,280  of  9,275.    Elapsed: 0:01:16.
#   Batch 1,320  of  9,275.    Elapsed: 0:01:19.
#   Batch 1,360  of  9,275.    Elapsed: 0:01:21.
#   Batch 1,400  of  9,275.    Elapsed: 0:01:23.
#   Batch 1,440  of  9,275.    Elapsed: 0:01:26.
#   Batch 1,480  of  9,275.    Elapsed: 0:01:28.
#   Batch 1,520  of  9,275.    Elapsed: 0:01:31.
#   Batch 1,560  of  9,275.    Elapsed: 0:01:33.
#   Batch 1,600  of  9,275.    Elapsed: 0:01:35.
#   Batch 1,640  of  9,275.    Elapsed: 0:01:38.
#   Batch 1,680  of  9,275.    Elapsed: 0:01:40.
#   Batch 1,720  of  9,275.    Elapsed: 0:01:43.
#   Batch 1,760  of  9,275.    Elapsed: 0:01:45.
#   Batch 1,800  of  9,275.    Elapsed: 0:01:47.
#   Batch 1,840  of  9,275.    Elapsed: 0:01:50.
#   Batch 1,880  of  9,275.    Elapsed: 0:01:52.
#   Batch 1,920  of  9,275.    Elapsed: 0:01:54.
#   Batch 1,960  of  9,275.    Elapsed: 0:01:57.
#   Batch 2,000  of  9,275.    Elapsed: 0:01:59.
#   Batch 2,040  of  9,275.    Elapsed: 0:02:02.
#   Batch 2,080  of  9,275.    Elapsed: 0:02:04.
#   Batch 2,120  of  9,275.    Elapsed: 0:02:06.
#   Batch 2,160  of  9,275.    Elapsed: 0:02:09.
#   Batch 2,200  of  9,275.    Elapsed: 0:02:11.
#   Batch 2,240  of  9,275.    Elapsed: 0:02:14.
#   Batch 2,280  of  9,275.    Elapsed: 0:02:16.
#   Batch 2,320  of  9,275.    Elapsed: 0:02:18.
#   Batch 2,360  of  9,275.    Elapsed: 0:02:21.
#   Batch 2,400  of  9,275.    Elapsed: 0:02:23.
#   Batch 2,440  of  9,275.    Elapsed: 0:02:25.
#   Batch 2,480  of  9,275.    Elapsed: 0:02:28.
#   Batch 2,520  of  9,275.    Elapsed: 0:02:30.
#   Batch 2,560  of  9,275.    Elapsed: 0:02:33.
#   Batch 2,600  of  9,275.    Elapsed: 0:02:35.
#   Batch 2,640  of  9,275.    Elapsed: 0:02:37.
#   Batch 2,680  of  9,275.    Elapsed: 0:02:40.
#   Batch 2,720  of  9,275.    Elapsed: 0:02:42.
#   Batch 2,760  of  9,275.    Elapsed: 0:02:45.
#   Batch 2,800  of  9,275.    Elapsed: 0:02:47.
#   Batch 2,840  of  9,275.    Elapsed: 0:02:49.
#   Batch 2,880  of  9,275.    Elapsed: 0:02:52.
#   Batch 2,920  of  9,275.    Elapsed: 0:02:54.
#   Batch 2,960  of  9,275.    Elapsed: 0:02:56.
#   Batch 3,000  of  9,275.    Elapsed: 0:02:59.
#   Batch 3,040  of  9,275.    Elapsed: 0:03:01.
#   Batch 3,080  of  9,275.    Elapsed: 0:03:04.
#   Batch 3,120  of  9,275.    Elapsed: 0:03:06.
#   Batch 3,160  of  9,275.    Elapsed: 0:03:08.
#   Batch 3,200  of  9,275.    Elapsed: 0:03:11.
#   Batch 3,240  of  9,275.    Elapsed: 0:03:13.
#   Batch 3,280  of  9,275.    Elapsed: 0:03:16.
#   Batch 3,320  of  9,275.    Elapsed: 0:03:18.
#   Batch 3,360  of  9,275.    Elapsed: 0:03:20.
#   Batch 3,400  of  9,275.    Elapsed: 0:03:23.
#   Batch 3,440  of  9,275.    Elapsed: 0:03:25.
#   Batch 3,480  of  9,275.    Elapsed: 0:03:27.
#   Batch 3,520  of  9,275.    Elapsed: 0:03:30.
#   Batch 3,560  of  9,275.    Elapsed: 0:03:32.
#   Batch 3,600  of  9,275.    Elapsed: 0:03:35.
#   Batch 3,640  of  9,275.    Elapsed: 0:03:37.
#   Batch 3,680  of  9,275.    Elapsed: 0:03:39.
#   Batch 3,720  of  9,275.    Elapsed: 0:03:42.
#   Batch 3,760  of  9,275.    Elapsed: 0:03:44.
#   Batch 3,800  of  9,275.    Elapsed: 0:03:47.
#   Batch 3,840  of  9,275.    Elapsed: 0:03:49.
#   Batch 3,880  of  9,275.    Elapsed: 0:03:51.
#   Batch 3,920  of  9,275.    Elapsed: 0:03:54.
#   Batch 3,960  of  9,275.    Elapsed: 0:03:56.
#   Batch 4,000  of  9,275.    Elapsed: 0:03:58.
#   Batch 4,040  of  9,275.    Elapsed: 0:04:01.
#   Batch 4,080  of  9,275.    Elapsed: 0:04:03.
#   Batch 4,120  of  9,275.    Elapsed: 0:04:06.
#   Batch 4,160  of  9,275.    Elapsed: 0:04:08.
#   Batch 4,200  of  9,275.    Elapsed: 0:04:10.
#   Batch 4,240  of  9,275.    Elapsed: 0:04:13.
#   Batch 4,280  of  9,275.    Elapsed: 0:04:15.
#   Batch 4,320  of  9,275.    Elapsed: 0:04:18.
#   Batch 4,360  of  9,275.    Elapsed: 0:04:20.
#   Batch 4,400  of  9,275.    Elapsed: 0:04:22.
#   Batch 4,440  of  9,275.    Elapsed: 0:04:25.
#   Batch 4,480  of  9,275.    Elapsed: 0:04:27.
#   Batch 4,520  of  9,275.    Elapsed: 0:04:30.
#   Batch 4,560  of  9,275.    Elapsed: 0:04:32.
#   Batch 4,600  of  9,275.    Elapsed: 0:04:34.
#   Batch 4,640  of  9,275.    Elapsed: 0:04:37.
#   Batch 4,680  of  9,275.    Elapsed: 0:04:39.
#   Batch 4,720  of  9,275.    Elapsed: 0:04:42.
#   Batch 4,760  of  9,275.    Elapsed: 0:04:44.
#   Batch 4,800  of  9,275.    Elapsed: 0:04:46.
#   Batch 4,840  of  9,275.    Elapsed: 0:04:49.
#   Batch 4,880  of  9,275.    Elapsed: 0:04:51.
#   Batch 4,920  of  9,275.    Elapsed: 0:04:53.
#   Batch 4,960  of  9,275.    Elapsed: 0:04:56.
#   Batch 5,000  of  9,275.    Elapsed: 0:04:58.
#   Batch 5,040  of  9,275.    Elapsed: 0:05:01.
#   Batch 5,080  of  9,275.    Elapsed: 0:05:03.
#   Batch 5,120  of  9,275.    Elapsed: 0:05:05.
#   Batch 5,160  of  9,275.    Elapsed: 0:05:08.
#   Batch 5,200  of  9,275.    Elapsed: 0:05:10.
#   Batch 5,240  of  9,275.    Elapsed: 0:05:13.
#   Batch 5,280  of  9,275.    Elapsed: 0:05:15.
#   Batch 5,320  of  9,275.    Elapsed: 0:05:17.
#   Batch 5,360  of  9,275.    Elapsed: 0:05:20.
#   Batch 5,400  of  9,275.    Elapsed: 0:05:22.
#   Batch 5,440  of  9,275.    Elapsed: 0:05:24.
#   Batch 5,480  of  9,275.    Elapsed: 0:05:27.
#   Batch 5,520  of  9,275.    Elapsed: 0:05:29.
#   Batch 5,560  of  9,275.    Elapsed: 0:05:32.
#   Batch 5,600  of  9,275.    Elapsed: 0:05:34.
#   Batch 5,640  of  9,275.    Elapsed: 0:05:36.
#   Batch 5,680  of  9,275.    Elapsed: 0:05:39.
#   Batch 5,720  of  9,275.    Elapsed: 0:05:41.
#   Batch 5,760  of  9,275.    Elapsed: 0:05:44.
#   Batch 5,800  of  9,275.    Elapsed: 0:05:46.
#   Batch 5,840  of  9,275.    Elapsed: 0:05:48.
#   Batch 5,880  of  9,275.    Elapsed: 0:05:51.
#   Batch 5,920  of  9,275.    Elapsed: 0:05:53.
#   Batch 5,960  of  9,275.    Elapsed: 0:05:56.
#   Batch 6,000  of  9,275.    Elapsed: 0:05:58.
#   Batch 6,040  of  9,275.    Elapsed: 0:06:00.
#   Batch 6,080  of  9,275.    Elapsed: 0:06:03.
#   Batch 6,120  of  9,275.    Elapsed: 0:06:05.
#   Batch 6,160  of  9,275.    Elapsed: 0:06:08.
#   Batch 6,200  of  9,275.    Elapsed: 0:06:10.
#   Batch 6,240  of  9,275.    Elapsed: 0:06:12.
#   Batch 6,280  of  9,275.    Elapsed: 0:06:15.
#   Batch 6,320  of  9,275.    Elapsed: 0:06:17.
#   Batch 6,360  of  9,275.    Elapsed: 0:06:20.
#   Batch 6,400  of  9,275.    Elapsed: 0:06:22.
#   Batch 6,440  of  9,275.    Elapsed: 0:06:24.
#   Batch 6,480  of  9,275.    Elapsed: 0:06:27.
#   Batch 6,520  of  9,275.    Elapsed: 0:06:29.
#   Batch 6,560  of  9,275.    Elapsed: 0:06:32.
#   Batch 6,600  of  9,275.    Elapsed: 0:06:34.
#   Batch 6,640  of  9,275.    Elapsed: 0:06:36.
#   Batch 6,680  of  9,275.    Elapsed: 0:06:39.
#   Batch 6,720  of  9,275.    Elapsed: 0:06:41.
#   Batch 6,760  of  9,275.    Elapsed: 0:06:43.
#   Batch 6,800  of  9,275.    Elapsed: 0:06:46.
#   Batch 6,840  of  9,275.    Elapsed: 0:06:48.
#   Batch 6,880  of  9,275.    Elapsed: 0:06:51.
#   Batch 6,920  of  9,275.    Elapsed: 0:06:53.
#   Batch 6,960  of  9,275.    Elapsed: 0:06:55.
#   Batch 7,000  of  9,275.    Elapsed: 0:06:58.
#   Batch 7,040  of  9,275.    Elapsed: 0:07:00.
#   Batch 7,080  of  9,275.    Elapsed: 0:07:03.
#   Batch 7,120  of  9,275.    Elapsed: 0:07:05.
#   Batch 7,160  of  9,275.    Elapsed: 0:07:07.
#   Batch 7,200  of  9,275.    Elapsed: 0:07:10.
#   Batch 7,240  of  9,275.    Elapsed: 0:07:12.
#   Batch 7,280  of  9,275.    Elapsed: 0:07:15.
#   Batch 7,320  of  9,275.    Elapsed: 0:07:17.
#   Batch 7,360  of  9,275.    Elapsed: 0:07:19.
#   Batch 7,400  of  9,275.    Elapsed: 0:07:22.
#   Batch 7,440  of  9,275.    Elapsed: 0:07:24.
#   Batch 7,480  of  9,275.    Elapsed: 0:07:26.
#   Batch 7,520  of  9,275.    Elapsed: 0:07:29.
#   Batch 7,560  of  9,275.    Elapsed: 0:07:31.
#   Batch 7,600  of  9,275.    Elapsed: 0:07:34.
#   Batch 7,640  of  9,275.    Elapsed: 0:07:36.
#   Batch 7,680  of  9,275.    Elapsed: 0:07:38.
#   Batch 7,720  of  9,275.    Elapsed: 0:07:41.
#   Batch 7,760  of  9,275.    Elapsed: 0:07:43.
#   Batch 7,800  of  9,275.    Elapsed: 0:07:46.
#   Batch 7,840  of  9,275.    Elapsed: 0:07:48.
#   Batch 7,880  of  9,275.    Elapsed: 0:07:50.
#   Batch 7,920  of  9,275.    Elapsed: 0:07:53.
#   Batch 7,960  of  9,275.    Elapsed: 0:07:55.
#   Batch 8,000  of  9,275.    Elapsed: 0:07:58.
#   Batch 8,040  of  9,275.    Elapsed: 0:08:00.
#   Batch 8,080  of  9,275.    Elapsed: 0:08:02.
#   Batch 8,120  of  9,275.    Elapsed: 0:08:05.
#   Batch 8,160  of  9,275.    Elapsed: 0:08:07.
#   Batch 8,200  of  9,275.    Elapsed: 0:08:09.
#   Batch 8,240  of  9,275.    Elapsed: 0:08:12.
#   Batch 8,280  of  9,275.    Elapsed: 0:08:14.
#   Batch 8,320  of  9,275.    Elapsed: 0:08:17.
#   Batch 8,360  of  9,275.    Elapsed: 0:08:19.
#   Batch 8,400  of  9,275.    Elapsed: 0:08:21.
#   Batch 8,440  of  9,275.    Elapsed: 0:08:24.
#   Batch 8,480  of  9,275.    Elapsed: 0:08:26.
#   Batch 8,520  of  9,275.    Elapsed: 0:08:29.
#   Batch 8,560  of  9,275.    Elapsed: 0:08:31.
#   Batch 8,600  of  9,275.    Elapsed: 0:08:33.
#   Batch 8,640  of  9,275.    Elapsed: 0:08:36.
#   Batch 8,680  of  9,275.    Elapsed: 0:08:38.
#   Batch 8,720  of  9,275.    Elapsed: 0:08:40.
#   Batch 8,760  of  9,275.    Elapsed: 0:08:43.
#   Batch 8,800  of  9,275.    Elapsed: 0:08:45.
#   Batch 8,840  of  9,275.    Elapsed: 0:08:48.
#   Batch 8,880  of  9,275.    Elapsed: 0:08:50.
#   Batch 8,920  of  9,275.    Elapsed: 0:08:52.
#   Batch 8,960  of  9,275.    Elapsed: 0:08:55.
#   Batch 9,000  of  9,275.    Elapsed: 0:08:57.
#   Batch 9,040  of  9,275.    Elapsed: 0:09:00.
#   Batch 9,080  of  9,275.    Elapsed: 0:09:02.
#   Batch 9,120  of  9,275.    Elapsed: 0:09:04.
#   Batch 9,160  of  9,275.    Elapsed: 0:09:07.
#   Batch 9,200  of  9,275.    Elapsed: 0:09:09.
#   Batch 9,240  of  9,275.    Elapsed: 0:09:11.
#
#   Average training loss: 0.29
#   Average training accuracy: 0.88
#   Training epcoh took: 0:09:14
#
# Running Validation...
# [I 2025-06-01 19:01:36,828] Trial 0 finished with value: 0.8483411949685534 and parameters: {'learning_rate': 3.335840349533228e-05, 'eps': 1.7338119613912742e-08, 'warmup_ratio': 0.07964221738916054}. Best is trial 0 with value: 0.8483411949685534.
#   Accuracy: 0.85
#   Validation Loss: 0.37
#   Validation took: 0:00:41
#
# Training complete!
# Total training took 0:19:50 (h:mm:ss)
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ======== Epoch 1 / 2 ========
# Training...
#   Batch    40  of  9,275.    Elapsed: 0:00:02.
#   Batch    80  of  9,275.    Elapsed: 0:00:05.
#   Batch   120  of  9,275.    Elapsed: 0:00:07.
#   Batch   160  of  9,275.    Elapsed: 0:00:10.
#   Batch   200  of  9,275.    Elapsed: 0:00:12.
#   Batch   240  of  9,275.    Elapsed: 0:00:14.
#   Batch   280  of  9,275.    Elapsed: 0:00:17.
#   Batch   320  of  9,275.    Elapsed: 0:00:19.
#   Batch   360  of  9,275.    Elapsed: 0:00:21.
#   Batch   400  of  9,275.    Elapsed: 0:00:24.
#   Batch   440  of  9,275.    Elapsed: 0:00:26.
#   Batch   480  of  9,275.    Elapsed: 0:00:29.
#   Batch   520  of  9,275.    Elapsed: 0:00:31.
#   Batch   560  of  9,275.    Elapsed: 0:00:33.
#   Batch   600  of  9,275.    Elapsed: 0:00:36.
#   Batch   640  of  9,275.    Elapsed: 0:00:38.
#   Batch   680  of  9,275.    Elapsed: 0:00:41.
#   Batch   720  of  9,275.    Elapsed: 0:00:43.
#   Batch   760  of  9,275.    Elapsed: 0:00:45.
#   Batch   800  of  9,275.    Elapsed: 0:00:48.
#   Batch   840  of  9,275.    Elapsed: 0:00:50.
#   Batch   880  of  9,275.    Elapsed: 0:00:53.
#   Batch   920  of  9,275.    Elapsed: 0:00:55.
#   Batch   960  of  9,275.    Elapsed: 0:00:57.
#   Batch 1,000  of  9,275.    Elapsed: 0:01:00.
#   Batch 1,040  of  9,275.    Elapsed: 0:01:02.
#   Batch 1,080  of  9,275.    Elapsed: 0:01:04.
#   Batch 1,120  of  9,275.    Elapsed: 0:01:07.
#   Batch 1,160  of  9,275.    Elapsed: 0:01:09.
#   Batch 1,200  of  9,275.    Elapsed: 0:01:12.
#   Batch 1,240  of  9,275.    Elapsed: 0:01:14.
#   Batch 1,280  of  9,275.    Elapsed: 0:01:16.
#   Batch 1,320  of  9,275.    Elapsed: 0:01:19.
#   Batch 1,360  of  9,275.    Elapsed: 0:01:21.
#   Batch 1,400  of  9,275.    Elapsed: 0:01:24.
#   Batch 1,440  of  9,275.    Elapsed: 0:01:26.
#   Batch 1,480  of  9,275.    Elapsed: 0:01:28.
#   Batch 1,520  of  9,275.    Elapsed: 0:01:31.
#   Batch 1,560  of  9,275.    Elapsed: 0:01:33.
#   Batch 1,600  of  9,275.    Elapsed: 0:01:36.
#   Batch 1,640  of  9,275.    Elapsed: 0:01:38.
#   Batch 1,680  of  9,275.    Elapsed: 0:01:40.
#   Batch 1,720  of  9,275.    Elapsed: 0:01:43.
#   Batch 1,760  of  9,275.    Elapsed: 0:01:45.
#   Batch 1,800  of  9,275.    Elapsed: 0:01:47.
#   Batch 1,840  of  9,275.    Elapsed: 0:01:50.
#   Batch 1,880  of  9,275.    Elapsed: 0:01:52.
#   Batch 1,920  of  9,275.    Elapsed: 0:01:55.
#   Batch 1,960  of  9,275.    Elapsed: 0:01:57.
#   Batch 2,000  of  9,275.    Elapsed: 0:01:59.
#   Batch 2,040  of  9,275.    Elapsed: 0:02:02.
#   Batch 2,080  of  9,275.    Elapsed: 0:02:04.
#   Batch 2,120  of  9,275.    Elapsed: 0:02:07.
#   Batch 2,160  of  9,275.    Elapsed: 0:02:09.
#   Batch 2,200  of  9,275.    Elapsed: 0:02:11.
#   Batch 2,240  of  9,275.    Elapsed: 0:02:14.
#   Batch 2,280  of  9,275.    Elapsed: 0:02:16.
#   Batch 2,320  of  9,275.    Elapsed: 0:02:19.
#   Batch 2,360  of  9,275.    Elapsed: 0:02:21.
#   Batch 2,400  of  9,275.    Elapsed: 0:02:23.
#   Batch 2,440  of  9,275.    Elapsed: 0:02:26.
#   Batch 2,480  of  9,275.    Elapsed: 0:02:28.
#   Batch 2,520  of  9,275.    Elapsed: 0:02:30.
#   Batch 2,560  of  9,275.    Elapsed: 0:02:33.
#   Batch 2,600  of  9,275.    Elapsed: 0:02:35.
#   Batch 2,640  of  9,275.    Elapsed: 0:02:38.
#   Batch 2,680  of  9,275.    Elapsed: 0:02:40.
#   Batch 2,720  of  9,275.    Elapsed: 0:02:42.
#   Batch 2,760  of  9,275.    Elapsed: 0:02:45.
#   Batch 2,800  of  9,275.    Elapsed: 0:02:47.
#   Batch 2,840  of  9,275.    Elapsed: 0:02:50.
#   Batch 2,880  of  9,275.    Elapsed: 0:02:52.
#   Batch 2,920  of  9,275.    Elapsed: 0:02:54.
#   Batch 2,960  of  9,275.    Elapsed: 0:02:57.
#   Batch 3,000  of  9,275.    Elapsed: 0:02:59.
#   Batch 3,040  of  9,275.    Elapsed: 0:03:02.
#   Batch 3,080  of  9,275.    Elapsed: 0:03:04.
#   Batch 3,120  of  9,275.    Elapsed: 0:03:06.
#   Batch 3,160  of  9,275.    Elapsed: 0:03:09.
#   Batch 3,200  of  9,275.    Elapsed: 0:03:11.
#   Batch 3,240  of  9,275.    Elapsed: 0:03:13.
#   Batch 3,280  of  9,275.    Elapsed: 0:03:16.
#   Batch 3,320  of  9,275.    Elapsed: 0:03:18.
#   Batch 3,360  of  9,275.    Elapsed: 0:03:21.
#   Batch 3,400  of  9,275.    Elapsed: 0:03:23.
#   Batch 3,440  of  9,275.    Elapsed: 0:03:25.
#   Batch 3,480  of  9,275.    Elapsed: 0:03:28.
#   Batch 3,520  of  9,275.    Elapsed: 0:03:30.
#   Batch 3,560  of  9,275.    Elapsed: 0:03:33.
#   Batch 3,600  of  9,275.    Elapsed: 0:03:35.
#   Batch 3,640  of  9,275.    Elapsed: 0:03:37.
#   Batch 3,680  of  9,275.    Elapsed: 0:03:40.
#   Batch 3,720  of  9,275.    Elapsed: 0:03:42.
#   Batch 3,760  of  9,275.    Elapsed: 0:03:45.
#   Batch 3,800  of  9,275.    Elapsed: 0:03:47.
#   Batch 3,840  of  9,275.    Elapsed: 0:03:49.
#   Batch 3,880  of  9,275.    Elapsed: 0:03:52.
#   Batch 3,920  of  9,275.    Elapsed: 0:03:54.
#   Batch 3,960  of  9,275.    Elapsed: 0:03:56.
#   Batch 4,000  of  9,275.    Elapsed: 0:03:59.
#   Batch 4,040  of  9,275.    Elapsed: 0:04:01.
#   Batch 4,080  of  9,275.    Elapsed: 0:04:04.
#   Batch 4,120  of  9,275.    Elapsed: 0:04:06.
#   Batch 4,160  of  9,275.    Elapsed: 0:04:08.
#   Batch 4,200  of  9,275.    Elapsed: 0:04:11.
#   Batch 4,240  of  9,275.    Elapsed: 0:04:13.
#   Batch 4,280  of  9,275.    Elapsed: 0:04:16.
#   Batch 4,320  of  9,275.    Elapsed: 0:04:18.
#   Batch 4,360  of  9,275.    Elapsed: 0:04:20.
#   Batch 4,400  of  9,275.    Elapsed: 0:04:23.
#   Batch 4,440  of  9,275.    Elapsed: 0:04:25.
#   Batch 4,480  of  9,275.    Elapsed: 0:04:28.
#   Batch 4,520  of  9,275.    Elapsed: 0:04:30.
#   Batch 4,560  of  9,275.    Elapsed: 0:04:32.
#   Batch 4,600  of  9,275.    Elapsed: 0:04:35.
#   Batch 4,640  of  9,275.    Elapsed: 0:04:37.
#   Batch 4,680  of  9,275.    Elapsed: 0:04:40.
#   Batch 4,720  of  9,275.    Elapsed: 0:04:42.
#   Batch 4,760  of  9,275.    Elapsed: 0:04:44.
#   Batch 4,800  of  9,275.    Elapsed: 0:04:47.
#   Batch 4,840  of  9,275.    Elapsed: 0:04:49.
#   Batch 4,880  of  9,275.    Elapsed: 0:04:51.
#   Batch 4,920  of  9,275.    Elapsed: 0:04:54.
#   Batch 4,960  of  9,275.    Elapsed: 0:04:56.
#   Batch 5,000  of  9,275.    Elapsed: 0:04:59.
#   Batch 5,040  of  9,275.    Elapsed: 0:05:01.
#   Batch 5,080  of  9,275.    Elapsed: 0:05:03.
#   Batch 5,120  of  9,275.    Elapsed: 0:05:06.
#   Batch 5,160  of  9,275.    Elapsed: 0:05:08.
#   Batch 5,200  of  9,275.    Elapsed: 0:05:11.
#   Batch 5,240  of  9,275.    Elapsed: 0:05:13.
#   Batch 5,280  of  9,275.    Elapsed: 0:05:15.
#   Batch 5,320  of  9,275.    Elapsed: 0:05:18.
#   Batch 5,360  of  9,275.    Elapsed: 0:05:20.
#   Batch 5,400  of  9,275.    Elapsed: 0:05:23.
#   Batch 5,440  of  9,275.    Elapsed: 0:05:25.
#   Batch 5,480  of  9,275.    Elapsed: 0:05:27.
#   Batch 5,520  of  9,275.    Elapsed: 0:05:30.
#   Batch 5,560  of  9,275.    Elapsed: 0:05:32.
#   Batch 5,600  of  9,275.    Elapsed: 0:05:34.
#   Batch 5,640  of  9,275.    Elapsed: 0:05:37.
#   Batch 5,680  of  9,275.    Elapsed: 0:05:39.
#   Batch 5,720  of  9,275.    Elapsed: 0:05:42.
#   Batch 5,760  of  9,275.    Elapsed: 0:05:44.
#   Batch 5,800  of  9,275.    Elapsed: 0:05:46.
#   Batch 5,840  of  9,275.    Elapsed: 0:05:49.
#   Batch 5,880  of  9,275.    Elapsed: 0:05:51.
#   Batch 5,920  of  9,275.    Elapsed: 0:05:54.
#   Batch 5,960  of  9,275.    Elapsed: 0:05:56.
#   Batch 6,000  of  9,275.    Elapsed: 0:05:58.
#   Batch 6,040  of  9,275.    Elapsed: 0:06:01.
#   Batch 6,080  of  9,275.    Elapsed: 0:06:03.
#   Batch 6,120  of  9,275.    Elapsed: 0:06:06.
#   Batch 6,160  of  9,275.    Elapsed: 0:06:08.
#   Batch 6,200  of  9,275.    Elapsed: 0:06:10.
#   Batch 6,240  of  9,275.    Elapsed: 0:06:13.
#   Batch 6,280  of  9,275.    Elapsed: 0:06:15.
#   Batch 6,320  of  9,275.    Elapsed: 0:06:18.
#   Batch 6,360  of  9,275.    Elapsed: 0:06:20.
#   Batch 6,400  of  9,275.    Elapsed: 0:06:22.
#   Batch 6,440  of  9,275.    Elapsed: 0:06:25.
#   Batch 6,480  of  9,275.    Elapsed: 0:06:27.
#   Batch 6,520  of  9,275.    Elapsed: 0:06:29.
#   Batch 6,560  of  9,275.    Elapsed: 0:06:32.
#   Batch 6,600  of  9,275.    Elapsed: 0:06:34.
#   Batch 6,640  of  9,275.    Elapsed: 0:06:37.
#   Batch 6,680  of  9,275.    Elapsed: 0:06:39.
#   Batch 6,720  of  9,275.    Elapsed: 0:06:41.
#   Batch 6,760  of  9,275.    Elapsed: 0:06:44.
#   Batch 6,800  of  9,275.    Elapsed: 0:06:46.
#   Batch 6,840  of  9,275.    Elapsed: 0:06:49.
#   Batch 6,880  of  9,275.    Elapsed: 0:06:51.
#   Batch 6,920  of  9,275.    Elapsed: 0:06:53.
#   Batch 6,960  of  9,275.    Elapsed: 0:06:56.
#   Batch 7,000  of  9,275.    Elapsed: 0:06:58.
#   Batch 7,040  of  9,275.    Elapsed: 0:07:01.
#   Batch 7,080  of  9,275.    Elapsed: 0:07:03.
#   Batch 7,120  of  9,275.    Elapsed: 0:07:05.
#   Batch 7,160  of  9,275.    Elapsed: 0:07:08.
#   Batch 7,200  of  9,275.    Elapsed: 0:07:10.
#   Batch 7,240  of  9,275.    Elapsed: 0:07:12.
#   Batch 7,280  of  9,275.    Elapsed: 0:07:15.
#   Batch 7,320  of  9,275.    Elapsed: 0:07:17.
#   Batch 7,360  of  9,275.    Elapsed: 0:07:20.
#   Batch 7,400  of  9,275.    Elapsed: 0:07:22.
#   Batch 7,440  of  9,275.    Elapsed: 0:07:24.
#   Batch 7,480  of  9,275.    Elapsed: 0:07:27.
#   Batch 7,520  of  9,275.    Elapsed: 0:07:29.
#   Batch 7,560  of  9,275.    Elapsed: 0:07:32.
#   Batch 7,600  of  9,275.    Elapsed: 0:07:34.
#   Batch 7,640  of  9,275.    Elapsed: 0:07:36.
#   Batch 7,680  of  9,275.    Elapsed: 0:07:39.
#   Batch 7,720  of  9,275.    Elapsed: 0:07:41.
#   Batch 7,760  of  9,275.    Elapsed: 0:07:44.
#   Batch 7,800  of  9,275.    Elapsed: 0:07:46.
#   Batch 7,840  of  9,275.    Elapsed: 0:07:48.
#   Batch 7,880  of  9,275.    Elapsed: 0:07:51.
#   Batch 7,920  of  9,275.    Elapsed: 0:07:53.
#   Batch 7,960  of  9,275.    Elapsed: 0:07:56.
#   Batch 8,000  of  9,275.    Elapsed: 0:07:58.
#   Batch 8,040  of  9,275.    Elapsed: 0:08:00.
#   Batch 8,080  of  9,275.    Elapsed: 0:08:03.
#   Batch 8,120  of  9,275.    Elapsed: 0:08:05.
#   Batch 8,160  of  9,275.    Elapsed: 0:08:07.
#   Batch 8,200  of  9,275.    Elapsed: 0:08:10.
#   Batch 8,240  of  9,275.    Elapsed: 0:08:12.
#   Batch 8,280  of  9,275.    Elapsed: 0:08:15.
#   Batch 8,320  of  9,275.    Elapsed: 0:08:17.
#   Batch 8,360  of  9,275.    Elapsed: 0:08:19.
#   Batch 8,400  of  9,275.    Elapsed: 0:08:22.
#   Batch 8,440  of  9,275.    Elapsed: 0:08:24.
#   Batch 8,480  of  9,275.    Elapsed: 0:08:27.
#   Batch 8,520  of  9,275.    Elapsed: 0:08:29.
#   Batch 8,560  of  9,275.    Elapsed: 0:08:31.
#   Batch 8,600  of  9,275.    Elapsed: 0:08:34.
#   Batch 8,640  of  9,275.    Elapsed: 0:08:36.
#   Batch 8,680  of  9,275.    Elapsed: 0:08:39.
#   Batch 8,720  of  9,275.    Elapsed: 0:08:41.
#   Batch 8,760  of  9,275.    Elapsed: 0:08:43.
#   Batch 8,800  of  9,275.    Elapsed: 0:08:46.
#   Batch 8,840  of  9,275.    Elapsed: 0:08:48.
#   Batch 8,880  of  9,275.    Elapsed: 0:08:50.
#   Batch 8,920  of  9,275.    Elapsed: 0:08:53.
#   Batch 8,960  of  9,275.    Elapsed: 0:08:55.
#   Batch 9,000  of  9,275.    Elapsed: 0:08:58.
#   Batch 9,040  of  9,275.    Elapsed: 0:09:00.
#   Batch 9,080  of  9,275.    Elapsed: 0:09:02.
#   Batch 9,120  of  9,275.    Elapsed: 0:09:05.
#   Batch 9,160  of  9,275.    Elapsed: 0:09:07.
#   Batch 9,200  of  9,275.    Elapsed: 0:09:10.
#   Batch 9,240  of  9,275.    Elapsed: 0:09:12.
#
#   Average training loss: 0.40
#   Average training accuracy: 0.82
#   Training epcoh took: 0:09:14
#
# Running Validation...
#   Accuracy: 0.84
#   Validation Loss: 0.37
#   Validation took: 0:00:41
#
# ======== Epoch 2 / 2 ========
# Training...
#   Batch    40  of  9,275.    Elapsed: 0:00:02.
#   Batch    80  of  9,275.    Elapsed: 0:00:05.
#   Batch   120  of  9,275.    Elapsed: 0:00:07.
#   Batch   160  of  9,275.    Elapsed: 0:00:10.
#   Batch   200  of  9,275.    Elapsed: 0:00:12.
#   Batch   240  of  9,275.    Elapsed: 0:00:14.
#   Batch   280  of  9,275.    Elapsed: 0:00:17.
#   Batch   320  of  9,275.    Elapsed: 0:00:19.
#   Batch   360  of  9,275.    Elapsed: 0:00:21.
#   Batch   400  of  9,275.    Elapsed: 0:00:24.
#   Batch   440  of  9,275.    Elapsed: 0:00:26.
#   Batch   480  of  9,275.    Elapsed: 0:00:29.
#   Batch   520  of  9,275.    Elapsed: 0:00:31.
#   Batch   560  of  9,275.    Elapsed: 0:00:33.
#   Batch   600  of  9,275.    Elapsed: 0:00:36.
#   Batch   640  of  9,275.    Elapsed: 0:00:38.
#   Batch   680  of  9,275.    Elapsed: 0:00:41.
#   Batch   720  of  9,275.    Elapsed: 0:00:43.
#   Batch   760  of  9,275.    Elapsed: 0:00:45.
#   Batch   800  of  9,275.    Elapsed: 0:00:48.
#   Batch   840  of  9,275.    Elapsed: 0:00:50.
#   Batch   880  of  9,275.    Elapsed: 0:00:53.
#   Batch   920  of  9,275.    Elapsed: 0:00:55.
#   Batch   960  of  9,275.    Elapsed: 0:00:57.
#   Batch 1,000  of  9,275.    Elapsed: 0:01:00.
#   Batch 1,040  of  9,275.    Elapsed: 0:01:02.
#   Batch 1,080  of  9,275.    Elapsed: 0:01:04.
#   Batch 1,120  of  9,275.    Elapsed: 0:01:07.
#   Batch 1,160  of  9,275.    Elapsed: 0:01:09.
#   Batch 1,200  of  9,275.    Elapsed: 0:01:12.
#   Batch 1,240  of  9,275.    Elapsed: 0:01:14.
#   Batch 1,280  of  9,275.    Elapsed: 0:01:16.
#   Batch 1,320  of  9,275.    Elapsed: 0:01:19.
#   Batch 1,360  of  9,275.    Elapsed: 0:01:21.
#   Batch 1,400  of  9,275.    Elapsed: 0:01:24.
#   Batch 1,440  of  9,275.    Elapsed: 0:01:26.
#   Batch 1,480  of  9,275.    Elapsed: 0:01:28.
#   Batch 1,520  of  9,275.    Elapsed: 0:01:31.
#   Batch 1,560  of  9,275.    Elapsed: 0:01:33.
#   Batch 1,600  of  9,275.    Elapsed: 0:01:36.
#   Batch 1,640  of  9,275.    Elapsed: 0:01:38.
#   Batch 1,680  of  9,275.    Elapsed: 0:01:40.
#   Batch 1,720  of  9,275.    Elapsed: 0:01:43.
#   Batch 1,760  of  9,275.    Elapsed: 0:01:45.
#   Batch 1,800  of  9,275.    Elapsed: 0:01:48.
#   Batch 1,840  of  9,275.    Elapsed: 0:01:50.
#   Batch 1,880  of  9,275.    Elapsed: 0:01:52.
#   Batch 1,920  of  9,275.    Elapsed: 0:01:55.
#   Batch 1,960  of  9,275.    Elapsed: 0:01:57.
#   Batch 2,000  of  9,275.    Elapsed: 0:01:59.
#   Batch 2,040  of  9,275.    Elapsed: 0:02:02.
#   Batch 2,080  of  9,275.    Elapsed: 0:02:04.
#   Batch 2,120  of  9,275.    Elapsed: 0:02:07.
#   Batch 2,160  of  9,275.    Elapsed: 0:02:09.
#   Batch 2,200  of  9,275.    Elapsed: 0:02:11.
#   Batch 2,240  of  9,275.    Elapsed: 0:02:14.
#   Batch 2,280  of  9,275.    Elapsed: 0:02:16.
#   Batch 2,320  of  9,275.    Elapsed: 0:02:19.
#   Batch 2,360  of  9,275.    Elapsed: 0:02:21.
#   Batch 2,400  of  9,275.    Elapsed: 0:02:23.
#   Batch 2,440  of  9,275.    Elapsed: 0:02:26.
#   Batch 2,480  of  9,275.    Elapsed: 0:02:28.
#   Batch 2,520  of  9,275.    Elapsed: 0:02:30.
#   Batch 2,560  of  9,275.    Elapsed: 0:02:33.
#   Batch 2,600  of  9,275.    Elapsed: 0:02:35.
#   Batch 2,640  of  9,275.    Elapsed: 0:02:38.
#   Batch 2,680  of  9,275.    Elapsed: 0:02:40.
#   Batch 2,720  of  9,275.    Elapsed: 0:02:42.
#   Batch 2,760  of  9,275.    Elapsed: 0:02:45.
#   Batch 2,800  of  9,275.    Elapsed: 0:02:47.
#   Batch 2,840  of  9,275.    Elapsed: 0:02:50.
#   Batch 2,880  of  9,275.    Elapsed: 0:02:52.
#   Batch 2,920  of  9,275.    Elapsed: 0:02:54.
#   Batch 2,960  of  9,275.    Elapsed: 0:02:57.
#   Batch 3,000  of  9,275.    Elapsed: 0:02:59.
#   Batch 3,040  of  9,275.    Elapsed: 0:03:02.
#   Batch 3,080  of  9,275.    Elapsed: 0:03:04.
#   Batch 3,120  of  9,275.    Elapsed: 0:03:06.
#   Batch 3,160  of  9,275.    Elapsed: 0:03:09.
#   Batch 3,200  of  9,275.    Elapsed: 0:03:11.
#   Batch 3,240  of  9,275.    Elapsed: 0:03:13.
#   Batch 3,280  of  9,275.    Elapsed: 0:03:16.
#   Batch 3,320  of  9,275.    Elapsed: 0:03:18.
#   Batch 3,360  of  9,275.    Elapsed: 0:03:21.
#   Batch 3,400  of  9,275.    Elapsed: 0:03:23.
#   Batch 3,440  of  9,275.    Elapsed: 0:03:25.
#   Batch 3,480  of  9,275.    Elapsed: 0:03:28.
#   Batch 3,520  of  9,275.    Elapsed: 0:03:30.
#   Batch 3,560  of  9,275.    Elapsed: 0:03:33.
#   Batch 3,600  of  9,275.    Elapsed: 0:03:35.
#   Batch 3,640  of  9,275.    Elapsed: 0:03:37.
#   Batch 3,680  of  9,275.    Elapsed: 0:03:40.
#   Batch 3,720  of  9,275.    Elapsed: 0:03:42.
#   Batch 3,760  of  9,275.    Elapsed: 0:03:45.
#   Batch 3,800  of  9,275.    Elapsed: 0:03:47.
#   Batch 3,840  of  9,275.    Elapsed: 0:03:49.
#   Batch 3,880  of  9,275.    Elapsed: 0:03:52.
#   Batch 3,920  of  9,275.    Elapsed: 0:03:54.
#   Batch 3,960  of  9,275.    Elapsed: 0:03:56.
#   Batch 4,000  of  9,275.    Elapsed: 0:03:59.
#   Batch 4,040  of  9,275.    Elapsed: 0:04:01.
#   Batch 4,080  of  9,275.    Elapsed: 0:04:04.
#   Batch 4,120  of  9,275.    Elapsed: 0:04:06.
#   Batch 4,160  of  9,275.    Elapsed: 0:04:08.
#   Batch 4,200  of  9,275.    Elapsed: 0:04:11.
#   Batch 4,240  of  9,275.    Elapsed: 0:04:13.
#   Batch 4,280  of  9,275.    Elapsed: 0:04:16.
#   Batch 4,320  of  9,275.    Elapsed: 0:04:18.
#   Batch 4,360  of  9,275.    Elapsed: 0:04:20.
#   Batch 4,400  of  9,275.    Elapsed: 0:04:23.
#   Batch 4,440  of  9,275.    Elapsed: 0:04:25.
#   Batch 4,480  of  9,275.    Elapsed: 0:04:28.
#   Batch 4,520  of  9,275.    Elapsed: 0:04:30.
#   Batch 4,560  of  9,275.    Elapsed: 0:04:32.
#   Batch 4,600  of  9,275.    Elapsed: 0:04:35.
#   Batch 4,640  of  9,275.    Elapsed: 0:04:37.
#   Batch 4,680  of  9,275.    Elapsed: 0:04:40.
#   Batch 4,720  of  9,275.    Elapsed: 0:04:42.
#   Batch 4,760  of  9,275.    Elapsed: 0:04:44.
#   Batch 4,800  of  9,275.    Elapsed: 0:04:47.
#   Batch 4,840  of  9,275.    Elapsed: 0:04:49.
#   Batch 4,880  of  9,275.    Elapsed: 0:04:51.
#   Batch 4,920  of  9,275.    Elapsed: 0:04:54.
#   Batch 4,960  of  9,275.    Elapsed: 0:04:56.
#   Batch 5,000  of  9,275.    Elapsed: 0:04:59.
#   Batch 5,040  of  9,275.    Elapsed: 0:05:01.
#   Batch 5,080  of  9,275.    Elapsed: 0:05:03.
#   Batch 5,120  of  9,275.    Elapsed: 0:05:06.
#   Batch 5,160  of  9,275.    Elapsed: 0:05:08.
#   Batch 5,200  of  9,275.    Elapsed: 0:05:11.
#   Batch 5,240  of  9,275.    Elapsed: 0:05:13.
#   Batch 5,280  of  9,275.    Elapsed: 0:05:15.
#   Batch 5,320  of  9,275.    Elapsed: 0:05:18.
#   Batch 5,360  of  9,275.    Elapsed: 0:05:20.
#   Batch 5,400  of  9,275.    Elapsed: 0:05:23.
#   Batch 5,440  of  9,275.    Elapsed: 0:05:25.
#   Batch 5,480  of  9,275.    Elapsed: 0:05:27.
#   Batch 5,520  of  9,275.    Elapsed: 0:05:30.
#   Batch 5,560  of  9,275.    Elapsed: 0:05:32.
#   Batch 5,600  of  9,275.    Elapsed: 0:05:34.
#   Batch 5,640  of  9,275.    Elapsed: 0:05:37.
#   Batch 5,680  of  9,275.    Elapsed: 0:05:39.
#   Batch 5,720  of  9,275.    Elapsed: 0:05:42.
#   Batch 5,760  of  9,275.    Elapsed: 0:05:44.
#   Batch 5,800  of  9,275.    Elapsed: 0:05:46.
#   Batch 5,840  of  9,275.    Elapsed: 0:05:49.
#   Batch 5,880  of  9,275.    Elapsed: 0:05:51.
#   Batch 5,920  of  9,275.    Elapsed: 0:05:54.
#   Batch 5,960  of  9,275.    Elapsed: 0:05:56.
#   Batch 6,000  of  9,275.    Elapsed: 0:05:58.
#   Batch 6,040  of  9,275.    Elapsed: 0:06:01.
#   Batch 6,080  of  9,275.    Elapsed: 0:06:03.
#   Batch 6,120  of  9,275.    Elapsed: 0:06:06.
#   Batch 6,160  of  9,275.    Elapsed: 0:06:08.
#   Batch 6,200  of  9,275.    Elapsed: 0:06:10.
#   Batch 6,240  of  9,275.    Elapsed: 0:06:13.
#   Batch 6,280  of  9,275.    Elapsed: 0:06:15.
#   Batch 6,320  of  9,275.    Elapsed: 0:06:17.
#   Batch 6,360  of  9,275.    Elapsed: 0:06:20.
#   Batch 6,400  of  9,275.    Elapsed: 0:06:22.
#   Batch 6,440  of  9,275.    Elapsed: 0:06:25.
#   Batch 6,480  of  9,275.    Elapsed: 0:06:27.
#   Batch 6,520  of  9,275.    Elapsed: 0:06:29.
#   Batch 6,560  of  9,275.    Elapsed: 0:06:32.
#   Batch 6,600  of  9,275.    Elapsed: 0:06:34.
#   Batch 6,640  of  9,275.    Elapsed: 0:06:37.
#   Batch 6,680  of  9,275.    Elapsed: 0:06:39.
#   Batch 6,720  of  9,275.    Elapsed: 0:06:41.
#   Batch 6,760  of  9,275.    Elapsed: 0:06:44.
#   Batch 6,800  of  9,275.    Elapsed: 0:06:46.
#   Batch 6,840  of  9,275.    Elapsed: 0:06:49.
#   Batch 6,880  of  9,275.    Elapsed: 0:06:51.
#   Batch 6,920  of  9,275.    Elapsed: 0:06:53.
#   Batch 6,960  of  9,275.    Elapsed: 0:06:56.
#   Batch 7,000  of  9,275.    Elapsed: 0:06:58.
#   Batch 7,040  of  9,275.    Elapsed: 0:07:01.
#   Batch 7,080  of  9,275.    Elapsed: 0:07:03.
#   Batch 7,120  of  9,275.    Elapsed: 0:07:05.
#   Batch 7,160  of  9,275.    Elapsed: 0:07:08.
#   Batch 7,200  of  9,275.    Elapsed: 0:07:10.
#   Batch 7,240  of  9,275.    Elapsed: 0:07:12.
#   Batch 7,280  of  9,275.    Elapsed: 0:07:15.
#   Batch 7,320  of  9,275.    Elapsed: 0:07:17.
#   Batch 7,360  of  9,275.    Elapsed: 0:07:20.
#   Batch 7,400  of  9,275.    Elapsed: 0:07:22.
#   Batch 7,440  of  9,275.    Elapsed: 0:07:24.
#   Batch 7,480  of  9,275.    Elapsed: 0:07:27.
#   Batch 7,520  of  9,275.    Elapsed: 0:07:29.
#   Batch 7,560  of  9,275.    Elapsed: 0:07:32.
#   Batch 7,600  of  9,275.    Elapsed: 0:07:34.
#   Batch 7,640  of  9,275.    Elapsed: 0:07:36.
#   Batch 7,680  of  9,275.    Elapsed: 0:07:39.
#   Batch 7,720  of  9,275.    Elapsed: 0:07:41.
#   Batch 7,760  of  9,275.    Elapsed: 0:07:44.
#   Batch 7,800  of  9,275.    Elapsed: 0:07:46.
#   Batch 7,840  of  9,275.    Elapsed: 0:07:48.
#   Batch 7,880  of  9,275.    Elapsed: 0:07:51.
#   Batch 7,920  of  9,275.    Elapsed: 0:07:53.
#   Batch 7,960  of  9,275.    Elapsed: 0:07:55.
#   Batch 8,000  of  9,275.    Elapsed: 0:07:58.
#   Batch 8,040  of  9,275.    Elapsed: 0:08:00.
#   Batch 8,080  of  9,275.    Elapsed: 0:08:03.
#   Batch 8,120  of  9,275.    Elapsed: 0:08:05.
#   Batch 8,160  of  9,275.    Elapsed: 0:08:07.
#   Batch 8,200  of  9,275.    Elapsed: 0:08:10.
#   Batch 8,240  of  9,275.    Elapsed: 0:08:12.
#   Batch 8,280  of  9,275.    Elapsed: 0:08:15.
#   Batch 8,320  of  9,275.    Elapsed: 0:08:17.
#   Batch 8,360  of  9,275.    Elapsed: 0:08:19.
#   Batch 8,400  of  9,275.    Elapsed: 0:08:22.
#   Batch 8,440  of  9,275.    Elapsed: 0:08:24.
#   Batch 8,480  of  9,275.    Elapsed: 0:08:27.
#   Batch 8,520  of  9,275.    Elapsed: 0:08:29.
#   Batch 8,560  of  9,275.    Elapsed: 0:08:31.
#   Batch 8,600  of  9,275.    Elapsed: 0:08:34.
#   Batch 8,640  of  9,275.    Elapsed: 0:08:36.
#   Batch 8,680  of  9,275.    Elapsed: 0:08:38.
#   Batch 8,720  of  9,275.    Elapsed: 0:08:41.
#   Batch 8,760  of  9,275.    Elapsed: 0:08:43.
#   Batch 8,800  of  9,275.    Elapsed: 0:08:46.
#   Batch 8,840  of  9,275.    Elapsed: 0:08:48.
#   Batch 8,880  of  9,275.    Elapsed: 0:08:50.
#   Batch 8,920  of  9,275.    Elapsed: 0:08:53.
#   Batch 8,960  of  9,275.    Elapsed: 0:08:55.
#   Batch 9,000  of  9,275.    Elapsed: 0:08:58.
#   Batch 9,040  of  9,275.    Elapsed: 0:09:00.
#   Batch 9,080  of  9,275.    Elapsed: 0:09:02.
#   Batch 9,120  of  9,275.    Elapsed: 0:09:05.
#   Batch 9,160  of  9,275.    Elapsed: 0:09:07.
#   Batch 9,200  of  9,275.    Elapsed: 0:09:10.
# ...
#   Batch 5,680  of  9,275.    Elapsed: 0:05:38.
#   Batch 5,720  of  9,275.    Elapsed: 0:05:41.
#   Batch 5,760  of  9,275.    Elapsed: 0:05:43.
#   Batch 5,800  of  9,275.    Elapsed: 0:05:46.
#   Batch 5,840  of  9,275.    Elapsed: 0:05:48.
#   Batch 5,880  of  9,275.    Elapsed: 0:05:50.
#   Batch 5,920  of  9,275.    Elapsed: 0:05:53.
#   Batch 5,960  of  9,275.    Elapsed: 0:05:55.
#   Batch 6,000  of  9,275.    Elapsed: 0:05:58.
#   Batch 6,040  of  9,275.    Elapsed: 0:06:00.
#   Batch 6,080  of  9,275.    Elapsed: 0:06:02.
#   Batch 6,120  of  9,275.    Elapsed: 0:06:05.
#   Batch 6,160  of  9,275.    Elapsed: 0:06:07.
#   Batch 6,200  of  9,275.    Elapsed: 0:06:09.
#   Batch 6,240  of  9,275.    Elapsed: 0:06:12.
#   Batch 6,280  of  9,275.    Elapsed: 0:06:14.
#   Batch 6,320  of  9,275.    Elapsed: 0:06:17.
#   Batch 6,360  of  9,275.    Elapsed: 0:06:19.
#   Batch 6,400  of  9,275.    Elapsed: 0:06:21.
#   Batch 6,440  of  9,275.    Elapsed: 0:06:24.
#   Batch 6,480  of  9,275.    Elapsed: 0:06:26.
#   Batch 6,520  of  9,275.    Elapsed: 0:06:29.
#   Batch 6,560  of  9,275.    Elapsed: 0:06:31.
#   Batch 6,600  of  9,275.    Elapsed: 0:06:33.
#   Batch 6,640  of  9,275.    Elapsed: 0:06:36.
#   Batch 6,680  of  9,275.    Elapsed: 0:06:38.
#   Batch 6,720  of  9,275.    Elapsed: 0:06:40.
#   Batch 6,760  of  9,275.    Elapsed: 0:06:43.
#   Batch 6,800  of  9,275.    Elapsed: 0:06:45.
#   Batch 6,840  of  9,275.    Elapsed: 0:06:48.
#   Batch 6,880  of  9,275.    Elapsed: 0:06:50.
#   Batch 6,920  of  9,275.    Elapsed: 0:06:52.
#   Batch 6,960  of  9,275.    Elapsed: 0:06:55.
#   Batch 7,000  of  9,275.    Elapsed: 0:06:57.
#   Batch 7,040  of  9,275.    Elapsed: 0:06:59.
#   Batch 7,080  of  9,275.    Elapsed: 0:07:02.
#   Batch 7,120  of  9,275.    Elapsed: 0:07:04.
#   Batch 7,160  of  9,275.    Elapsed: 0:07:07.
#   Batch 7,200  of  9,275.    Elapsed: 0:07:09.
#   Batch 7,240  of  9,275.    Elapsed: 0:07:11.
#   Batch 7,280  of  9,275.    Elapsed: 0:07:14.
#   Batch 7,320  of  9,275.    Elapsed: 0:07:16.
#   Batch 7,360  of  9,275.    Elapsed: 0:07:19.
#   Batch 7,400  of  9,275.    Elapsed: 0:07:21.
#   Batch 7,440  of  9,275.    Elapsed: 0:07:23.
#   Batch 7,480  of  9,275.    Elapsed: 0:07:26.
#   Batch 7,520  of  9,275.    Elapsed: 0:07:28.
#   Batch 7,560  of  9,275.    Elapsed: 0:07:30.
#   Batch 7,600  of  9,275.    Elapsed: 0:07:33.
#   Batch 7,640  of  9,275.    Elapsed: 0:07:35.
#   Batch 7,680  of  9,275.    Elapsed: 0:07:38.
#   Batch 7,720  of  9,275.    Elapsed: 0:07:40.
#   Batch 7,760  of  9,275.    Elapsed: 0:07:42.
#   Batch 7,800  of  9,275.    Elapsed: 0:07:45.
#   Batch 7,840  of  9,275.    Elapsed: 0:07:47.
#   Batch 7,880  of  9,275.    Elapsed: 0:07:49.
#   Batch 7,920  of  9,275.    Elapsed: 0:07:52.
#   Batch 7,960  of  9,275.    Elapsed: 0:07:54.
#   Batch 8,000  of  9,275.    Elapsed: 0:07:57.
#   Batch 8,040  of  9,275.    Elapsed: 0:07:59.
#   Batch 8,080  of  9,275.    Elapsed: 0:08:01.
#   Batch 8,120  of  9,275.    Elapsed: 0:08:04.
#   Batch 8,160  of  9,275.    Elapsed: 0:08:06.
#   Batch 8,200  of  9,275.    Elapsed: 0:08:09.
#   Batch 8,240  of  9,275.    Elapsed: 0:08:11.
#   Batch 8,280  of  9,275.    Elapsed: 0:08:13.
#   Batch 8,320  of  9,275.    Elapsed: 0:08:16.
#   Batch 8,360  of  9,275.    Elapsed: 0:08:18.
#   Batch 8,400  of  9,275.    Elapsed: 0:08:20.
#   Batch 8,440  of  9,275.    Elapsed: 0:08:23.
#   Batch 8,480  of  9,275.    Elapsed: 0:08:25.
#   Batch 8,520  of  9,275.    Elapsed: 0:08:28.
#   Batch 8,560  of  9,275.    Elapsed: 0:08:30.
#   Batch 8,600  of  9,275.    Elapsed: 0:08:32.
#   Batch 8,640  of  9,275.    Elapsed: 0:08:35.
#   Batch 8,680  of  9,275.    Elapsed: 0:08:37.
#   Batch 8,720  of  9,275.    Elapsed: 0:08:39.
#   Batch 8,760  of  9,275.    Elapsed: 0:08:42.
#   Batch 8,800  of  9,275.    Elapsed: 0:08:44.
#   Batch 8,840  of  9,275.    Elapsed: 0:08:47.
#   Batch 8,880  of  9,275.    Elapsed: 0:08:49.
#   Batch 8,920  of  9,275.    Elapsed: 0:08:51.
#   Batch 8,960  of  9,275.    Elapsed: 0:08:54.
#   Batch 9,000  of  9,275.    Elapsed: 0:08:56.
#   Batch 9,040  of  9,275.    Elapsed: 0:08:59.
#   Batch 9,080  of  9,275.    Elapsed: 0:09:01.
#   Batch 9,120  of  9,275.    Elapsed: 0:09:03.
#   Batch 9,160  of  9,275.    Elapsed: 0:09:06.
#   Batch 9,200  of  9,275.    Elapsed: 0:09:08.
#   Batch 9,240  of  9,275.    Elapsed: 0:09:10.
#
#   Average training loss: 0.41
#   Average training accuracy: 0.81
#   Training epcoh took: 0:09:13
#
# Running Validation...
#   Accuracy: 0.84
#   Validation Loss: 0.36
#   Validation took: 0:00:41
#
# ======== Epoch 2 / 2 ========
# Training...
#   Batch    40  of  9,275.    Elapsed: 0:00:02.
#   Batch    80  of  9,275.    Elapsed: 0:00:05.
#   Batch   120  of  9,275.    Elapsed: 0:00:07.
#   Batch   160  of  9,275.    Elapsed: 0:00:09.
#   Batch   200  of  9,275.    Elapsed: 0:00:12.
#   Batch   240  of  9,275.    Elapsed: 0:00:14.
#   Batch   280  of  9,275.    Elapsed: 0:00:17.
#   Batch   320  of  9,275.    Elapsed: 0:00:19.
#   Batch   360  of  9,275.    Elapsed: 0:00:21.
#   Batch   400  of  9,275.    Elapsed: 0:00:24.
#   Batch   440  of  9,275.    Elapsed: 0:00:26.
#   Batch   480  of  9,275.    Elapsed: 0:00:29.
#   Batch   520  of  9,275.    Elapsed: 0:00:31.
#   Batch   560  of  9,275.    Elapsed: 0:00:33.
#   Batch   600  of  9,275.    Elapsed: 0:00:36.
#   Batch   640  of  9,275.    Elapsed: 0:00:38.
#   Batch   680  of  9,275.    Elapsed: 0:00:40.
#   Batch   720  of  9,275.    Elapsed: 0:00:43.
#   Batch   760  of  9,275.    Elapsed: 0:00:45.
#   Batch   800  of  9,275.    Elapsed: 0:00:48.
#   Batch   840  of  9,275.    Elapsed: 0:00:50.
#   Batch   880  of  9,275.    Elapsed: 0:00:52.
#   Batch   920  of  9,275.    Elapsed: 0:00:55.
#   Batch   960  of  9,275.    Elapsed: 0:00:57.
#   Batch 1,000  of  9,275.    Elapsed: 0:01:00.
#   Batch 1,040  of  9,275.    Elapsed: 0:01:02.
#   Batch 1,080  of  9,275.    Elapsed: 0:01:04.
#   Batch 1,120  of  9,275.    Elapsed: 0:01:07.
#   Batch 1,160  of  9,275.    Elapsed: 0:01:09.
#   Batch 1,200  of  9,275.    Elapsed: 0:01:11.
#   Batch 1,240  of  9,275.    Elapsed: 0:01:14.
#   Batch 1,280  of  9,275.    Elapsed: 0:01:16.
#   Batch 1,320  of  9,275.    Elapsed: 0:01:19.
#   Batch 1,360  of  9,275.    Elapsed: 0:01:21.
#   Batch 1,400  of  9,275.    Elapsed: 0:01:23.
#   Batch 1,440  of  9,275.    Elapsed: 0:01:26.
#   Batch 1,480  of  9,275.    Elapsed: 0:01:28.
#   Batch 1,520  of  9,275.    Elapsed: 0:01:30.
#   Batch 1,560  of  9,275.    Elapsed: 0:01:33.
#   Batch 1,600  of  9,275.    Elapsed: 0:01:35.
#   Batch 1,640  of  9,275.    Elapsed: 0:01:38.
#   Batch 1,680  of  9,275.    Elapsed: 0:01:40.
#   Batch 1,720  of  9,275.    Elapsed: 0:01:42.
#   Batch 1,760  of  9,275.    Elapsed: 0:01:45.
#   Batch 1,800  of  9,275.    Elapsed: 0:01:47.
#   Batch 1,840  of  9,275.    Elapsed: 0:01:50.
#   Batch 1,880  of  9,275.    Elapsed: 0:01:52.
#   Batch 1,920  of  9,275.    Elapsed: 0:01:54.
#   Batch 1,960  of  9,275.    Elapsed: 0:01:57.
#   Batch 2,000  of  9,275.    Elapsed: 0:01:59.
#   Batch 2,040  of  9,275.    Elapsed: 0:02:01.
#   Batch 2,080  of  9,275.    Elapsed: 0:02:04.
#   Batch 2,120  of  9,275.    Elapsed: 0:02:06.
#   Batch 2,160  of  9,275.    Elapsed: 0:02:09.
#   Batch 2,200  of  9,275.    Elapsed: 0:02:11.
#   Batch 2,240  of  9,275.    Elapsed: 0:02:13.
#   Batch 2,280  of  9,275.    Elapsed: 0:02:16.
#   Batch 2,320  of  9,275.    Elapsed: 0:02:18.
#   Batch 2,360  of  9,275.    Elapsed: 0:02:21.
#   Batch 2,400  of  9,275.    Elapsed: 0:02:23.
#   Batch 2,440  of  9,275.    Elapsed: 0:02:25.
#   Batch 2,480  of  9,275.    Elapsed: 0:02:28.
#   Batch 2,520  of  9,275.    Elapsed: 0:02:30.
#   Batch 2,560  of  9,275.    Elapsed: 0:02:32.
#   Batch 2,600  of  9,275.    Elapsed: 0:02:35.
#   Batch 2,640  of  9,275.    Elapsed: 0:02:37.
#   Batch 2,680  of  9,275.    Elapsed: 0:02:40.
#   Batch 2,720  of  9,275.    Elapsed: 0:02:42.
#   Batch 2,760  of  9,275.    Elapsed: 0:02:44.
#   Batch 2,800  of  9,275.    Elapsed: 0:02:47.
#   Batch 2,840  of  9,275.    Elapsed: 0:02:49.
#   Batch 2,880  of  9,275.    Elapsed: 0:02:51.
#   Batch 2,920  of  9,275.    Elapsed: 0:02:54.
#   Batch 2,960  of  9,275.    Elapsed: 0:02:56.
#   Batch 3,000  of  9,275.    Elapsed: 0:02:59.
#   Batch 3,040  of  9,275.    Elapsed: 0:03:01.
#   Batch 3,080  of  9,275.    Elapsed: 0:03:03.
#   Batch 3,120  of  9,275.    Elapsed: 0:03:06.
#   Batch 3,160  of  9,275.    Elapsed: 0:03:08.
#   Batch 3,200  of  9,275.    Elapsed: 0:03:11.
#   Batch 3,240  of  9,275.    Elapsed: 0:03:13.
#   Batch 3,280  of  9,275.    Elapsed: 0:03:15.
#   Batch 3,320  of  9,275.    Elapsed: 0:03:18.
#   Batch 3,360  of  9,275.    Elapsed: 0:03:20.
#   Batch 3,400  of  9,275.    Elapsed: 0:03:22.
#   Batch 3,440  of  9,275.    Elapsed: 0:03:25.
#   Batch 3,480  of  9,275.    Elapsed: 0:03:27.
#   Batch 3,520  of  9,275.    Elapsed: 0:03:30.
#   Batch 3,560  of  9,275.    Elapsed: 0:03:32.
#   Batch 3,600  of  9,275.    Elapsed: 0:03:34.
#   Batch 3,640  of  9,275.    Elapsed: 0:03:37.
#   Batch 3,680  of  9,275.    Elapsed: 0:03:39.
#   Batch 3,720  of  9,275.    Elapsed: 0:03:41.
#   Batch 3,760  of  9,275.    Elapsed: 0:03:44.
#   Batch 3,800  of  9,275.    Elapsed: 0:03:46.
#   Batch 3,840  of  9,275.    Elapsed: 0:03:49.
#   Batch 3,880  of  9,275.    Elapsed: 0:03:51.
#   Batch 3,920  of  9,275.    Elapsed: 0:03:53.
#   Batch 3,960  of  9,275.    Elapsed: 0:03:56.
#   Batch 4,000  of  9,275.    Elapsed: 0:03:58.
#   Batch 4,040  of  9,275.    Elapsed: 0:04:01.
#   Batch 4,080  of  9,275.    Elapsed: 0:04:03.
#   Batch 4,120  of  9,275.    Elapsed: 0:04:05.
#   Batch 4,160  of  9,275.    Elapsed: 0:04:08.
#   Batch 4,200  of  9,275.    Elapsed: 0:04:10.
#   Batch 4,240  of  9,275.    Elapsed: 0:04:12.
#   Batch 4,280  of  9,275.    Elapsed: 0:04:15.
#   Batch 4,320  of  9,275.    Elapsed: 0:04:17.
#   Batch 4,360  of  9,275.    Elapsed: 0:04:20.
#   Batch 4,400  of  9,275.    Elapsed: 0:04:22.
#   Batch 4,440  of  9,275.    Elapsed: 0:04:24.
#   Batch 4,480  of  9,275.    Elapsed: 0:04:27.
#   Batch 4,520  of  9,275.    Elapsed: 0:04:29.
#   Batch 4,560  of  9,275.    Elapsed: 0:04:31.
#   Batch 4,600  of  9,275.    Elapsed: 0:04:34.
#   Batch 4,640  of  9,275.    Elapsed: 0:04:36.
#   Batch 4,680  of  9,275.    Elapsed: 0:04:39.
#   Batch 4,720  of  9,275.    Elapsed: 0:04:41.
#   Batch 4,760  of  9,275.    Elapsed: 0:04:43.
#   Batch 4,800  of  9,275.    Elapsed: 0:04:46.
#   Batch 4,840  of  9,275.    Elapsed: 0:04:48.
#   Batch 4,880  of  9,275.    Elapsed: 0:04:51.
#   Batch 4,920  of  9,275.    Elapsed: 0:04:53.
#   Batch 4,960  of  9,275.    Elapsed: 0:04:55.
#   Batch 5,000  of  9,275.    Elapsed: 0:04:58.
#   Batch 5,040  of  9,275.    Elapsed: 0:05:00.
#   Batch 5,080  of  9,275.    Elapsed: 0:05:02.
#   Batch 5,120  of  9,275.    Elapsed: 0:05:05.
#   Batch 5,160  of  9,275.    Elapsed: 0:05:07.
#   Batch 5,200  of  9,275.    Elapsed: 0:05:10.
#   Batch 5,240  of  9,275.    Elapsed: 0:05:12.
#   Batch 5,280  of  9,275.    Elapsed: 0:05:14.
#   Batch 5,320  of  9,275.    Elapsed: 0:05:17.
#   Batch 5,360  of  9,275.    Elapsed: 0:05:19.
#   Batch 5,400  of  9,275.    Elapsed: 0:05:22.
#   Batch 5,440  of  9,275.    Elapsed: 0:05:24.
#   Batch 5,480  of  9,275.    Elapsed: 0:05:26.
#   Batch 5,520  of  9,275.    Elapsed: 0:05:29.
#   Batch 5,560  of  9,275.    Elapsed: 0:05:31.
#   Batch 5,600  of  9,275.    Elapsed: 0:05:33.
#   Batch 5,640  of  9,275.    Elapsed: 0:05:36.
#   Batch 5,680  of  9,275.    Elapsed: 0:05:38.
#   Batch 5,720  of  9,275.    Elapsed: 0:05:41.
#   Batch 5,760  of  9,275.    Elapsed: 0:05:43.
#   Batch 5,800  of  9,275.    Elapsed: 0:05:45.
#   Batch 5,840  of  9,275.    Elapsed: 0:05:48.
#   Batch 5,880  of  9,275.    Elapsed: 0:05:50.
#   Batch 5,920  of  9,275.    Elapsed: 0:05:52.
#   Batch 5,960  of  9,275.    Elapsed: 0:05:55.
#   Batch 6,000  of  9,275.    Elapsed: 0:05:57.
#   Batch 6,040  of  9,275.    Elapsed: 0:06:00.
#   Batch 6,080  of  9,275.    Elapsed: 0:06:02.
#   Batch 6,120  of  9,275.    Elapsed: 0:06:04.
#   Batch 6,160  of  9,275.    Elapsed: 0:06:07.
#   Batch 6,200  of  9,275.    Elapsed: 0:06:09.
#   Batch 6,240  of  9,275.    Elapsed: 0:06:12.
#   Batch 6,280  of  9,275.    Elapsed: 0:06:14.
#   Batch 6,320  of  9,275.    Elapsed: 0:06:16.
#   Batch 6,360  of  9,275.    Elapsed: 0:06:19.
#   Batch 6,400  of  9,275.    Elapsed: 0:06:21.
#   Batch 6,440  of  9,275.    Elapsed: 0:06:24.
#   Batch 6,480  of  9,275.    Elapsed: 0:06:26.
#   Batch 6,520  of  9,275.    Elapsed: 0:06:28.
#   Batch 6,560  of  9,275.    Elapsed: 0:06:31.
#   Batch 6,600  of  9,275.    Elapsed: 0:06:33.
#   Batch 6,640  of  9,275.    Elapsed: 0:06:35.
#   Batch 6,680  of  9,275.    Elapsed: 0:06:38.
#   Batch 6,720  of  9,275.    Elapsed: 0:06:40.
#   Batch 6,760  of  9,275.    Elapsed: 0:06:43.
#   Batch 6,800  of  9,275.    Elapsed: 0:06:45.
#   Batch 6,840  of  9,275.    Elapsed: 0:06:47.
#   Batch 6,880  of  9,275.    Elapsed: 0:06:50.
#   Batch 6,920  of  9,275.    Elapsed: 0:06:52.
#   Batch 6,960  of  9,275.    Elapsed: 0:06:55.
#   Batch 7,000  of  9,275.    Elapsed: 0:06:57.
#   Batch 7,040  of  9,275.    Elapsed: 0:06:59.
#   Batch 7,080  of  9,275.    Elapsed: 0:07:02.
#   Batch 7,120  of  9,275.    Elapsed: 0:07:04.
#   Batch 7,160  of  9,275.    Elapsed: 0:07:06.
#   Batch 7,200  of  9,275.    Elapsed: 0:07:09.
#   Batch 7,240  of  9,275.    Elapsed: 0:07:11.
#   Batch 7,280  of  9,275.    Elapsed: 0:07:14.
#   Batch 7,320  of  9,275.    Elapsed: 0:07:16.
#   Batch 7,360  of  9,275.    Elapsed: 0:07:18.
#   Batch 7,400  of  9,275.    Elapsed: 0:07:21.
#   Batch 7,440  of  9,275.    Elapsed: 0:07:23.
#   Batch 7,480  of  9,275.    Elapsed: 0:07:26.
#   Batch 7,520  of  9,275.    Elapsed: 0:07:28.
#   Batch 7,560  of  9,275.    Elapsed: 0:07:30.
#   Batch 7,600  of  9,275.    Elapsed: 0:07:33.
#   Batch 7,640  of  9,275.    Elapsed: 0:07:35.
#   Batch 7,680  of  9,275.    Elapsed: 0:07:37.
#   Batch 7,720  of  9,275.    Elapsed: 0:07:40.
#   Batch 7,760  of  9,275.    Elapsed: 0:07:42.
#   Batch 7,800  of  9,275.    Elapsed: 0:07:45.
#   Batch 7,840  of  9,275.    Elapsed: 0:07:47.
#   Batch 7,880  of  9,275.    Elapsed: 0:07:49.
#   Batch 7,920  of  9,275.    Elapsed: 0:07:52.
#   Batch 7,960  of  9,275.    Elapsed: 0:07:54.
#   Batch 8,000  of  9,275.    Elapsed: 0:07:57.
#   Batch 8,040  of  9,275.    Elapsed: 0:07:59.
#   Batch 8,080  of  9,275.    Elapsed: 0:08:01.
#   Batch 8,120  of  9,275.    Elapsed: 0:08:04.
#   Batch 8,160  of  9,275.    Elapsed: 0:08:06.
#   Batch 8,200  of  9,275.    Elapsed: 0:08:08.
#   Batch 8,240  of  9,275.    Elapsed: 0:08:11.
#   Batch 8,280  of  9,275.    Elapsed: 0:08:13.
#   Batch 8,320  of  9,275.    Elapsed: 0:08:16.
#   Batch 8,360  of  9,275.    Elapsed: 0:08:18.
#   Batch 8,400  of  9,275.    Elapsed: 0:08:20.
#   Batch 8,440  of  9,275.    Elapsed: 0:08:23.
#   Batch 8,480  of  9,275.    Elapsed: 0:08:25.
#   Batch 8,520  of  9,275.    Elapsed: 0:08:28.
#   Batch 8,560  of  9,275.    Elapsed: 0:08:30.
#   Batch 8,600  of  9,275.    Elapsed: 0:08:32.
#   Batch 8,640  of  9,275.    Elapsed: 0:08:35.
#   Batch 8,680  of  9,275.    Elapsed: 0:08:37.
#   Batch 8,720  of  9,275.    Elapsed: 0:08:39.
#   Batch 8,760  of  9,275.    Elapsed: 0:08:42.
#   Batch 8,800  of  9,275.    Elapsed: 0:08:44.
#   Batch 8,840  of  9,275.    Elapsed: 0:08:47.
#   Batch 8,880  of  9,275.    Elapsed: 0:08:49.
#   Batch 8,920  of  9,275.    Elapsed: 0:08:51.
#   Batch 8,960  of  9,275.    Elapsed: 0:08:54.
#   Batch 9,000  of  9,275.    Elapsed: 0:08:56.
#   Batch 9,040  of  9,275.    Elapsed: 0:08:59.
#   Batch 9,080  of  9,275.    Elapsed: 0:09:01.
#   Batch 9,120  of  9,275.    Elapsed: 0:09:03.
#   Batch 9,160  of  9,275.    Elapsed: 0:09:06.
#   Batch 9,200  of  9,275.    Elapsed: 0:09:08.
#   Batch 9,240  of  9,275.    Elapsed: 0:09:10.
#
#   Average training loss: 0.32
#   Average training accuracy: 0.86
#   Training epcoh took: 0:09:13
#
# Running Validation...
# [I 2025-06-01 22:00:03,343] Trial 9 finished with value: 0.8484512578616352 and parameters: {'learning_rate': 1.0806068800897613e-05, 'eps': 1.7912350859822853e-09, 'warmup_ratio': 0.080936885654388}. Best is trial 6 with value: 0.8495754716981132.
#   Accuracy: 0.85
#   Validation Loss: 0.36
#   Validation took: 0:00:41
#
# Training complete!
# Total training took 0:19:47 (h:mm:ss)
# Best trial:
#   Value: 0.8495754716981132
#   Params:
#     learning_rate: 3.449076943303823e-05
#     eps: 4.193728499250623e-09
#     warmup_ratio: 0.08668534259748178

# %%
# prompt: retrain model with best parameters


best_params = study.best_trial.params


final_epochs = 2


best_model = get_model(resize_embeddings=True, device=device)
best_model.train()

# Define optimizer and scheduler with the best hyperparameters
best_optimizer = AdamW(best_model.parameters(), lr=best_params['learning_rate'], eps=best_params['eps'])

total_steps = len(best_train_dataloader) * final_epochs
warmup_steps = int(total_steps * best_params['warmup_ratio'])

best_scheduler = get_linear_schedule_with_warmup(best_optimizer, num_warmup_steps=warmup_steps, num_training_steps=total_steps)

results4 = train_and_validate(best_model, best_train_dataloader, best_val_dataloader, best_optimizer, best_scheduler, device, epochs=final_epochs)
y_true4, y_pred4, y_proba4 = extract_metrics(best_model, best_val_dataloader, device)
print(classification_report(y_true4, y_pred4))
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ======== Epoch 1 / 2 ========
# Training...
#   Batch    40  of  9,275.    Elapsed: 0:00:02.
#   Batch    80  of  9,275.    Elapsed: 0:00:05.
#   Batch   120  of  9,275.    Elapsed: 0:00:07.
#   Batch   160  of  9,275.    Elapsed: 0:00:10.
#   Batch   200  of  9,275.    Elapsed: 0:00:12.
#   Batch   240  of  9,275.    Elapsed: 0:00:14.
#   Batch   280  of  9,275.    Elapsed: 0:00:17.
#   Batch   320  of  9,275.    Elapsed: 0:00:19.
#   Batch   360  of  9,275.    Elapsed: 0:00:21.
#   Batch   400  of  9,275.    Elapsed: 0:00:24.
#   Batch   440  of  9,275.    Elapsed: 0:00:26.
#   Batch   480  of  9,275.    Elapsed: 0:00:29.
#   Batch   520  of  9,275.    Elapsed: 0:00:31.
#   Batch   560  of  9,275.    Elapsed: 0:00:33.
#   Batch   600  of  9,275.    Elapsed: 0:00:36.
#   Batch   640  of  9,275.    Elapsed: 0:00:38.
#   Batch   680  of  9,275.    Elapsed: 0:00:41.
#   Batch   720  of  9,275.    Elapsed: 0:00:43.
#   Batch   760  of  9,275.    Elapsed: 0:00:45.
#   Batch   800  of  9,275.    Elapsed: 0:00:48.
#   Batch   840  of  9,275.    Elapsed: 0:00:50.
#   Batch   880  of  9,275.    Elapsed: 0:00:52.
#   Batch   920  of  9,275.    Elapsed: 0:00:55.
#   Batch   960  of  9,275.    Elapsed: 0:00:57.
#   Batch 1,000  of  9,275.    Elapsed: 0:01:00.
#   Batch 1,040  of  9,275.    Elapsed: 0:01:02.
#   Batch 1,080  of  9,275.    Elapsed: 0:01:04.
#   Batch 1,120  of  9,275.    Elapsed: 0:01:07.
#   Batch 1,160  of  9,275.    Elapsed: 0:01:09.
#   Batch 1,200  of  9,275.    Elapsed: 0:01:12.
#   Batch 1,240  of  9,275.    Elapsed: 0:01:14.
#   Batch 1,280  of  9,275.    Elapsed: 0:01:16.
#   Batch 1,320  of  9,275.    Elapsed: 0:01:19.
#   Batch 1,360  of  9,275.    Elapsed: 0:01:21.
#   Batch 1,400  of  9,275.    Elapsed: 0:01:23.
#   Batch 1,440  of  9,275.    Elapsed: 0:01:26.
#   Batch 1,480  of  9,275.    Elapsed: 0:01:28.
#   Batch 1,520  of  9,275.    Elapsed: 0:01:31.
#   Batch 1,560  of  9,275.    Elapsed: 0:01:33.
#   Batch 1,600  of  9,275.    Elapsed: 0:01:35.
#   Batch 1,640  of  9,275.    Elapsed: 0:01:38.
#   Batch 1,680  of  9,275.    Elapsed: 0:01:40.
#   Batch 1,720  of  9,275.    Elapsed: 0:01:43.
#   Batch 1,760  of  9,275.    Elapsed: 0:01:45.
#   Batch 1,800  of  9,275.    Elapsed: 0:01:47.
#   Batch 1,840  of  9,275.    Elapsed: 0:01:50.
#   Batch 1,880  of  9,275.    Elapsed: 0:01:52.
#   Batch 1,920  of  9,275.    Elapsed: 0:01:54.
#   Batch 1,960  of  9,275.    Elapsed: 0:01:57.
#   Batch 2,000  of  9,275.    Elapsed: 0:01:59.
#   Batch 2,040  of  9,275.    Elapsed: 0:02:02.
#   Batch 2,080  of  9,275.    Elapsed: 0:02:04.
#   Batch 2,120  of  9,275.    Elapsed: 0:02:06.
#   Batch 2,160  of  9,275.    Elapsed: 0:02:09.
#   Batch 2,200  of  9,275.    Elapsed: 0:02:11.
#   Batch 2,240  of  9,275.    Elapsed: 0:02:14.
#   Batch 2,280  of  9,275.    Elapsed: 0:02:16.
#   Batch 2,320  of  9,275.    Elapsed: 0:02:18.
#   Batch 2,360  of  9,275.    Elapsed: 0:02:21.
#   Batch 2,400  of  9,275.    Elapsed: 0:02:23.
#   Batch 2,440  of  9,275.    Elapsed: 0:02:25.
#   Batch 2,480  of  9,275.    Elapsed: 0:02:28.
#   Batch 2,520  of  9,275.    Elapsed: 0:02:30.
#   Batch 2,560  of  9,275.    Elapsed: 0:02:33.
#   Batch 2,600  of  9,275.    Elapsed: 0:02:35.
#   Batch 2,640  of  9,275.    Elapsed: 0:02:37.
#   Batch 2,680  of  9,275.    Elapsed: 0:02:40.
#   Batch 2,720  of  9,275.    Elapsed: 0:02:42.
#   Batch 2,760  of  9,275.    Elapsed: 0:02:45.
#   Batch 2,800  of  9,275.    Elapsed: 0:02:47.
#   Batch 2,840  of  9,275.    Elapsed: 0:02:49.
#   Batch 2,880  of  9,275.    Elapsed: 0:02:52.
#   Batch 2,920  of  9,275.    Elapsed: 0:02:54.
#   Batch 2,960  of  9,275.    Elapsed: 0:02:56.
#   Batch 3,000  of  9,275.    Elapsed: 0:02:59.
#   Batch 3,040  of  9,275.    Elapsed: 0:03:01.
#   Batch 3,080  of  9,275.    Elapsed: 0:03:04.
#   Batch 3,120  of  9,275.    Elapsed: 0:03:06.
#   Batch 3,160  of  9,275.    Elapsed: 0:03:08.
#   Batch 3,200  of  9,275.    Elapsed: 0:03:11.
#   Batch 3,240  of  9,275.    Elapsed: 0:03:13.
#   Batch 3,280  of  9,275.    Elapsed: 0:03:16.
#   Batch 3,320  of  9,275.    Elapsed: 0:03:18.
#   Batch 3,360  of  9,275.    Elapsed: 0:03:20.
#   Batch 3,400  of  9,275.    Elapsed: 0:03:23.
#   Batch 3,440  of  9,275.    Elapsed: 0:03:25.
#   Batch 3,480  of  9,275.    Elapsed: 0:03:27.
#   Batch 3,520  of  9,275.    Elapsed: 0:03:30.
#   Batch 3,560  of  9,275.    Elapsed: 0:03:32.
#   Batch 3,600  of  9,275.    Elapsed: 0:03:35.
#   Batch 3,640  of  9,275.    Elapsed: 0:03:37.
#   Batch 3,680  of  9,275.    Elapsed: 0:03:39.
#   Batch 3,720  of  9,275.    Elapsed: 0:03:42.
#   Batch 3,760  of  9,275.    Elapsed: 0:03:44.
#   Batch 3,800  of  9,275.    Elapsed: 0:03:46.
#   Batch 3,840  of  9,275.    Elapsed: 0:03:49.
#   Batch 3,880  of  9,275.    Elapsed: 0:03:51.
#   Batch 3,920  of  9,275.    Elapsed: 0:03:54.
#   Batch 3,960  of  9,275.    Elapsed: 0:03:56.
#   Batch 4,000  of  9,275.    Elapsed: 0:03:58.
#   Batch 4,040  of  9,275.    Elapsed: 0:04:01.
#   Batch 4,080  of  9,275.    Elapsed: 0:04:03.
#   Batch 4,120  of  9,275.    Elapsed: 0:04:06.
#   Batch 4,160  of  9,275.    Elapsed: 0:04:08.
#   Batch 4,200  of  9,275.    Elapsed: 0:04:10.
#   Batch 4,240  of  9,275.    Elapsed: 0:04:13.
#   Batch 4,280  of  9,275.    Elapsed: 0:04:15.
#   Batch 4,320  of  9,275.    Elapsed: 0:04:18.
#   Batch 4,360  of  9,275.    Elapsed: 0:04:20.
#   Batch 4,400  of  9,275.    Elapsed: 0:04:22.
#   Batch 4,440  of  9,275.    Elapsed: 0:04:25.
#   Batch 4,480  of  9,275.    Elapsed: 0:04:27.
#   Batch 4,520  of  9,275.    Elapsed: 0:04:29.
#   Batch 4,560  of  9,275.    Elapsed: 0:04:32.
#   Batch 4,600  of  9,275.    Elapsed: 0:04:34.
#   Batch 4,640  of  9,275.    Elapsed: 0:04:37.
#   Batch 4,680  of  9,275.    Elapsed: 0:04:39.
#   Batch 4,720  of  9,275.    Elapsed: 0:04:41.
#   Batch 4,760  of  9,275.    Elapsed: 0:04:44.
#   Batch 4,800  of  9,275.    Elapsed: 0:04:46.
#   Batch 4,840  of  9,275.    Elapsed: 0:04:49.
#   Batch 4,880  of  9,275.    Elapsed: 0:04:51.
#   Batch 4,920  of  9,275.    Elapsed: 0:04:53.
#   Batch 4,960  of  9,275.    Elapsed: 0:04:56.
#   Batch 5,000  of  9,275.    Elapsed: 0:04:58.
#   Batch 5,040  of  9,275.    Elapsed: 0:05:00.
#   Batch 5,080  of  9,275.    Elapsed: 0:05:03.
#   Batch 5,120  of  9,275.    Elapsed: 0:05:05.
#   Batch 5,160  of  9,275.    Elapsed: 0:05:08.
#   Batch 5,200  of  9,275.    Elapsed: 0:05:10.
#   Batch 5,240  of  9,275.    Elapsed: 0:05:12.
#   Batch 5,280  of  9,275.    Elapsed: 0:05:15.
#   Batch 5,320  of  9,275.    Elapsed: 0:05:17.
#   Batch 5,360  of  9,275.    Elapsed: 0:05:19.
#   Batch 5,400  of  9,275.    Elapsed: 0:05:22.
#   Batch 5,440  of  9,275.    Elapsed: 0:05:24.
#   Batch 5,480  of  9,275.    Elapsed: 0:05:27.
#   Batch 5,520  of  9,275.    Elapsed: 0:05:29.
#   Batch 5,560  of  9,275.    Elapsed: 0:05:31.
#   Batch 5,600  of  9,275.    Elapsed: 0:05:34.
#   Batch 5,640  of  9,275.    Elapsed: 0:05:36.
#   Batch 5,680  of  9,275.    Elapsed: 0:05:39.
#   Batch 5,720  of  9,275.    Elapsed: 0:05:41.
#   Batch 5,760  of  9,275.    Elapsed: 0:05:43.
#   Batch 5,800  of  9,275.    Elapsed: 0:05:46.
#   Batch 5,840  of  9,275.    Elapsed: 0:05:48.
#   Batch 5,880  of  9,275.    Elapsed: 0:05:50.
#   Batch 5,920  of  9,275.    Elapsed: 0:05:53.
#   Batch 5,960  of  9,275.    Elapsed: 0:05:55.
#   Batch 6,000  of  9,275.    Elapsed: 0:05:58.
#   Batch 6,040  of  9,275.    Elapsed: 0:06:00.
#   Batch 6,080  of  9,275.    Elapsed: 0:06:02.
#   Batch 6,120  of  9,275.    Elapsed: 0:06:05.
#   Batch 6,160  of  9,275.    Elapsed: 0:06:07.
#   Batch 6,200  of  9,275.    Elapsed: 0:06:10.
#   Batch 6,240  of  9,275.    Elapsed: 0:06:12.
#   Batch 6,280  of  9,275.    Elapsed: 0:06:14.
#   Batch 6,320  of  9,275.    Elapsed: 0:06:17.
#   Batch 6,360  of  9,275.    Elapsed: 0:06:19.
#   Batch 6,400  of  9,275.    Elapsed: 0:06:21.
#   Batch 6,440  of  9,275.    Elapsed: 0:06:24.
#   Batch 6,480  of  9,275.    Elapsed: 0:06:26.
#   Batch 6,520  of  9,275.    Elapsed: 0:06:29.
#   Batch 6,560  of  9,275.    Elapsed: 0:06:31.
#   Batch 6,600  of  9,275.    Elapsed: 0:06:33.
#   Batch 6,640  of  9,275.    Elapsed: 0:06:36.
#   Batch 6,680  of  9,275.    Elapsed: 0:06:38.
#   Batch 6,720  of  9,275.    Elapsed: 0:06:41.
#   Batch 6,760  of  9,275.    Elapsed: 0:06:43.
#   Batch 6,800  of  9,275.    Elapsed: 0:06:45.
#   Batch 6,840  of  9,275.    Elapsed: 0:06:48.
#   Batch 6,880  of  9,275.    Elapsed: 0:06:50.
#   Batch 6,920  of  9,275.    Elapsed: 0:06:52.
#   Batch 6,960  of  9,275.    Elapsed: 0:06:55.
#   Batch 7,000  of  9,275.    Elapsed: 0:06:57.
#   Batch 7,040  of  9,275.    Elapsed: 0:07:00.
#   Batch 7,080  of  9,275.    Elapsed: 0:07:02.
#   Batch 7,120  of  9,275.    Elapsed: 0:07:04.
#   Batch 7,160  of  9,275.    Elapsed: 0:07:07.
#   Batch 7,200  of  9,275.    Elapsed: 0:07:09.
#   Batch 7,240  of  9,275.    Elapsed: 0:07:11.
#   Batch 7,280  of  9,275.    Elapsed: 0:07:14.
#   Batch 7,320  of  9,275.    Elapsed: 0:07:16.
#   Batch 7,360  of  9,275.    Elapsed: 0:07:19.
#   Batch 7,400  of  9,275.    Elapsed: 0:07:21.
#   Batch 7,440  of  9,275.    Elapsed: 0:07:23.
#   Batch 7,480  of  9,275.    Elapsed: 0:07:26.
#   Batch 7,520  of  9,275.    Elapsed: 0:07:28.
#   Batch 7,560  of  9,275.    Elapsed: 0:07:31.
#   Batch 7,600  of  9,275.    Elapsed: 0:07:33.
#   Batch 7,640  of  9,275.    Elapsed: 0:07:35.
#   Batch 7,680  of  9,275.    Elapsed: 0:07:38.
#   Batch 7,720  of  9,275.    Elapsed: 0:07:40.
#   Batch 7,760  of  9,275.    Elapsed: 0:07:42.
#   Batch 7,800  of  9,275.    Elapsed: 0:07:45.
#   Batch 7,840  of  9,275.    Elapsed: 0:07:47.
#   Batch 7,880  of  9,275.    Elapsed: 0:07:50.
#   Batch 7,920  of  9,275.    Elapsed: 0:07:52.
#   Batch 7,960  of  9,275.    Elapsed: 0:07:54.
#   Batch 8,000  of  9,275.    Elapsed: 0:07:57.
#   Batch 8,040  of  9,275.    Elapsed: 0:07:59.
#   Batch 8,080  of  9,275.    Elapsed: 0:08:02.
#   Batch 8,120  of  9,275.    Elapsed: 0:08:04.
#   Batch 8,160  of  9,275.    Elapsed: 0:08:06.
#   Batch 8,200  of  9,275.    Elapsed: 0:08:09.
#   Batch 8,240  of  9,275.    Elapsed: 0:08:11.
#   Batch 8,280  of  9,275.    Elapsed: 0:08:13.
#   Batch 8,320  of  9,275.    Elapsed: 0:08:16.
#   Batch 8,360  of  9,275.    Elapsed: 0:08:18.
#   Batch 8,400  of  9,275.    Elapsed: 0:08:21.
#   Batch 8,440  of  9,275.    Elapsed: 0:08:23.
#   Batch 8,480  of  9,275.    Elapsed: 0:08:25.
#   Batch 8,520  of  9,275.    Elapsed: 0:08:28.
#   Batch 8,560  of  9,275.    Elapsed: 0:08:30.
#   Batch 8,600  of  9,275.    Elapsed: 0:08:33.
#   Batch 8,640  of  9,275.    Elapsed: 0:08:35.
#   Batch 8,680  of  9,275.    Elapsed: 0:08:37.
#   Batch 8,720  of  9,275.    Elapsed: 0:08:40.
#   Batch 8,760  of  9,275.    Elapsed: 0:08:42.
#   Batch 8,800  of  9,275.    Elapsed: 0:08:44.
#   Batch 8,840  of  9,275.    Elapsed: 0:08:47.
#   Batch 8,880  of  9,275.    Elapsed: 0:08:49.
#   Batch 8,920  of  9,275.    Elapsed: 0:08:52.
#   Batch 8,960  of  9,275.    Elapsed: 0:08:54.
#   Batch 9,000  of  9,275.    Elapsed: 0:08:56.
#   Batch 9,040  of  9,275.    Elapsed: 0:08:59.
#   Batch 9,080  of  9,275.    Elapsed: 0:09:01.
#   Batch 9,120  of  9,275.    Elapsed: 0:09:04.
#   Batch 9,160  of  9,275.    Elapsed: 0:09:06.
#   Batch 9,200  of  9,275.    Elapsed: 0:09:08.
#   Batch 9,240  of  9,275.    Elapsed: 0:09:11.
#
#   Average training loss: 0.41
#   Average training accuracy: 0.82
#   Training epcoh took: 0:09:13
#
# Running Validation...
#   Accuracy: 0.84
#   Validation Loss: 0.37
#   Validation took: 0:00:41
#
# ======== Epoch 2 / 2 ========
# Training...
#   Batch    40  of  9,275.    Elapsed: 0:00:02.
#   Batch    80  of  9,275.    Elapsed: 0:00:05.
#   Batch   120  of  9,275.    Elapsed: 0:00:07.
#   Batch   160  of  9,275.    Elapsed: 0:00:10.
#   Batch   200  of  9,275.    Elapsed: 0:00:12.
#   Batch   240  of  9,275.    Elapsed: 0:00:14.
#   Batch   280  of  9,275.    Elapsed: 0:00:17.
#   Batch   320  of  9,275.    Elapsed: 0:00:19.
#   Batch   360  of  9,275.    Elapsed: 0:00:21.
#   Batch   400  of  9,275.    Elapsed: 0:00:24.
#   Batch   440  of  9,275.    Elapsed: 0:00:26.
#   Batch   480  of  9,275.    Elapsed: 0:00:29.
#   Batch   520  of  9,275.    Elapsed: 0:00:31.
#   Batch   560  of  9,275.    Elapsed: 0:00:33.
#   Batch   600  of  9,275.    Elapsed: 0:00:36.
#   Batch   640  of  9,275.    Elapsed: 0:00:38.
#   Batch   680  of  9,275.    Elapsed: 0:00:41.
#   Batch   720  of  9,275.    Elapsed: 0:00:43.
#   Batch   760  of  9,275.    Elapsed: 0:00:45.
#   Batch   800  of  9,275.    Elapsed: 0:00:48.
#   Batch   840  of  9,275.    Elapsed: 0:00:50.
#   Batch   880  of  9,275.    Elapsed: 0:00:52.
#   Batch   920  of  9,275.    Elapsed: 0:00:55.
#   Batch   960  of  9,275.    Elapsed: 0:00:57.
#   Batch 1,000  of  9,275.    Elapsed: 0:01:00.
#   Batch 1,040  of  9,275.    Elapsed: 0:01:02.
#   Batch 1,080  of  9,275.    Elapsed: 0:01:04.
#   Batch 1,120  of  9,275.    Elapsed: 0:01:07.
#   Batch 1,160  of  9,275.    Elapsed: 0:01:09.
#   Batch 1,200  of  9,275.    Elapsed: 0:01:12.
#   Batch 1,240  of  9,275.    Elapsed: 0:01:14.
#   Batch 1,280  of  9,275.    Elapsed: 0:01:16.
#   Batch 1,320  of  9,275.    Elapsed: 0:01:19.
#   Batch 1,360  of  9,275.    Elapsed: 0:01:21.
#   Batch 1,400  of  9,275.    Elapsed: 0:01:23.
#   Batch 1,440  of  9,275.    Elapsed: 0:01:26.
#   Batch 1,480  of  9,275.    Elapsed: 0:01:28.
#   Batch 1,520  of  9,275.    Elapsed: 0:01:31.
#   Batch 1,560  of  9,275.    Elapsed: 0:01:33.
#   Batch 1,600  of  9,275.    Elapsed: 0:01:35.
#   Batch 1,640  of  9,275.    Elapsed: 0:01:38.
#   Batch 1,680  of  9,275.    Elapsed: 0:01:40.
#   Batch 1,720  of  9,275.    Elapsed: 0:01:43.
#   Batch 1,760  of  9,275.    Elapsed: 0:01:45.
#   Batch 1,800  of  9,275.    Elapsed: 0:01:47.
#   Batch 1,840  of  9,275.    Elapsed: 0:01:50.
#   Batch 1,880  of  9,275.    Elapsed: 0:01:52.
#   Batch 1,920  of  9,275.    Elapsed: 0:01:54.
#   Batch 1,960  of  9,275.    Elapsed: 0:01:57.
#   Batch 2,000  of  9,275.    Elapsed: 0:01:59.
#   Batch 2,040  of  9,275.    Elapsed: 0:02:02.
#   Batch 2,080  of  9,275.    Elapsed: 0:02:04.
#   Batch 2,120  of  9,275.    Elapsed: 0:02:06.
#   Batch 2,160  of  9,275.    Elapsed: 0:02:09.
#   Batch 2,200  of  9,275.    Elapsed: 0:02:11.
#   Batch 2,240  of  9,275.    Elapsed: 0:02:13.
#   Batch 2,280  of  9,275.    Elapsed: 0:02:16.
#   Batch 2,320  of  9,275.    Elapsed: 0:02:18.
#   Batch 2,360  of  9,275.    Elapsed: 0:02:21.
#   Batch 2,400  of  9,275.    Elapsed: 0:02:23.
#   Batch 2,440  of  9,275.    Elapsed: 0:02:25.
#   Batch 2,480  of  9,275.    Elapsed: 0:02:28.
#   Batch 2,520  of  9,275.    Elapsed: 0:02:30.
#   Batch 2,560  of  9,275.    Elapsed: 0:02:33.
#   Batch 2,600  of  9,275.    Elapsed: 0:02:35.
#   Batch 2,640  of  9,275.    Elapsed: 0:02:37.
#   Batch 2,680  of  9,275.    Elapsed: 0:02:40.
#   Batch 2,720  of  9,275.    Elapsed: 0:02:42.
#   Batch 2,760  of  9,275.    Elapsed: 0:02:44.
#   Batch 2,800  of  9,275.    Elapsed: 0:02:47.
#   Batch 2,840  of  9,275.    Elapsed: 0:02:49.
#   Batch 2,880  of  9,275.    Elapsed: 0:02:52.
#   Batch 2,920  of  9,275.    Elapsed: 0:02:54.
#   Batch 2,960  of  9,275.    Elapsed: 0:02:56.
#   Batch 3,000  of  9,275.    Elapsed: 0:02:59.
#   Batch 3,040  of  9,275.    Elapsed: 0:03:01.
#   Batch 3,080  of  9,275.    Elapsed: 0:03:04.
#   Batch 3,120  of  9,275.    Elapsed: 0:03:06.
#   Batch 3,160  of  9,275.    Elapsed: 0:03:08.
#   Batch 3,200  of  9,275.    Elapsed: 0:03:11.
#   Batch 3,240  of  9,275.    Elapsed: 0:03:13.
#   Batch 3,280  of  9,275.    Elapsed: 0:03:15.
#   Batch 3,320  of  9,275.    Elapsed: 0:03:18.
#   Batch 3,360  of  9,275.    Elapsed: 0:03:20.
#   Batch 3,400  of  9,275.    Elapsed: 0:03:23.
#   Batch 3,440  of  9,275.    Elapsed: 0:03:25.
#   Batch 3,480  of  9,275.    Elapsed: 0:03:27.
#   Batch 3,520  of  9,275.    Elapsed: 0:03:30.
#   Batch 3,560  of  9,275.    Elapsed: 0:03:32.
#   Batch 3,600  of  9,275.    Elapsed: 0:03:35.
#   Batch 3,640  of  9,275.    Elapsed: 0:03:37.
#   Batch 3,680  of  9,275.    Elapsed: 0:03:39.
#   Batch 3,720  of  9,275.    Elapsed: 0:03:42.
#   Batch 3,760  of  9,275.    Elapsed: 0:03:44.
#   Batch 3,800  of  9,275.    Elapsed: 0:03:46.
#   Batch 3,840  of  9,275.    Elapsed: 0:03:49.
#   Batch 3,880  of  9,275.    Elapsed: 0:03:51.
#   Batch 3,920  of  9,275.    Elapsed: 0:03:54.
#   Batch 3,960  of  9,275.    Elapsed: 0:03:56.
#   Batch 4,000  of  9,275.    Elapsed: 0:03:58.
#   Batch 4,040  of  9,275.    Elapsed: 0:04:01.
#   Batch 4,080  of  9,275.    Elapsed: 0:04:03.
#   Batch 4,120  of  9,275.    Elapsed: 0:04:06.
#   Batch 4,160  of  9,275.    Elapsed: 0:04:08.
#   Batch 4,200  of  9,275.    Elapsed: 0:04:10.
#   Batch 4,240  of  9,275.    Elapsed: 0:04:13.
#   Batch 4,280  of  9,275.    Elapsed: 0:04:15.
#   Batch 4,320  of  9,275.    Elapsed: 0:04:17.
#   Batch 4,360  of  9,275.    Elapsed: 0:04:20.
#   Batch 4,400  of  9,275.    Elapsed: 0:04:22.
#   Batch 4,440  of  9,275.    Elapsed: 0:04:25.
#   Batch 4,480  of  9,275.    Elapsed: 0:04:27.
#   Batch 4,520  of  9,275.    Elapsed: 0:04:29.
#   Batch 4,560  of  9,275.    Elapsed: 0:04:32.
#   Batch 4,600  of  9,275.    Elapsed: 0:04:34.
#   Batch 4,640  of  9,275.    Elapsed: 0:04:37.
#   Batch 4,680  of  9,275.    Elapsed: 0:04:39.
#   Batch 4,720  of  9,275.    Elapsed: 0:04:41.
#   Batch 4,760  of  9,275.    Elapsed: 0:04:44.
#   Batch 4,800  of  9,275.    Elapsed: 0:04:46.
#   Batch 4,840  of  9,275.    Elapsed: 0:04:48.
#   Batch 4,880  of  9,275.    Elapsed: 0:04:51.
#   Batch 4,920  of  9,275.    Elapsed: 0:04:53.
#   Batch 4,960  of  9,275.    Elapsed: 0:04:56.
#   Batch 5,000  of  9,275.    Elapsed: 0:04:58.
#   Batch 5,040  of  9,275.    Elapsed: 0:05:00.
#   Batch 5,080  of  9,275.    Elapsed: 0:05:03.
#   Batch 5,120  of  9,275.    Elapsed: 0:05:05.
#   Batch 5,160  of  9,275.    Elapsed: 0:05:07.
#   Batch 5,200  of  9,275.    Elapsed: 0:05:10.
#   Batch 5,240  of  9,275.    Elapsed: 0:05:12.
#   Batch 5,280  of  9,275.    Elapsed: 0:05:15.
#   Batch 5,320  of  9,275.    Elapsed: 0:05:17.
#   Batch 5,360  of  9,275.    Elapsed: 0:05:19.
#   Batch 5,400  of  9,275.    Elapsed: 0:05:22.
#   Batch 5,440  of  9,275.    Elapsed: 0:05:24.
#   Batch 5,480  of  9,275.    Elapsed: 0:05:27.
#   Batch 5,520  of  9,275.    Elapsed: 0:05:29.
#   Batch 5,560  of  9,275.    Elapsed: 0:05:31.
#   Batch 5,600  of  9,275.    Elapsed: 0:05:34.
#   Batch 5,640  of  9,275.    Elapsed: 0:05:36.
#   Batch 5,680  of  9,275.    Elapsed: 0:05:38.
#   Batch 5,720  of  9,275.    Elapsed: 0:05:41.
#   Batch 5,760  of  9,275.    Elapsed: 0:05:43.
#   Batch 5,800  of  9,275.    Elapsed: 0:05:46.
#   Batch 5,840  of  9,275.    Elapsed: 0:05:48.
#   Batch 5,880  of  9,275.    Elapsed: 0:05:50.
#   Batch 5,920  of  9,275.    Elapsed: 0:05:53.
#   Batch 5,960  of  9,275.    Elapsed: 0:05:55.
#   Batch 6,000  of  9,275.    Elapsed: 0:05:58.
#   Batch 6,040  of  9,275.    Elapsed: 0:06:00.
#   Batch 6,080  of  9,275.    Elapsed: 0:06:02.
#   Batch 6,120  of  9,275.    Elapsed: 0:06:05.
#   Batch 6,160  of  9,275.    Elapsed: 0:06:07.
#   Batch 6,200  of  9,275.    Elapsed: 0:06:09.
#   Batch 6,240  of  9,275.    Elapsed: 0:06:12.
#   Batch 6,280  of  9,275.    Elapsed: 0:06:14.
#   Batch 6,320  of  9,275.    Elapsed: 0:06:17.
#   Batch 6,360  of  9,275.    Elapsed: 0:06:19.
#   Batch 6,400  of  9,275.    Elapsed: 0:06:21.
#   Batch 6,440  of  9,275.    Elapsed: 0:06:24.
#   Batch 6,480  of  9,275.    Elapsed: 0:06:26.
#   Batch 6,520  of  9,275.    Elapsed: 0:06:28.
#   Batch 6,560  of  9,275.    Elapsed: 0:06:31.
#   Batch 6,600  of  9,275.    Elapsed: 0:06:33.
#   Batch 6,640  of  9,275.    Elapsed: 0:06:36.
#   Batch 6,680  of  9,275.    Elapsed: 0:06:38.
#   Batch 6,720  of  9,275.    Elapsed: 0:06:40.
#   Batch 6,760  of  9,275.    Elapsed: 0:06:43.
#   Batch 6,800  of  9,275.    Elapsed: 0:06:45.
#   Batch 6,840  of  9,275.    Elapsed: 0:06:48.
#   Batch 6,880  of  9,275.    Elapsed: 0:06:50.
#   Batch 6,920  of  9,275.    Elapsed: 0:06:52.
#   Batch 6,960  of  9,275.    Elapsed: 0:06:55.
#   Batch 7,000  of  9,275.    Elapsed: 0:06:57.
#   Batch 7,040  of  9,275.    Elapsed: 0:06:59.
#   Batch 7,080  of  9,275.    Elapsed: 0:07:02.
#   Batch 7,120  of  9,275.    Elapsed: 0:07:04.
#   Batch 7,160  of  9,275.    Elapsed: 0:07:07.
#   Batch 7,200  of  9,275.    Elapsed: 0:07:09.
#   Batch 7,240  of  9,275.    Elapsed: 0:07:11.
#   Batch 7,280  of  9,275.    Elapsed: 0:07:14.
#   Batch 7,320  of  9,275.    Elapsed: 0:07:16.
#   Batch 7,360  of  9,275.    Elapsed: 0:07:18.
#   Batch 7,400  of  9,275.    Elapsed: 0:07:21.
#   Batch 7,440  of  9,275.    Elapsed: 0:07:23.
#   Batch 7,480  of  9,275.    Elapsed: 0:07:26.
#   Batch 7,520  of  9,275.    Elapsed: 0:07:28.
#   Batch 7,560  of  9,275.    Elapsed: 0:07:30.
#   Batch 7,600  of  9,275.    Elapsed: 0:07:33.
#   Batch 7,640  of  9,275.    Elapsed: 0:07:35.
#   Batch 7,680  of  9,275.    Elapsed: 0:07:38.
#   Batch 7,720  of  9,275.    Elapsed: 0:07:40.
#   Batch 7,760  of  9,275.    Elapsed: 0:07:42.
#   Batch 7,800  of  9,275.    Elapsed: 0:07:45.
#   Batch 7,840  of  9,275.    Elapsed: 0:07:47.
#   Batch 7,880  of  9,275.    Elapsed: 0:07:49.
#   Batch 7,920  of  9,275.    Elapsed: 0:07:52.
#   Batch 7,960  of  9,275.    Elapsed: 0:07:54.
#   Batch 8,000  of  9,275.    Elapsed: 0:07:57.
#   Batch 8,040  of  9,275.    Elapsed: 0:07:59.
#   Batch 8,080  of  9,275.    Elapsed: 0:08:01.
#   Batch 8,120  of  9,275.    Elapsed: 0:08:04.
#   Batch 8,160  of  9,275.    Elapsed: 0:08:06.
#   Batch 8,200  of  9,275.    Elapsed: 0:08:08.
#   Batch 8,240  of  9,275.    Elapsed: 0:08:11.
#   Batch 8,280  of  9,275.    Elapsed: 0:08:13.
#   Batch 8,320  of  9,275.    Elapsed: 0:08:16.
#   Batch 8,360  of  9,275.    Elapsed: 0:08:18.
#   Batch 8,400  of  9,275.    Elapsed: 0:08:20.
#   Batch 8,440  of  9,275.    Elapsed: 0:08:23.
#   Batch 8,480  of  9,275.    Elapsed: 0:08:25.
#   Batch 8,520  of  9,275.    Elapsed: 0:08:28.
#   Batch 8,560  of  9,275.    Elapsed: 0:08:30.
#   Batch 8,600  of  9,275.    Elapsed: 0:08:32.
#   Batch 8,640  of  9,275.    Elapsed: 0:08:35.
#   Batch 8,680  of  9,275.    Elapsed: 0:08:37.
#   Batch 8,720  of  9,275.    Elapsed: 0:08:39.
#   Batch 8,760  of  9,275.    Elapsed: 0:08:42.
#   Batch 8,800  of  9,275.    Elapsed: 0:08:44.
#   Batch 8,840  of  9,275.    Elapsed: 0:08:47.
#   Batch 8,880  of  9,275.    Elapsed: 0:08:49.
#   Batch 8,920  of  9,275.    Elapsed: 0:08:51.
#   Batch 8,960  of  9,275.    Elapsed: 0:08:54.
#   Batch 9,000  of  9,275.    Elapsed: 0:08:56.
#   Batch 9,040  of  9,275.    Elapsed: 0:08:59.
#   Batch 9,080  of  9,275.    Elapsed: 0:09:01.
#   Batch 9,120  of  9,275.    Elapsed: 0:09:03.
#   Batch 9,160  of  9,275.    Elapsed: 0:09:06.
#   Batch 9,200  of  9,275.    Elapsed: 0:09:08.
#   Batch 9,240  of  9,275.    Elapsed: 0:09:10.
#
#   Average training loss: 0.28
#   Average training accuracy: 0.88
#   Training epcoh took: 0:09:12
#
# Running Validation...
#   Accuracy: 0.85
#   Validation Loss: 0.38
#   Validation took: 0:00:41
#
# Training complete!
# Total training took 0:19:47 (h:mm:ss)
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85     21197
#            1       0.85      0.85      0.85     21199
#
#     accuracy                           0.85     42396
#    macro avg       0.85      0.85      0.85     42396
# weighted avg       0.85      0.85      0.85     42396

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true1, y_pred1))

print(classification_report(y_true2, y_pred2))

print(classification_report(y_true3, y_pred3))

print(classification_report(y_true4, y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83     21197
#            1       0.83      0.83      0.83     21199
#
#     accuracy                           0.83     42396
#    macro avg       0.83      0.83      0.83     42396
# weighted avg       0.83      0.83      0.83     42396
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85     21197
#            1       0.85      0.84      0.84     21199
#
#     accuracy                           0.85     42396
#    macro avg       0.85      0.85      0.85     42396
# weighted avg       0.85      0.85      0.85     42396
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85     21197
#            1       0.85      0.85      0.85     21199
#
#     accuracy                           0.85     42396
#    macro avg       0.85      0.85      0.85     42396
# weighted avg       0.85      0.85      0.85     42396
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85     21197
#            1       0.85      0.85      0.85     21199
#
#     accuracy                           0.85     42396
#    macro avg       0.85      0.85      0.85     42396
# weighted avg       0.85      0.85      0.85     42396

# %%
results1 = pd.DataFrame(results1)
results2 = pd.DataFrame(results2)
results3 = pd.DataFrame(results3)
results4 = pd.DataFrame(results4)

plot_metrics(results1['Training Loss'].to_list(), results1['Valid. Loss'].to_list(), results1['Training Accur.'].to_list(), results1['Valid. Accur.'].to_list(), name='plots/curve_model1.png')
plot_metrics(results2['Training Loss'].to_list(), results2['Valid. Loss'].to_list(), results2['Training Accur.'].to_list(), results2['Valid. Accur.'].to_list(), name='plots/curve_model2.png')
plot_metrics(results3['Training Loss'].to_list(), results3['Valid. Loss'].to_list(), results3['Training Accur.'].to_list(), results3['Valid. Accur.'].to_list(), name='plots/curve_model3.png')
plot_metrics(results4['Training Loss'].to_list(), results4['Valid. Loss'].to_list(), results4['Training Accur.'].to_list(), results4['Valid. Accur.'].to_list(), name='plots/curve_model4.png')

# %%
from sklearn.metrics import roc_curve, auc

# Generate ROC curves
plt.figure(figsize=(6, 5))

fpr1, tpr1, _ = roc_curve(y_true1, y_proba1)
auc1 = auc(fpr1, tpr1)
plt.plot(fpr1, tpr1, label=f'Model1 (AUC = {auc1:.2f})')

fpr2, tpr2, _ = roc_curve(y_true2, y_proba2)
auc2 = auc(fpr2, tpr2)
plt.plot(fpr2, tpr2, label=f'Model2 (AUC = {auc2:.2f})')


fpr3, tpr3, _ = roc_curve(y_true3, y_proba3)
auc3 = auc(fpr3, tpr3)
plt.plot(fpr3, tpr3, label=f'Model3 (AUC = {auc3:.2f})')


fpr4, tpr4, _ = roc_curve(y_true4, y_proba4)
auc4 = auc(fpr4, tpr4)
plt.plot(fpr4, tpr4, label=f'Model4 (AUC = {auc4:.2f})')

# Plot settings
# plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.title('ROC Curves for All Models')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.tight_layout()
plt.savefig('plots/roc_curves.png', dpi=300)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, title, filename):
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap='Blues', values_format='d')
    plt.title(title)
    plt.tight_layout()
    plt.savefig(filename, dpi=300)
    plt.show()
    plt.close()

# Plot and save confusion matrices for all models
plot_confusion_matrix(y_true1, y_pred1, 'Confusion Matrix: Model 1', 'plots/cm_model1.png')
plot_confusion_matrix(y_true2, y_pred2, 'Confusion Matrix: Model 2', 'plots/cm_model2.png')
plot_confusion_matrix(y_true3, y_pred3, 'Confusion Matrix: Model 3', 'plots/cm_model3.png')
plot_confusion_matrix(y_true4, y_pred4, 'Confusion Matrix: Model 4', 'plots/cm_model4.png')

# %%
_, y_pred, _ = extract_metrics(best_model, best_test_dataloader, device)

submission_df = pd.DataFrame({'ID': test_data['ID'], 'Label': y_pred})
submission_df.to_csv('submission.csv', index=False)
